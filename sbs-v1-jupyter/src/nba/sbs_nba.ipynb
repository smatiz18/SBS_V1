# %%
# Written by Sebastian Matiz
import pandas as pd
import requests
import json
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, roc_auc_score
from bs4 import BeautifulSoup
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
from pprint import pprint

cols_to_drop_for_player_stats = [
    "comment",
    "player.firstname",
    "player.lastname",
    "player.id",
    "team.id",
    "team.nickname",
    "team.code",
    "team.name",
    "team.logo",
    "game.id",
    "pos"
]

cols_to_drop_for_game_stats = [
    "league",
    "season",
    "stage",
    "officials",
    "timesTied",
    "leadChanges",
    "nugget",
    "date.start",
    "date.end",
    "date.duration",
    "status.clock",
    "status.halftime",
    "status.short",
    "status.long",
    "periods.current",
    "periods.total",
    "periods.endOfPeriod",
    "arena.name",
    "arena.city",
    "arena.state",
    "arena.country",
    "teams.visitors.id",
    "teams.visitors.name",
    "teams.visitors.nickname",
    "teams.visitors.code",
    "teams.visitors.logo",
    "teams.home.id",
    "teams.home.name",
    "teams.home.nickname",
    "teams.home.code",
    "teams.home.logo",
    "scores.visitors.points",
    "scores.visitors.win",
    "scores.visitors.loss",
    "scores.visitors.series.win",
    "scores.visitors.series.loss",
    "scores.visitors.linescore",
    "scores.home.points",
    "scores.home.win",
    "scores.home.loss",
    "scores.home.series.win",
    "scores.home.series.loss",
    "scores.home.linescore"
]

# %%
# rapidApi headers
headers = {
    "X-RapidAPI-Key": "REDACTED_RAPIDAPI_KEY",
    "X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

# %%
#########################################################
# games by game ids #####################################
def get_team_nicknames_by_id():
    # team code by id
    url = "https://api-nba-v1.p.rapidapi.com/teams"
    response = requests.get(url, headers=headers).json()["response"]
    df = pd.DataFrame(response)
    df = df.loc[(df["nbaFranchise"] == True) & (df["allStar"] == False)]
    
    team_nickname_to_id_map = {}
    
    for index, row in df.iterrows():
        team_nickname_to_id_map.update({row["nickname"]: row["id"]})
    return team_nickname_to_id_map
#########################################################

# %%
team_nickname_to_id_map = get_team_nicknames_by_id()

# %%
#########################################################
# games by game ids #####################################
def get_games_by_game_ids(season, team_id):
    url = "https://api-nba-v1.p.rapidapi.com/games"
    querystring = {"season":season,"team":team_id}

    response = requests.get(url, headers=headers, params=querystring)
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
    df = df.loc[(df["status.long"] == "Finished")]
    df = df.sort_values(by=["date.start"])
    
    # adding win col to df
    df["win"] = ""

    df.loc[
        ((df["scores.home.points"] > df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.home.id"])) |
        ((df["scores.home.points"] < df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.visitors.id"])),
        "win"
    ] = 1

    df.loc[
        ((df["scores.home.points"] < df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.home.id"])) |
        ((df["scores.home.points"] > df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.visitors.id"])),
        "win"
    ] = 0

    df["points"] = np.where(
        df["teams.home.id"] == team_id, 
        df["scores.home.points"], 
        df["scores.visitors.points"]
    )
    df["opponent.points"] = np.where(
        df["teams.home.id"] != team_id, 
        df["scores.home.points"], 
        df["scores.visitors.points"]
    )
    df["opponent.team_id"] = np.where(
        df["teams.home.id"] != team_id, 
        df["teams.home.id"], 
        df["teams.visitors.id"]
    )

    # adding home col to df
    df["home"] = ""
    
    df.loc[(int(team_id) == df["teams.home.id"]), "home"] = 1
        
    df.loc[(int(team_id) == df["teams.visitors.id"]), "home"] = 0    
    
    return drop_cols(df, cols_to_drop_for_game_stats)
#########################################################

# %%
#########################################################
# drop all cols from a df ###############################
def drop_cols(df, cols):
    for col in cols:
        df = df.drop(col, axis=1)
    return df
#########################################################

# %%
#########################################################
# get top n player stats by game by #####################
def get_top_players_per_game_df(n, team_id, game_id):    
    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"

    querystring = {"game": game_id }
    
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )

    df_opponent = df.loc[df["team.id"] != team_id]
    df = df.loc[df["team.id"] == team_id]
    
    df_opponent = drop_cols(df_opponent, cols_to_drop_for_player_stats)
    df = drop_cols(df, cols_to_drop_for_player_stats)
    
    df_opponent = zero_non_numeric_values(df_opponent)
    df = zero_non_numeric_values(df)
    
    df_opponent = df_opponent.add_prefix("opponent.")

    return df_opponent.nlargest(n, "opponent.plusMinus"), df.nlargest(n, "plusMinus")
#########################################################

# %%
#########################################################
# flatten data frames ###################################
def flatten_df(df):
    # Flatten the DataFrame
    flattened_data = {}
    for col in df.columns:
        for row in range(df.shape[0]):
            new_col_name = f"{col}{row}"
            flattened_data[new_col_name] = df[col].iloc[row]

    # Convert to DataFrame
    return pd.DataFrame([flattened_data])
#########################################################

# %%
#########################################################
# per game, get top 5 players by plusMinus metric #######
def get_top_five_players_per_game(team_id, game_ids): 
    top_5_players_on_team_per_game = {}
    for game_id in game_ids:
        # transform player_stats_df
        opponent_top_five_player_stats, friendly_top_five_player_stats = get_top_players_per_game_df(5, team_id, game_id)
        opponent_top_five_player_stats = flatten_df(opponent_top_five_player_stats)
        friendly_top_five_player_stats = flatten_df(friendly_top_five_player_stats)
        top_five_players_stats = pd.concat(
            [opponent_top_five_player_stats, friendly_top_five_player_stats], 
            axis=1
        )
        ###########################
        top_5_players_on_team_per_game[game_id] = top_five_players_stats          
    return top_5_players_on_team_per_game
#########################################################

# %%
#########################################################
# get win prc, and last 10 win prc ######################
def get_win_prc(game_df):
    total_win_prc = []
    last_ten_win_prc = []
    last_ten_games_win_loss = []
    total_games_played = []
    last_ten_win_count = 0
    total_win_count = 0
    total_game_count = 0
    
    for index, row in game_df.iterrows():
        total_game_count += 1
        last_ten_games_win_loss.append(row["win"])
        
        if row["win"]:
            total_win_count += 1
            last_ten_win_count += 1
            
        total_win_prc.append(total_win_count/total_game_count)
               
        if total_game_count >= 10:
            if last_ten_games_win_loss[0]:
                last_ten_win_count -= 1
            last_ten_games_win_loss.pop(0)
            last_ten_win_prc.append(last_ten_win_count/10)
        else:
            last_ten_win_prc.append(last_ten_win_count/total_game_count)
        
        total_games_played.append(total_game_count)            
    return last_ten_win_prc, total_win_prc, total_games_played
#########################################################

# %%
#########################################################
# combine player stats and games features ###############
def combine_player_stats_and_games_data(games_df, player_stats_per_game):
    feature_map = []
    feature_map_cols_header = []
    for index, row in games_df.iterrows():
        game_id = row["id"]
        game_df = pd.DataFrame(row).transpose()
        players_stats_df = player_stats_per_game.get(game_id)
        if len(feature_map_cols_header) < 1:
            feature_map_cols_header = list(game_df) + list(players_stats_df)

        game_data = np.array(game_df.iloc[0])
        player_stats_data = np.array(players_stats_df.iloc[0])
        feature_map_data_row = np.concatenate((game_data, player_stats_data))
        feature_map.append(feature_map_data_row)
    return pd.DataFrame(feature_map, columns=feature_map_cols_header)
#########################################################

# %%
#########################################################
def get_feature_map_and_y(season, team_id):
    games_df = get_games_by_game_ids(season, team_id) 
    
    players_stats_per_games = get_top_five_players_per_game(
        team_id, 
        games_df["id"].array
    )
    
    last_ten_win_prc, total_win_prc, total_games_played = get_win_prc(games_df)
    games_df = games_df.assign(last_ten_w_prc=last_ten_win_prc)
    games_df = games_df.assign(w_prc=total_win_prc)
    games_df = games_df.assign(games_played=total_games_played)
    
    df = combine_player_stats_and_games_data(games_df, players_stats_per_games)
    df = zero_non_numeric_values(df)
    x = drop_cols(df, ["win", "id"])
    y = df["win"]
    return x, y 
#########################################################

# %%
#########################################################
normalization_func_by_team_nickname = {}
def get_xgb_model_and_rf_classifier_model(team_nickname, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

    # normalize feature map
    scaler = MinMaxScaler()
    x_train_normalized = pd.DataFrame(scaler.fit_transform(x_train), columns=x.columns)
    x_test_normalized = pd.DataFrame(scaler.transform(x_test), columns=x.columns)
    normalization_func_by_team_nickname.update({team_nickname: [scaler]})

    # XGB ###################################################
    dtrain = xgb.DMatrix(x_train_normalized, label=y_train)
    dtest = xgb.DMatrix(x_test_normalized, label=y_test)

    params = {
        "objective": "binary:logistic",
        "max_depth": 5,
        "eta": 0.05,
        "eval_metric": "logloss",
    }

    num_boost_round = 999

    bst = xgb.train(
        params, 
        dtrain, 
        num_boost_round, 
        evals=[(dtest, "Test")], 
        early_stopping_rounds=10
    )
    
    # Predict probabilities on the test set
    y_pred_proba = bst.predict(dtest)
    
    # Calculate ROC AUC
    auc_score = roc_auc_score(y_test, y_pred_proba)
    print(f"ROC AUC Score: {auc_score}")
    #########################################################

    # Classifier ############################################
    # training random forest classifier 
    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

    # Train the model on the training set
    rf_classifier.fit(x_train_normalized, y_train)
    
    # Make predictions on the test set
    rf_classifier_predictions = rf_classifier.predict(x_test_normalized)

    # Evaluate the model
    rf_classifier_accuracy = accuracy_score(y_test, rf_classifier_predictions)
    print(f"Accuracy: {rf_classifier_accuracy:.2f}")
    #########################################################
    
    return bst, rf_classifier
#########################################################

# %%
#########################################################
def zero_non_numeric_values(df):
    for col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0)
    return df
#########################################################

# %%
#########################################################
xgb_rf_model_and_data_map = {}
def get_data_and_xgb_rf_models(season, team_nickname):
    team_id = team_nickname_to_id_map.get(team_nickname)
    x, y = get_feature_map_and_y(season, team_id)
   
    xgb, classifier = get_xgb_model_and_rf_classifier_model(team_nickname, x, y)
    xgb_rf_model_and_data_map.update({team_nickname: [xgb, classifier, x, y]})
#########################################################

# %%
#########################################################
def get_player_season_stats_avgs(season, player_id):
    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"
    querystring = {"id":player_id,"season":season}
    
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
    
    df = drop_cols(df, cols_to_drop_for_player_stats)
    df = zero_non_numeric_values(df)

    played_games = df[df["min"] > 0]    
    return played_games.mean()
#########################################################

# %%
#########################################################
def get_players_season_stats_avgs(season, player_ids):
    player_stats_avgs = []
    for i in player_ids:
        player_stats_avgs.append(get_player_season_stats_avgs(season, i))
    
    df = pd.DataFrame(player_stats_avgs)
    return df.sort_values(by=["plusMinus"], ascending=False)
#########################################################

# %%
#########################################################
def get_player_lineups_for_tn():
    url = "https://www.rotowire.com/basketball/nba-lineups.php"
    response = requests.get(url, verify=False)
    soup = BeautifulSoup(response.text, "html.parser")
    players_by_team = {}
    button_divs = soup.find_all("button", class_="see-court-on-off")

    for div in button_divs:
        nickname = div["data-nickname"]
        players_by_team.update({ nickname: [] })
        player_ids = div["data-lineup"].split(",")[:5]
        for player_id in player_ids:
            player_divs = soup.find_all("li", class_="lineup__player")
            for player_div in player_divs:
                a_tags = player_div.find_all("a", href=lambda href: href and player_id in href)
                for a_tag in a_tags:
                    if a_tag["title"] not in players_by_team.get(nickname):
                        players_by_team[nickname].append(a_tag["title"])

    return players_by_team
#########################################################

# %%
#########################################################
def get_players_by_team_and_season(team_id, season):
    url = "https://api-nba-v1.p.rapidapi.com/players"
    querystring = {"team": team_id,"season":season}
    return pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
#########################################################

# %%
#########################################################
def get_team_latest_stats(team_id, season):
    url = "https://api-nba-v1.p.rapidapi.com/teams/statistics"
    querystring = {"id": team_id,"season": season}
    return pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
#########################################################

# %%
#########################################################
def make_alphanum(str):
    return "".join(char.lower() for char in str if char.isalnum())
#########################################################

# %%
#########################################################
def filter_list_not_contain_substrs(list, substrs):
    res = []
    for i in substrs:
        for j in list:
            if make_alphanum(i) in make_alphanum(j):
                res.append(j)
                
    # bug in rapid api, they have Jamie Jaquez Jr. listed as Jamie Jr. Jaquez
    if 'Jaime Jaquez' in substrs:
        res.append('Jamie Jr. Jaquez')
        
    return res
#########################################################

# %%
#########################################################
def get_prediction_feature_map(
    training_data_tail,
    season,
    team_nickname,
    o_team_nickname,
    home
):   
    team_id = team_nickname_to_id_map.get(team_nickname)
    o_team_id = team_nickname_to_id_map.get(o_team_nickname)
    
    # getting player attributes
    df = get_players_by_team_and_season(team_id, season)  
    o_df = get_players_by_team_and_season(o_team_id, season)

    concat_names = df["firstname"] + " " + df["lastname"]
    o_concat_names = o_df["firstname"] + " " + o_df["lastname"]

    name_list = players_name_map.get(team_nickname)    
    o_name_list = players_name_map.get(o_team_nickname)

    filtered_names = filter_list_not_contain_substrs(concat_names, name_list)
    o_filtered_names = filter_list_not_contain_substrs(o_concat_names, o_name_list)
    
    df_players = df[concat_names.isin(set(filtered_names))]
    o_df_players = o_df[o_concat_names.isin(set(o_filtered_names))]
    
    team_latest_stats = get_team_latest_stats(team_id, season)
    o_team_latest_stats = get_team_latest_stats(o_team_id, season)

    team_avg_ppg = team_latest_stats.iloc[0]["points"] / team_latest_stats.iloc[0]["games"]
    o_team_avg_ppg = o_team_latest_stats.iloc[0]["points"] / o_team_latest_stats.iloc[0]["games"]
    
    player_ids = np.array(df_players["id"])
    o_player_ids = np.array(o_df_players["id"])
    
    players_stats_avgs = get_players_season_stats_avgs(season, player_ids)
    o_players_stats_avgs = get_players_season_stats_avgs(season, o_player_ids)
    o_players_stats_avgs = o_players_stats_avgs.add_prefix("opponent.")

    players_stats_avgs = flatten_df(players_stats_avgs)
    o_players_stats_avgs = flatten_df(o_players_stats_avgs)

    players_stats = pd.concat(
        [o_players_stats_avgs, players_stats_avgs], 
        axis=1
    )
    
    games_col_headers = [
        "points",
        "opponent.points", 
        "opponent.team_id",
        "home", 
        "last_ten_w_prc", 
        "w_prc", 
        "games_played"
    ]
    
    games_data = [
        team_avg_ppg, 
        o_team_avg_ppg, 
        o_team_id,
        home, 
        training_data_tail["last_ten_w_prc"].iloc[0], 
        training_data_tail["w_prc"].iloc[0],
        training_data_tail["games_played"].iloc[0] + 1
    ]
        
    feature_map_col_headers = games_col_headers + list(players_stats)
    feature_map_data_row = np.concatenate((games_data, players_stats.iloc[0]))
    return pd.DataFrame([feature_map_data_row], columns=feature_map_col_headers)    
#########################################################

# %%
players_name_map = get_player_lineups_for_tn()
# Out:
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.rotowire.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# Get models for teams ##################################
season = "2023"
# print("76ers")
# get_data_and_xgb_rf_models(season, "76ers")
# print()

print("Knicks")
get_data_and_xgb_rf_models(season, "Knicks")
print()

print("Pacers")
get_data_and_xgb_rf_models(season, "Pacers")
print()

# print("Thunder")
# get_data_and_xgb_rf_models(season, "Thunder")
# print()

# print("Wizards")
# get_data_and_xgb_rf_models(season, "Wizards")
# print()

# print("Grizzlies")
# get_data_and_xgb_rf_models(season, "Grizzlies")
# print()

# print("Rockets")
# get_data_and_xgb_rf_models(season, "Rockets")
# print()

# print("Spurs")
# get_data_and_xgb_rf_models(season, "Spurs")
# print()

# print("Celtics")
# get_data_and_xgb_rf_models(season, "Celtics")
# print()

# print("Jazz")
# get_data_and_xgb_rf_models(season, "Jazz")
# print()

print("Timberwolves")
get_data_and_xgb_rf_models(season, "Timberwolves")
print()

# print("Clippers")
# get_data_and_xgb_rf_models(season, "Clippers")
# print()

# print("Bucks")
# get_data_and_xgb_rf_models(season, "Bucks")
# print()

# print("Kings")
# get_data_and_xgb_rf_models(season, "Kings")
# print()

# print("Raptors")
# get_data_and_xgb_rf_models(season, "Raptors")
# print()
#########################################################
# Out:
# Knicks
# [0]	Test-logloss:0.67925
# [1]	Test-logloss:0.64330
# [2]	Test-logloss:0.61211
# [3]	Test-logloss:0.58391
# [153]	Test-logloss:0.10011
# [154]	Test-logloss:0.10011
# [155]	Test-logloss:0.10011
# [156]	Test-logloss:0.10010
# [157]	Test-logloss:0.10010
# [158]	Test-logloss:0.10010
# [159]	Test-logloss:0.10010
# [160]	Test-logloss:0.10010
# [161]	Test-logloss:0.10010
# [162]	Test-logloss:0.10010
# [163]	Test-logloss:0.10010
# [164]	Test-logloss:0.10010
# [165]	Test-logloss:0.10010
# [166]	Test-logloss:0.10010
# [167]	Test-logloss:0.10010
# [168]	Test-logloss:0.10010
# [169]	Test-logloss:0.10009
# [170]	Test-logloss:0.10009
# [171]	Test-logloss:0.10009
# [172]	Test-logloss:0.10009
# [173]	Test-logloss:0.10009
# [174]	Test-logloss:0.10009
# [175]	Test-logloss:0.10009
# [176]	Test-logloss:0.10009
# [177]	Test-logloss:0.10009
# [178]	Test-logloss:0.10009
# [179]	Test-logloss:0.10009
# [180]	Test-logloss:0.10009
# [181]	Test-logloss:0.10009
# [182]	Test-logloss:0.10009
# [183]	Test-logloss:0.10009
# [184]	Test-logloss:0.10009
# [185]	Test-logloss:0.10009
# [186]	Test-logloss:0.10009
# [187]	Test-logloss:0.10009
# [188]	Test-logloss:0.10009
# [189]	Test-logloss:0.10009
# [190]	Test-logloss:0.10009
# [191]	Test-logloss:0.10009
# [192]	Test-logloss:0.10008
# [193]	Test-logloss:0.10008
# [194]	Test-logloss:0.10008
# [195]	Test-logloss:0.10008
# [196]	Test-logloss:0.10008
# [197]	Test-logloss:0.10008
# [198]	Test-logloss:0.10008
# [199]	Test-logloss:0.10008
# [200]	Test-logloss:0.10008
# [201]	Test-logloss:0.10008
# [202]	Test-logloss:0.10008
# [203]	Test-logloss:0.10008
# [204]	Test-logloss:0.10008
# [205]	Test-logloss:0.10008
# [206]	Test-logloss:0.10008
# [207]	Test-logloss:0.10008
# [208]	Test-logloss:0.10008
# [209]	Test-logloss:0.10008
# [210]	Test-logloss:0.10008
# [211]	Test-logloss:0.10008
# [212]	Test-logloss:0.10008
# [213]	Test-logloss:0.10008
# [214]	Test-logloss:0.10008
# [215]	Test-logloss:0.10008
# [216]	Test-logloss:0.10008
# [217]	Test-logloss:0.10008
# [218]	Test-logloss:0.10008
# [219]	Test-logloss:0.10008
# [220]	Test-logloss:0.10008
# [221]	Test-logloss:0.10008
# [222]	Test-logloss:0.10008
# [223]	Test-logloss:0.10008
# [224]	Test-logloss:0.10008
# [225]	Test-logloss:0.10008
# [226]	Test-logloss:0.10008
# [227]	Test-logloss:0.10008
# [228]	Test-logloss:0.10008
# [229]	Test-logloss:0.10008
# [230]	Test-logloss:0.10008
# [231]	Test-logloss:0.10008
# [232]	Test-logloss:0.10008
# [233]	Test-logloss:0.10008
# [234]	Test-logloss:0.10008
# [235]	Test-logloss:0.10008
# [236]	Test-logloss:0.10008
# [237]	Test-logloss:0.10008
# [238]	Test-logloss:0.10008
# [239]	Test-logloss:0.10008
# [240]	Test-logloss:0.10008
# [241]	Test-logloss:0.10008
# [242]	Test-logloss:0.10008
# [243]	Test-logloss:0.10008
# [244]	Test-logloss:0.10008
# [245]	Test-logloss:0.10008
# [246]	Test-logloss:0.10008
# [247]	Test-logloss:0.10008
# [248]	Test-logloss:0.10008
# [249]	Test-logloss:0.10008
# [250]	Test-logloss:0.10008
# [251]	Test-logloss:0.10008
# [252]	Test-logloss:0.10008
# [253]	Test-logloss:0.10008
# [254]	Test-logloss:0.10008
# [255]	Test-logloss:0.10008
# [256]	Test-logloss:0.10008
# [257]	Test-logloss:0.10008
# [258]	Test-logloss:0.10008
# [259]	Test-logloss:0.10008
# [260]	Test-logloss:0.10008
# [261]	Test-logloss:0.10008
# [262]	Test-logloss:0.10008
# [263]	Test-logloss:0.10008
# [264]	Test-logloss:0.10008
# [265]	Test-logloss:0.10008
# [266]	Test-logloss:0.10008
# [267]	Test-logloss:0.10008
# [268]	Test-logloss:0.10008
# [269]	Test-logloss:0.10008
# [270]	Test-logloss:0.10008
# [271]	Test-logloss:0.10008
# [272]	Test-logloss:0.10008
# [273]	Test-logloss:0.10008
# [274]	Test-logloss:0.10008
# [275]	Test-logloss:0.10008
# [276]	Test-logloss:0.10008
# [277]	Test-logloss:0.10008
# [278]	Test-logloss:0.10008
# [279]	Test-logloss:0.10008
# [280]	Test-logloss:0.10008
# [281]	Test-logloss:0.10008
# [282]	Test-logloss:0.10008
# [283]	Test-logloss:0.10008
# [284]	Test-logloss:0.10008
# [285]	Test-logloss:0.10008
# [286]	Test-logloss:0.10008
# [287]	Test-logloss:0.10008
# [288]	Test-logloss:0.10008
# [289]	Test-logloss:0.10008
# [290]	Test-logloss:0.10008
# [291]	Test-logloss:0.10008
# [292]	Test-logloss:0.10008
# [293]	Test-logloss:0.10008
# [294]	Test-logloss:0.10008
# [295]	Test-logloss:0.10008
# [296]	Test-logloss:0.10008
# [297]	Test-logloss:0.10008
# [298]	Test-logloss:0.10008
# [299]	Test-logloss:0.10008
# [300]	Test-logloss:0.10008
# [301]	Test-logloss:0.10008
# [302]	Test-logloss:0.10008
# [303]	Test-logloss:0.10008
# [304]	Test-logloss:0.10008
# [305]	Test-logloss:0.10008
# [306]	Test-logloss:0.10008
# [307]	Test-logloss:0.10008
# [308]	Test-logloss:0.10008
# [309]	Test-logloss:0.10008
# [310]	Test-logloss:0.10008
# [311]	Test-logloss:0.10008
# [312]	Test-logloss:0.10008
# [313]	Test-logloss:0.10008
# [314]	Test-logloss:0.10008
# [315]	Test-logloss:0.10008
# [316]	Test-logloss:0.10008
# [317]	Test-logloss:0.10008
# [318]	Test-logloss:0.10008
# [319]	Test-logloss:0.10008
# [320]	Test-logloss:0.10008
# [321]	Test-logloss:0.10008
# [322]	Test-logloss:0.10008
# [323]	Test-logloss:0.10008
# [324]	Test-logloss:0.10008
# [325]	Test-logloss:0.10008
# [326]	Test-logloss:0.10008
# [327]	Test-logloss:0.10008
# [328]	Test-logloss:0.10008
# [329]	Test-logloss:0.10008
# [330]	Test-logloss:0.10008
# [331]	Test-logloss:0.10008
# [332]	Test-logloss:0.10008
# [333]	Test-logloss:0.10008
# [334]	Test-logloss:0.10008
# [335]	Test-logloss:0.10008
# [336]	Test-logloss:0.10008
# [337]	Test-logloss:0.10008
# [338]	Test-logloss:0.10008
# [339]	Test-logloss:0.10008
# [340]	Test-logloss:0.10008
# [341]	Test-logloss:0.10008
# [342]	Test-logloss:0.10008
# [343]	Test-logloss:0.10008
# [344]	Test-logloss:0.10008
# [345]	Test-logloss:0.10008
# [346]	Test-logloss:0.10008
# [347]	Test-logloss:0.10008
# [348]	Test-logloss:0.10008
# [349]	Test-logloss:0.10008
# [350]	Test-logloss:0.10008
# [351]	Test-logloss:0.10008
# [352]	Test-logloss:0.10008
# [353]	Test-logloss:0.10008
# [354]	Test-logloss:0.10008
# [355]	Test-logloss:0.10008
# [356]	Test-logloss:0.10008
# [357]	Test-logloss:0.10008
# [358]	Test-logloss:0.10008
# [359]	Test-logloss:0.10008
# [360]	Test-logloss:0.10008
# [361]	Test-logloss:0.10008
# [362]	Test-logloss:0.10008
# [363]	Test-logloss:0.10008
# [364]	Test-logloss:0.10008
# [365]	Test-logloss:0.10008
# [366]	Test-logloss:0.10008
# [367]	Test-logloss:0.10008
# [368]	Test-logloss:0.10008
# [369]	Test-logloss:0.10008
# [370]	Test-logloss:0.10008
# [371]	Test-logloss:0.10008
# [372]	Test-logloss:0.10008
# [373]	Test-logloss:0.10008
# [374]	Test-logloss:0.10008
# [375]	Test-logloss:0.10008
# [376]	Test-logloss:0.10008
# [377]	Test-logloss:0.10008
# [378]	Test-logloss:0.10008
# [379]	Test-logloss:0.10008
# [380]	Test-logloss:0.10008
# [381]	Test-logloss:0.10008
# [382]	Test-logloss:0.10008
# [383]	Test-logloss:0.10008
# [384]	Test-logloss:0.10008
# [385]	Test-logloss:0.10008
# [386]	Test-logloss:0.10008
# [387]	Test-logloss:0.10008
# [388]	Test-logloss:0.10008
# [389]	Test-logloss:0.10008
# [390]	Test-logloss:0.10008
# [391]	Test-logloss:0.10008
# [392]	Test-logloss:0.10008
# [393]	Test-logloss:0.10008
# [394]	Test-logloss:0.10008
# [395]	Test-logloss:0.10008
# [396]	Test-logloss:0.10008
# [397]	Test-logloss:0.10008
# [398]	Test-logloss:0.10008
# [399]	Test-logloss:0.10008
# [400]	Test-logloss:0.10008
# [401]	Test-logloss:0.10008
# [402]	Test-logloss:0.10008
# [403]	Test-logloss:0.10008
# [404]	Test-logloss:0.10008
# [405]	Test-logloss:0.10008
# [406]	Test-logloss:0.10008
# [407]	Test-logloss:0.10008
# [408]	Test-logloss:0.10008
# [409]	Test-logloss:0.10008
# [410]	Test-logloss:0.10008
# [411]	Test-logloss:0.10008
# [412]	Test-logloss:0.10008
# [413]	Test-logloss:0.10008
# [414]	Test-logloss:0.10008
# [415]	Test-logloss:0.10008
# [416]	Test-logloss:0.10008
# [417]	Test-logloss:0.10008
# [418]	Test-logloss:0.10008
# [419]	Test-logloss:0.10008
# [420]	Test-logloss:0.10008
# [421]	Test-logloss:0.10008
# [422]	Test-logloss:0.10008
# [423]	Test-logloss:0.10008
# [424]	Test-logloss:0.10008
# [425]	Test-logloss:0.10008
# [426]	Test-logloss:0.10008
# [427]	Test-logloss:0.10008
# [428]	Test-logloss:0.10008
# [429]	Test-logloss:0.10008
# [430]	Test-logloss:0.10008
# [431]	Test-logloss:0.10008
# [432]	Test-logloss:0.10008
# [433]	Test-logloss:0.10008
# [434]	Test-logloss:0.10008
# [435]	Test-logloss:0.10008
# [436]	Test-logloss:0.10008
# [437]	Test-logloss:0.10008
# [438]	Test-logloss:0.10008
# [439]	Test-logloss:0.10008
# [440]	Test-logloss:0.10008
# [441]	Test-logloss:0.10008
# [442]	Test-logloss:0.10008
# [443]	Test-logloss:0.10008
# [444]	Test-logloss:0.10008
# [445]	Test-logloss:0.10008
# [446]	Test-logloss:0.10008
# [447]	Test-logloss:0.10008
# [448]	Test-logloss:0.10008
# [449]	Test-logloss:0.10008
# [450]	Test-logloss:0.10008
# [451]	Test-logloss:0.10008
# [452]	Test-logloss:0.10008
# [453]	Test-logloss:0.10008
# [454]	Test-logloss:0.10008
# [455]	Test-logloss:0.10008
# [456]	Test-logloss:0.10008
# [457]	Test-logloss:0.10008
# [458]	Test-logloss:0.10008
# [459]	Test-logloss:0.10008
# [460]	Test-logloss:0.10008
# [461]	Test-logloss:0.10008
# [462]	Test-logloss:0.10008
# [463]	Test-logloss:0.10008
# [464]	Test-logloss:0.10008
# [465]	Test-logloss:0.10008
# [466]	Test-logloss:0.10008
# [467]	Test-logloss:0.10008
# [468]	Test-logloss:0.10008
# [469]	Test-logloss:0.10008
# [470]	Test-logloss:0.10008
# [471]	Test-logloss:0.10008
# [472]	Test-logloss:0.10008
# [473]	Test-logloss:0.10008
# [474]	Test-logloss:0.10008
# [475]	Test-logloss:0.10008
# [476]	Test-logloss:0.10008
# [477]	Test-logloss:0.10008
# [478]	Test-logloss:0.10008
# [479]	Test-logloss:0.10008
# [480]	Test-logloss:0.10008
# [481]	Test-logloss:0.10008
# [482]	Test-logloss:0.10008
# [483]	Test-logloss:0.10008
# [484]	Test-logloss:0.10008
# [485]	Test-logloss:0.10008
# [486]	Test-logloss:0.10008
# [487]	Test-logloss:0.10008
# [488]	Test-logloss:0.10008
# [489]	Test-logloss:0.10008
# [490]	Test-logloss:0.10008
# [491]	Test-logloss:0.10008
# [492]	Test-logloss:0.10008
# [493]	Test-logloss:0.10008
# [494]	Test-logloss:0.10008
# [495]	Test-logloss:0.10008
# [496]	Test-logloss:0.10008
# [497]	Test-logloss:0.10008
# [498]	Test-logloss:0.10008
# [499]	Test-logloss:0.10008
# [500]	Test-logloss:0.10008
# [501]	Test-logloss:0.10008
# [502]	Test-logloss:0.10008
# [503]	Test-logloss:0.10008
# [504]	Test-logloss:0.10008
# [505]	Test-logloss:0.10008
# [506]	Test-logloss:0.10008
# [507]	Test-logloss:0.10008
# [508]	Test-logloss:0.10008
# [509]	Test-logloss:0.10008
# [510]	Test-logloss:0.10008
# [511]	Test-logloss:0.10008
# [512]	Test-logloss:0.10008
# [513]	Test-logloss:0.10008
# [514]	Test-logloss:0.10008
# [515]	Test-logloss:0.10008
# [516]	Test-logloss:0.10008
# [517]	Test-logloss:0.10008
# [518]	Test-logloss:0.10008
# [519]	Test-logloss:0.10008
# [520]	Test-logloss:0.10008
# [521]	Test-logloss:0.10008
# [522]	Test-logloss:0.10008
# [523]	Test-logloss:0.10008
# [524]	Test-logloss:0.10008
# [525]	Test-logloss:0.10008
# [526]	Test-logloss:0.10008
# [527]	Test-logloss:0.10008
# [528]	Test-logloss:0.10008
# [529]	Test-logloss:0.10008
# [530]	Test-logloss:0.10008
# [531]	Test-logloss:0.10008
# [532]	Test-logloss:0.10008
# [533]	Test-logloss:0.10008
# [534]	Test-logloss:0.10008
# [535]	Test-logloss:0.10008
# [536]	Test-logloss:0.10008
# [537]	Test-logloss:0.10008
# [538]	Test-logloss:0.10008
# [539]	Test-logloss:0.10008
# [540]	Test-logloss:0.10008
# [541]	Test-logloss:0.10008
# [542]	Test-logloss:0.10008
# [543]	Test-logloss:0.10008
# [544]	Test-logloss:0.10008
# [545]	Test-logloss:0.10008
# [546]	Test-logloss:0.10008
# [547]	Test-logloss:0.10008
# [548]	Test-logloss:0.10008
# [549]	Test-logloss:0.10008
# [550]	Test-logloss:0.10008
# [551]	Test-logloss:0.10008
# [552]	Test-logloss:0.10008
# [553]	Test-logloss:0.10008
# [554]	Test-logloss:0.10008
# [555]	Test-logloss:0.10008
# [556]	Test-logloss:0.10008
# [557]	Test-logloss:0.10008
# [558]	Test-logloss:0.10008
# [559]	Test-logloss:0.10008
# [560]	Test-logloss:0.10008
# [561]	Test-logloss:0.10008
# [562]	Test-logloss:0.10008
# [563]	Test-logloss:0.10008
# [564]	Test-logloss:0.10008
# [565]	Test-logloss:0.10008
# [566]	Test-logloss:0.10008
# [567]	Test-logloss:0.10008
# [568]	Test-logloss:0.10008
# [569]	Test-logloss:0.10008
# [570]	Test-logloss:0.10008
# [571]	Test-logloss:0.10008
# [572]	Test-logloss:0.10008
# [573]	Test-logloss:0.10008
# [574]	Test-logloss:0.10008
# [575]	Test-logloss:0.10008
# [576]	Test-logloss:0.10008
# [577]	Test-logloss:0.10008
# [578]	Test-logloss:0.10008
# [579]	Test-logloss:0.10008
# [580]	Test-logloss:0.10008
# [581]	Test-logloss:0.10008
# [582]	Test-logloss:0.10008
# [583]	Test-logloss:0.10008
# [584]	Test-logloss:0.10008
# [585]	Test-logloss:0.10008
# [586]	Test-logloss:0.10008
# [587]	Test-logloss:0.10008
# [588]	Test-logloss:0.10008
# [589]	Test-logloss:0.10008
# [590]	Test-logloss:0.10008
# [591]	Test-logloss:0.10008
# [592]	Test-logloss:0.10008
# [593]	Test-logloss:0.10008
# [594]	Test-logloss:0.10008
# [595]	Test-logloss:0.10008
# [596]	Test-logloss:0.10008
# [597]	Test-logloss:0.10008
# [598]	Test-logloss:0.10008
# [599]	Test-logloss:0.10008
# [600]	Test-logloss:0.10008
# [601]	Test-logloss:0.10008
# [602]	Test-logloss:0.10008
# [603]	Test-logloss:0.10008
# [604]	Test-logloss:0.10008
# [605]	Test-logloss:0.10008
# [606]	Test-logloss:0.10008
# [607]	Test-logloss:0.10008
# [608]	Test-logloss:0.10008
# [609]	Test-logloss:0.10008
# [610]	Test-logloss:0.10008
# [611]	Test-logloss:0.10008
# [612]	Test-logloss:0.10008
# [613]	Test-logloss:0.10008
# [614]	Test-logloss:0.10008
# [615]	Test-logloss:0.10008
# [616]	Test-logloss:0.10008
# [617]	Test-logloss:0.10008
# [618]	Test-logloss:0.10008
# [619]	Test-logloss:0.10008
# [620]	Test-logloss:0.10008
# [621]	Test-logloss:0.10008
# [622]	Test-logloss:0.10008
# [623]	Test-logloss:0.10008
# [624]	Test-logloss:0.10008
# [625]	Test-logloss:0.10008
# [626]	Test-logloss:0.10008
# [627]	Test-logloss:0.10008
# [628]	Test-logloss:0.10008
# [629]	Test-logloss:0.10008
# [630]	Test-logloss:0.10008
# [631]	Test-logloss:0.10008
# [632]	Test-logloss:0.10008
# [633]	Test-logloss:0.10008
# [634]	Test-logloss:0.10008
# [635]	Test-logloss:0.10008
# [636]	Test-logloss:0.10008
# [637]	Test-logloss:0.10008
# [638]	Test-logloss:0.10008
# [639]	Test-logloss:0.10008
# [640]	Test-logloss:0.10008
# [641]	Test-logloss:0.10008
# [642]	Test-logloss:0.10008
# [643]	Test-logloss:0.10008
# [644]	Test-logloss:0.10008
# [645]	Test-logloss:0.10008
# [646]	Test-logloss:0.10008
# [647]	Test-logloss:0.10008
# [648]	Test-logloss:0.10008
# [649]	Test-logloss:0.10008
# [650]	Test-logloss:0.10008
# [651]	Test-logloss:0.10008
# [652]	Test-logloss:0.10008
# [653]	Test-logloss:0.10008
# [654]	Test-logloss:0.10008
# [655]	Test-logloss:0.10008
# [656]	Test-logloss:0.10008
# [657]	Test-logloss:0.10008
# [658]	Test-logloss:0.10008
# [659]	Test-logloss:0.10008
# [660]	Test-logloss:0.10008
# [661]	Test-logloss:0.10008
# [662]	Test-logloss:0.10008
# [663]	Test-logloss:0.10008
# [664]	Test-logloss:0.10008
# [665]	Test-logloss:0.10008
# [666]	Test-logloss:0.10008
# [667]	Test-logloss:0.10008
# [668]	Test-logloss:0.10008
# [669]	Test-logloss:0.10008
# [670]	Test-logloss:0.10008
# [671]	Test-logloss:0.10008
# [672]	Test-logloss:0.10008
# [673]	Test-logloss:0.10008
# [674]	Test-logloss:0.10008
# [675]	Test-logloss:0.10008
# [676]	Test-logloss:0.10008
# [677]	Test-logloss:0.10008
# [678]	Test-logloss:0.10008
# [679]	Test-logloss:0.10008
# [680]	Test-logloss:0.10008
# [681]	Test-logloss:0.10008
# [682]	Test-logloss:0.10008
# [683]	Test-logloss:0.10008
# [684]	Test-logloss:0.10008
# [685]	Test-logloss:0.10008
# [686]	Test-logloss:0.10008
# [687]	Test-logloss:0.10008
# [688]	Test-logloss:0.10008
# [689]	Test-logloss:0.10008
# [690]	Test-logloss:0.10008
# [691]	Test-logloss:0.10008
# [692]	Test-logloss:0.10008
# [693]	Test-logloss:0.10008
# [694]	Test-logloss:0.10008
# [695]	Test-logloss:0.10008
# [696]	Test-logloss:0.10008
# [697]	Test-logloss:0.10008
# [698]	Test-logloss:0.10008
# [699]	Test-logloss:0.10008
# [700]	Test-logloss:0.10008
# [701]	Test-logloss:0.10008
# [702]	Test-logloss:0.10008
# [703]	Test-logloss:0.10008
# [704]	Test-logloss:0.10008
# [705]	Test-logloss:0.10008
# [706]	Test-logloss:0.10008
# [707]	Test-logloss:0.10008
# [708]	Test-logloss:0.10008
# [709]	Test-logloss:0.10008
# [710]	Test-logloss:0.10008
# [711]	Test-logloss:0.10008
# [712]	Test-logloss:0.10008
# [713]	Test-logloss:0.10008
# [714]	Test-logloss:0.10008
# [715]	Test-logloss:0.10008
# [716]	Test-logloss:0.10008
# [717]	Test-logloss:0.10008
# [718]	Test-logloss:0.10008
# [719]	Test-logloss:0.10008
# [720]	Test-logloss:0.10008
# [721]	Test-logloss:0.10008
# [722]	Test-logloss:0.10008
# [723]	Test-logloss:0.10008
# [724]	Test-logloss:0.10008
# [725]	Test-logloss:0.10008
# [726]	Test-logloss:0.10008
# [727]	Test-logloss:0.10008
# [728]	Test-logloss:0.10008
# [729]	Test-logloss:0.10008
# [730]	Test-logloss:0.10008
# [731]	Test-logloss:0.10008
# [732]	Test-logloss:0.10008
# [733]	Test-logloss:0.10008
# [734]	Test-logloss:0.10008
# [735]	Test-logloss:0.10008
# [736]	Test-logloss:0.10008
# [737]	Test-logloss:0.10008
# [738]	Test-logloss:0.10008
# [739]	Test-logloss:0.10008
# [740]	Test-logloss:0.10008
# [741]	Test-logloss:0.10008
# [742]	Test-logloss:0.10008
# [743]	Test-logloss:0.10008
# [744]	Test-logloss:0.10008
# [745]	Test-logloss:0.10008
# [746]	Test-logloss:0.10008
# [747]	Test-logloss:0.10008
# [748]	Test-logloss:0.10008
# [749]	Test-logloss:0.10008
# [750]	Test-logloss:0.10008
# [751]	Test-logloss:0.10008
# [752]	Test-logloss:0.10008
# [753]	Test-logloss:0.10008
# [754]	Test-logloss:0.10008
# [755]	Test-logloss:0.10008
# [756]	Test-logloss:0.10008
# [757]	Test-logloss:0.10008
# [758]	Test-logloss:0.10008
# [759]	Test-logloss:0.10008
# [760]	Test-logloss:0.10008
# [761]	Test-logloss:0.10008
# [762]	Test-logloss:0.10008
# [763]	Test-logloss:0.10008
# [764]	Test-logloss:0.10008
# [765]	Test-logloss:0.10008
# [766]	Test-logloss:0.10008
# [767]	Test-logloss:0.10008
# [768]	Test-logloss:0.10008
# [769]	Test-logloss:0.10008
# [770]	Test-logloss:0.10008
# [771]	Test-logloss:0.10008
# [772]	Test-logloss:0.10008
# [773]	Test-logloss:0.10008
# [774]	Test-logloss:0.10008
# [775]	Test-logloss:0.10008
# [776]	Test-logloss:0.10008
# [777]	Test-logloss:0.10008
# [778]	Test-logloss:0.10008
# [779]	Test-logloss:0.10008
# [780]	Test-logloss:0.10008
# [781]	Test-logloss:0.10008
# [782]	Test-logloss:0.10008
# [783]	Test-logloss:0.10008
# [784]	Test-logloss:0.10007
# [785]	Test-logloss:0.10007
# [786]	Test-logloss:0.10007
# [787]	Test-logloss:0.10007
# [788]	Test-logloss:0.10007
# [61]	Test-logloss:0.35402
# [62]	Test-logloss:0.35199
# [63]	Test-logloss:0.34894
# [64]	Test-logloss:0.35237
# [65]	Test-logloss:0.34924
# [66]	Test-logloss:0.34421
# [67]	Test-logloss:0.34233
# [68]	Test-logloss:0.33958
# [69]	Test-logloss:0.33488
# [70]	Test-logloss:0.33813
# [71]	Test-logloss:0.33459
# [72]	Test-logloss:0.33044
# [73]	Test-logloss:0.33359
# [74]	Test-logloss:0.32919
# [75]	Test-logloss:0.32646
# [76]	Test-logloss:0.32302
# [77]	Test-logloss:0.32470
# [78]	Test-logloss:0.32181
# [79]	Test-logloss:0.31781
# [80]	Test-logloss:0.31533
# [81]	Test-logloss:0.31733
# [82]	Test-logloss:0.31383
# [83]	Test-logloss:0.31148
# [84]	Test-logloss:0.31446
# [85]	Test-logloss:0.31108
# [86]	Test-logloss:0.30882
# [87]	Test-logloss:0.31041
# [88]	Test-logloss:0.30786
# [89]	Test-logloss:0.31071
# [90]	Test-logloss:0.30950
# [91]	Test-logloss:0.30704
# [92]	Test-logloss:0.30861
# [93]	Test-logloss:0.30960
# [94]	Test-logloss:0.31078
# [95]	Test-logloss:0.30946
# [96]	Test-logloss:0.30711
# [97]	Test-logloss:0.30865
# [98]	Test-logloss:0.30985
# [99]	Test-logloss:0.30860
# [100]	Test-logloss:0.30636
# [101]	Test-logloss:0.30653
# [102]	Test-logloss:0.30914
# [103]	Test-logloss:0.31032
# [104]	Test-logloss:0.30815
# [105]	Test-logloss:0.30697
# [106]	Test-logloss:0.30714
# [107]	Test-logloss:0.30502
# [108]	Test-logloss:0.30617
# [109]	Test-logloss:0.30489
# [110]	Test-logloss:0.30286
# [111]	Test-logloss:0.30303
# [112]	Test-logloss:0.30193
# [113]	Test-logloss:0.30307
# [114]	Test-logloss:0.30109
# [115]	Test-logloss:0.30004
# [116]	Test-logloss:0.29903
# [117]	Test-logloss:0.29807
# [118]	Test-logloss:0.29714
# [119]	Test-logloss:0.29624
# [120]	Test-logloss:0.29620
# [121]	Test-logloss:0.29644
# [122]	Test-logloss:0.29641
# [123]	Test-logloss:0.29642
# [124]	Test-logloss:0.29643
# [125]	Test-logloss:0.29643
# [126]	Test-logloss:0.29644
# [127]	Test-logloss:0.29644
# [128]	Test-logloss:0.29645
# [129]	Test-logloss:0.29645
# [130]	Test-logloss:0.29646
# ROC AUC Score: 1.0
# Accuracy: 0.89

# %%
# Get models for teams ##################################
# print("Pistons")
# get_data_and_xgb_rf_models(season, "Pistons")
# print()

# print("Nets")
# get_data_and_xgb_rf_models(season, "Nets")
# print()

# print("Magic")
# get_data_and_xgb_rf_models(season, "Magic")
# print()

print("Nuggets")
get_data_and_xgb_rf_models(season, "Nuggets")
print()

# print("Heat")
# get_data_and_xgb_rf_models(season, "Heat")
# print()

# print("Bulls")
# get_data_and_xgb_rf_models(season, "Bulls")
# print()

# print("Hornets")
# get_data_and_xgb_rf_models(season, "Hornets")
# print()

# print("Cavaliers")
# get_data_and_xgb_rf_models(season, "Cavaliers")
# print()

# print("Pelicans")
# get_data_and_xgb_rf_models(season, "Pelicans")
# print()

# print("Warriors")
# get_data_and_xgb_rf_models(season, "Warriors")
# print()

# print("Suns")
# get_data_and_xgb_rf_models(season, "Suns")
# print()

# print("Mavericks")
# get_data_and_xgb_rf_models(season, "Mavericks")
# print()

# print("Lakers")
# get_data_and_xgb_rf_models(season, "Lakers")
# print()

# print("Hawks")
# get_data_and_xgb_rf_models(season, "Hawks")
# print()

# print("Trail Blazers")
# get_data_and_xgb_rf_models(season, "Trail Blazers")
# print()
#########################################################
# Out:
# Nuggets
# [0]	Test-logloss:0.51407
# [1]	Test-logloss:0.48744
# [2]	Test-logloss:0.46202
# [3]	Test-logloss:0.44502
# [4]	Test-logloss:0.42451
# [5]	Test-logloss:0.40705
# [6]	Test-logloss:0.39057
# [7]	Test-logloss:0.37251
# [8]	Test-logloss:0.35896
# [9]	Test-logloss:0.34419
# [10]	Test-logloss:0.32975
# [11]	Test-logloss:0.31582
# [12]	Test-logloss:0.30254
# [13]	Test-logloss:0.29122
# [14]	Test-logloss:0.28296
# [15]	Test-logloss:0.27287
# [16]	Test-logloss:0.26382
# [17]	Test-logloss:0.25487
# [18]	Test-logloss:0.24714
# [19]	Test-logloss:0.23985
# [20]	Test-logloss:0.23318
# [21]	Test-logloss:0.22665
# [22]	Test-logloss:0.22124
# [23]	Test-logloss:0.21635
# [24]	Test-logloss:0.21136
# [25]	Test-logloss:0.20596
# [26]	Test-logloss:0.20362
# [27]	Test-logloss:0.19964
# [28]	Test-logloss:0.19493
# [29]	Test-logloss:0.19131
# [30]	Test-logloss:0.18912
# [31]	Test-logloss:0.18664
# [32]	Test-logloss:0.18420
# [33]	Test-logloss:0.18161
# [34]	Test-logloss:0.17638
# [35]	Test-logloss:0.17329
# [36]	Test-logloss:0.17202
# [37]	Test-logloss:0.16725
# [38]	Test-logloss:0.16463
# [39]	Test-logloss:0.16000
# [40]	Test-logloss:0.15767
# [41]	Test-logloss:0.15622
# [42]	Test-logloss:0.15359
# [43]	Test-logloss:0.15043
# [44]	Test-logloss:0.14859
# [45]	Test-logloss:0.14477
# [46]	Test-logloss:0.14315
# [47]	Test-logloss:0.14016
# [48]	Test-logloss:0.13929
# [49]	Test-logloss:0.13649
# [50]	Test-logloss:0.13503
# [51]	Test-logloss:0.13388
# [52]	Test-logloss:0.13075
# [53]	Test-logloss:0.12975
# [54]	Test-logloss:0.12738
# [55]	Test-logloss:0.12654
# [56]	Test-logloss:0.12424
# [57]	Test-logloss:0.12209
# [58]	Test-logloss:0.12103
# [59]	Test-logloss:0.11901
# [60]	Test-logloss:0.11826
# [61]	Test-logloss:0.11771
# [62]	Test-logloss:0.11552
# [63]	Test-logloss:0.11506
# [64]	Test-logloss:0.11347
# [65]	Test-logloss:0.11297
# [66]	Test-logloss:0.11087
# [67]	Test-logloss:0.10944
# [68]	Test-logloss:0.10916
# [69]	Test-logloss:0.10856
# [70]	Test-logloss:0.10843
# [71]	Test-logloss:0.10654
# [72]	Test-logloss:0.10529
# [73]	Test-logloss:0.10519
# [74]	Test-logloss:0.10535
# [75]	Test-logloss:0.10360
# [76]	Test-logloss:0.10332
# [77]	Test-logloss:0.10222
# [78]	Test-logloss:0.10225
# [79]	Test-logloss:0.10065
# [80]	Test-logloss:0.09968
# [81]	Test-logloss:0.09992
# [82]	Test-logloss:0.09977
# [83]	Test-logloss:0.09804
# [84]	Test-logloss:0.09719
# [85]	Test-logloss:0.09709
# [86]	Test-logloss:0.09731
# [87]	Test-logloss:0.09590
# [88]	Test-logloss:0.09619
# [89]	Test-logloss:0.09615
# [90]	Test-logloss:0.09497
# [91]	Test-logloss:0.09344
# [92]	Test-logloss:0.09345
# [93]	Test-logloss:0.09376
# [94]	Test-logloss:0.09249
# [95]	Test-logloss:0.09258
# [96]	Test-logloss:0.09292
# [97]	Test-logloss:0.09185
# [98]	Test-logloss:0.09191
# [99]	Test-logloss:0.09073
# [100]	Test-logloss:0.09108
# [101]	Test-logloss:0.09117
# [102]	Test-logloss:0.09018
# [103]	Test-logloss:0.09027
# [104]	Test-logloss:0.09064
# [105]	Test-logloss:0.08955
# [106]	Test-logloss:0.08967
# [107]	Test-logloss:0.09005
# [108]	Test-logloss:0.08912
# [109]	Test-logloss:0.08950
# [110]	Test-logloss:0.08848
# [111]	Test-logloss:0.08858
# [112]	Test-logloss:0.08760
# [113]	Test-logloss:0.08676
# [114]	Test-logloss:0.08688
# [115]	Test-logloss:0.08607
# [116]	Test-logloss:0.08620
# [117]	Test-logloss:0.08634
# [118]	Test-logloss:0.08546
# [119]	Test-logloss:0.08470
# [120]	Test-logloss:0.08385
# [121]	Test-logloss:0.08304
# [122]	Test-logloss:0.08258
# [123]	Test-logloss:0.08267
# [124]	Test-logloss:0.08276
# [125]	Test-logloss:0.08302
# [126]	Test-logloss:0.08327
# [127]	Test-logloss:0.08351
# [128]	Test-logloss:0.08352
# [129]	Test-logloss:0.08352
# [130]	Test-logloss:0.08353
# [131]	Test-logloss:0.08354
# ROC AUC Score: 1.0
# Accuracy: 1.00

# %%
games_pred = []
def predict(
    season,
    nickname_0, 
    nickname_1
):
    xgb_rf_pred_map_0 = {}
    xgb_rf_pred_map_1 = {}
    
    x_0 = get_prediction_feature_map(xgb_rf_model_and_data_map.get(nickname_0)[2].tail(1), season, nickname_0, nickname_1, 0)
    x_1 = get_prediction_feature_map(xgb_rf_model_and_data_map.get(nickname_1)[2].tail(1), season, nickname_1, nickname_0, 1)
    normalization_func_0 = normalization_func_by_team_nickname.get(nickname_0)[0]
    normalization_func_1 = normalization_func_by_team_nickname.get(nickname_1)[0]
    
    x_0_normalized = pd.DataFrame(normalization_func_0.transform(x_0), columns=x_0.columns)
    x_1_normalized = pd.DataFrame(normalization_func_1.transform(x_1), columns=x_1.columns)
    dnew_0 = xgb.DMatrix(x_0_normalized)
    dnew_1 = xgb.DMatrix(x_1_normalized)

    xgb_res_0 = xgb_rf_model_and_data_map.get(nickname_0)[0].predict(dnew_0)
    xgb_res_1 = xgb_rf_model_and_data_map.get(nickname_1)[0].predict(dnew_1)

    rf_res_0 = xgb_rf_model_and_data_map.get(nickname_0)[1].predict(x_0_normalized)
    rf_res_1 = xgb_rf_model_and_data_map.get(nickname_1)[1].predict(x_1_normalized)

    xgb_rf_pred_map_0[nickname_0] = {
        "xgb_proba": xgb_res_0,
        "rf_clf": rf_res_0
    }
    xgb_rf_pred_map_1[nickname_1] = {
        "xgb_proba": xgb_res_1,
        "rf_clf": rf_res_1
    }

    games_pred.append([xgb_rf_pred_map_0, xgb_rf_pred_map_1])
    
    print(nickname_0, " Xgb Proba: ", xgb_res_0)
    print(nickname_1, " Xgb Proba: ", xgb_res_1)
    print(nickname_0, " Classifier: ", rf_res_0)
    print(nickname_1, " Classifier: ", rf_res_1)

# %%
predict(season, "Knicks", "Pacers")
# Out:
# Knicks  Xgb Proba:  [0.97189504]
# Pacers  Xgb Proba:  [0.94385433]
# Knicks  Classifier:  [1]
# Pacers  Classifier:  [1]

# %%
predict(season, "Nuggets", "Timberwolves")
# Out:
# Nuggets  Xgb Proba:  [0.62386256]
# Timberwolves  Xgb Proba:  [0.65408653]
# Nuggets  Classifier:  [1]
# Timberwolves  Classifier:  [1]

# %%
#########################################################
# get probability of games hitting in set ###############
def get_proba_from_set(nickname_set, nickname_to_proba_map):
    proba = 1
    for nickname in nickname_set:
        proba = proba * nickname_to_proba_map.get(nickname)
    return proba

# Get combination of games that have 
# highest probablity of winning
def sort_probable_games(games_pred):
    confident_games = []
    for game in games_pred:
        nickname_0 = list(game[0].keys())[0]
        nickname_1 = list(game[1].keys())[0]
        xgb_0 = game[0].get(nickname_0).get("xgb_proba")[0]
        xgb_1 = game[1].get(nickname_1).get("xgb_proba")[0]
        rf_clf_0 = game[0].get(nickname_0).get("rf_clf")[0]
        rf_clf_1 = game[1].get(nickname_1).get("rf_clf")[0]

        spread = abs(xgb_0 - xgb_1)
        if xgb_0 > xgb_1 and rf_clf_0 == 1 and rf_clf_1 == 0 and spread > .15:
            confident_games.append({ "proba": xgb_0, "spread": spread, "nickname": nickname_0})
        if xgb_0 < xgb_1 and rf_clf_0 == 0 and rf_clf_1 == 1 and spread > .15:
            confident_games.append({ "proba": xgb_1, "spread": spread, "nickname": nickname_1 })

    confident_games = list(filter(lambda game: game.get("proba") > .5, confident_games))
    
    nickname_to_proba_map = {}
    parlays_set = set()
    for game in confident_games:
        nickname_to_proba_map.update({ game.get("nickname"): game.get("proba")})    
        parlays_set.add(frozenset([game.get("nickname")]))
        
    for game in confident_games:
        for parlay in parlays_set.copy():            
            if game.get("nickname") not in parlay and game.get("proba") * get_proba_from_set(parlay, nickname_to_proba_map) > .5:
                parlays_set.add(parlay.union([game.get("nickname")]))
    
    
    parlay_probas = {}
    for parlay in parlays_set:
        parlay_probas.update({ parlay: get_proba_from_set(parlay, nickname_to_proba_map)})
    return nickname_to_proba_map, dict(sorted(parlay_probas.items(), key=lambda item: item[1], reverse=True))
#########################################################

# %%
proba_map, parlay_probas = sort_probable_games(games_pred) 
pprint(proba_map)
print()
pprint(parlay_probas)
# Out:
# {}
#
# {}

# %%
# knicks, lakers, Rockets, suns
