# %%
# Written by Sebastian Matiz
import pandas as pd
import requests
import json
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, roc_auc_score
from bs4 import BeautifulSoup
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
from pprint import pprint

cols_to_drop_for_player_stats = [
    "comment",
    "player.firstname",
    "player.lastname",
    "player.id",
    "team.id",
    "team.nickname",
    "team.code",
    "team.name",
    "team.logo",
    "game.id",
    "pos"
]

cols_to_drop_for_game_stats = [
    "league",
    "season",
    "stage",
    "officials",
    "timesTied",
    "leadChanges",
    "nugget",
    "date.start",
    "date.end",
    "date.duration",
    "status.clock",
    "status.halftime",
    "status.short",
    "status.long",
    "periods.current",
    "periods.total",
    "periods.endOfPeriod",
    "arena.name",
    "arena.city",
    "arena.state",
    "arena.country",
    "teams.visitors.id",
    "teams.visitors.name",
    "teams.visitors.nickname",
    "teams.visitors.code",
    "teams.visitors.logo",
    "teams.home.id",
    "teams.home.name",
    "teams.home.nickname",
    "teams.home.code",
    "teams.home.logo",
    "scores.visitors.points",
    "scores.visitors.win",
    "scores.visitors.loss",
    "scores.visitors.series.win",
    "scores.visitors.series.loss",
    "scores.visitors.linescore",
    "scores.home.points",
    "scores.home.win",
    "scores.home.loss",
    "scores.home.series.win",
    "scores.home.series.loss",
    "scores.home.linescore"
]

# %%
# rapidApi headers
headers = {
    "X-RapidAPI-Key": "REDACTED_RAPIDAPI_KEY",
    "X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

# %%
#########################################################
# games by game ids #####################################
def get_team_nicknames_by_id():
    # team code by id
    url = "https://api-nba-v1.p.rapidapi.com/teams"
    response = requests.get(url, headers=headers).json()["response"]
    df = pd.DataFrame(response)
    df = df.loc[(df["nbaFranchise"] == True) & (df["allStar"] == False)]
    
    team_nickname_to_id_map = {}
    
    for index, row in df.iterrows():
        team_nickname_to_id_map.update({row["nickname"]: row["id"]})
    return team_nickname_to_id_map
#########################################################

# %%
team_nickname_to_id_map = get_team_nicknames_by_id()

# %%
#########################################################
# games by game ids #####################################
def get_games_by_game_ids(season, team_id):
    url = "https://api-nba-v1.p.rapidapi.com/games"
    querystring = {"season":season,"team":team_id}

    response = requests.get(url, headers=headers, params=querystring)
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
    df = df.loc[(df["status.long"] == "Finished")]
    df = df.sort_values(by=["date.start"])
    
    # adding win col to df
    df["win"] = ""

    df.loc[
        ((df["scores.home.points"] > df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.home.id"])) |
        ((df["scores.home.points"] < df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.visitors.id"])),
        "win"
    ] = 1

    df.loc[
        ((df["scores.home.points"] < df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.home.id"])) |
        ((df["scores.home.points"] > df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.visitors.id"])),
        "win"
    ] = 0

    df["points"] = np.where(
        df["teams.home.id"] == team_id, 
        df["scores.home.points"], 
        df["scores.visitors.points"]
    )
    df["opponent.points"] = np.where(
        df["teams.home.id"] != team_id, 
        df["scores.home.points"], 
        df["scores.visitors.points"]
    )
    df["opponent.team_id"] = np.where(
        df["teams.home.id"] != team_id, 
        df["teams.home.id"], 
        df["teams.visitors.id"]
    )

    # adding home col to df
    df["home"] = ""
    
    df.loc[(int(team_id) == df["teams.home.id"]), "home"] = 1
        
    df.loc[(int(team_id) == df["teams.visitors.id"]), "home"] = 0    
    
    return drop_cols(df, cols_to_drop_for_game_stats)
#########################################################

# %%
#########################################################
# drop all cols from a df ###############################
def drop_cols(df, cols):
    for col in cols:
        df = df.drop(col, axis=1)
    return df
#########################################################

# %%
#########################################################
# get top n player stats by game by #####################
def get_top_players_per_game_df(n, team_id, game_id):    
    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"

    querystring = {"game": game_id }
    
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )

    df_opponent = df.loc[df["team.id"] != team_id]
    df = df.loc[df["team.id"] == team_id]
    
    df_opponent = drop_cols(df_opponent, cols_to_drop_for_player_stats)
    df = drop_cols(df, cols_to_drop_for_player_stats)
    
    df_opponent = zero_non_numeric_values(df_opponent)
    df = zero_non_numeric_values(df)
    
    df_opponent = df_opponent.add_prefix("opponent.")

    return df_opponent.nlargest(n, "opponent.plusMinus"), df.nlargest(n, "plusMinus")
#########################################################

# %%
#########################################################
# flatten data frames ###################################
def flatten_df(df):
    # Flatten the DataFrame
    flattened_data = {}
    for col in df.columns:
        for row in range(df.shape[0]):
            new_col_name = f"{col}{row}"
            flattened_data[new_col_name] = df[col].iloc[row]

    # Convert to DataFrame
    return pd.DataFrame([flattened_data])
#########################################################

# %%
#########################################################
# per game, get top 5 players by plusMinus metric #######
def get_top_five_players_per_game(team_id, game_ids): 
    top_5_players_on_team_per_game = {}
    for game_id in game_ids:
        # transform player_stats_df
        opponent_top_five_player_stats, friendly_top_five_player_stats = get_top_players_per_game_df(5, team_id, game_id)
        opponent_top_five_player_stats = flatten_df(opponent_top_five_player_stats)
        friendly_top_five_player_stats = flatten_df(friendly_top_five_player_stats)
        top_five_players_stats = pd.concat(
            [opponent_top_five_player_stats, friendly_top_five_player_stats], 
            axis=1
        )
        ###########################
        top_5_players_on_team_per_game[game_id] = top_five_players_stats          
    return top_5_players_on_team_per_game
#########################################################

# %%
#########################################################
# get win prc, and last 10 win prc ######################
def get_win_prc(game_df):
    total_win_prc = []
    last_ten_win_prc = []
    last_ten_games_win_loss = []
    total_games_played = []
    last_ten_win_count = 0
    total_win_count = 0
    total_game_count = 0
    
    for index, row in game_df.iterrows():
        total_game_count += 1
        last_ten_games_win_loss.append(row["win"])
        
        if row["win"]:
            total_win_count += 1
            last_ten_win_count += 1
            
        total_win_prc.append(total_win_count/total_game_count)
               
        if total_game_count >= 10:
            if last_ten_games_win_loss[0]:
                last_ten_win_count -= 1
            last_ten_games_win_loss.pop(0)
            last_ten_win_prc.append(last_ten_win_count/10)
        else:
            last_ten_win_prc.append(last_ten_win_count/total_game_count)
        
        total_games_played.append(total_game_count)            
    return last_ten_win_prc, total_win_prc, total_games_played
#########################################################

# %%
#########################################################
# combine player stats and games features ###############
def combine_player_stats_and_games_data(games_df, player_stats_per_game):
    feature_map = []
    feature_map_cols_header = []
    for index, row in games_df.iterrows():
        game_id = row["id"]
        game_df = pd.DataFrame(row).transpose()
        players_stats_df = player_stats_per_game.get(game_id)
        if len(feature_map_cols_header) < 1:
            feature_map_cols_header = list(game_df) + list(players_stats_df)

        game_data = np.array(game_df.iloc[0])
        player_stats_data = np.array(players_stats_df.iloc[0])
        feature_map_data_row = np.concatenate((game_data, player_stats_data))
        feature_map.append(feature_map_data_row)
    return pd.DataFrame(feature_map, columns=feature_map_cols_header)
#########################################################

# %%
#########################################################
def get_feature_map_and_y(season, team_id):
    games_df = get_games_by_game_ids(season, team_id) 
    
    players_stats_per_games = get_top_five_players_per_game(
        team_id, 
        games_df["id"].array
    )
    
    last_ten_win_prc, total_win_prc, total_games_played = get_win_prc(games_df)
    games_df = games_df.assign(last_ten_w_prc=last_ten_win_prc)
    games_df = games_df.assign(w_prc=total_win_prc)
    games_df = games_df.assign(games_played=total_games_played)
    
    df = combine_player_stats_and_games_data(games_df, players_stats_per_games)
    df = zero_non_numeric_values(df)
    x = drop_cols(df, ["win", "id"])
    y = df["win"]
    return x, y 
#########################################################

# %%
#########################################################
normalization_func_by_team_nickname = {}
def get_xgb_model_and_rf_classifier_model(team_nickname, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

    # normalize feature map
    scaler = MinMaxScaler()
    x_train_normalized = pd.DataFrame(scaler.fit_transform(x_train), columns=x.columns)
    x_test_normalized = pd.DataFrame(scaler.transform(x_test), columns=x.columns)
    normalization_func_by_team_nickname.update({team_nickname: [scaler]})

    # XGB ###################################################
    dtrain = xgb.DMatrix(x_train_normalized, label=y_train)
    dtest = xgb.DMatrix(x_test_normalized, label=y_test)

    params = {
        "objective": "binary:logistic",
        "max_depth": 5,
        "eta": 0.05,
        "eval_metric": "logloss",
    }

    num_boost_round = 999

    bst = xgb.train(
        params, 
        dtrain, 
        num_boost_round, 
        evals=[(dtest, "Test")], 
        early_stopping_rounds=10
    )
    
    # Predict probabilities on the test set
    y_pred_proba = bst.predict(dtest)
    
    # Calculate ROC AUC
    auc_score = roc_auc_score(y_test, y_pred_proba)
    print(f"ROC AUC Score: {auc_score}")
    #########################################################

    # Classifier ############################################
    # training random forest classifier 
    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

    # Train the model on the training set
    rf_classifier.fit(x_train_normalized, y_train)
    
    # Make predictions on the test set
    rf_classifier_predictions = rf_classifier.predict(x_test_normalized)

    # Evaluate the model
    rf_classifier_accuracy = accuracy_score(y_test, rf_classifier_predictions)
    print(f"Accuracy: {rf_classifier_accuracy:.2f}")
    #########################################################
    
    return bst, rf_classifier
#########################################################

# %%
#########################################################
def zero_non_numeric_values(df):
    for col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0)
    return df
#########################################################

# %%
#########################################################
xgb_rf_model_and_data_map = {}
def get_data_and_xgb_rf_models(season, team_nickname):
    team_id = team_nickname_to_id_map.get(team_nickname)
    x, y = get_feature_map_and_y(season, team_id)
   
    xgb, classifier = get_xgb_model_and_rf_classifier_model(team_nickname, x, y)
    xgb_rf_model_and_data_map.update({team_nickname: [xgb, classifier, x, y]})
#########################################################

# %%
#########################################################
def get_player_season_stats_avgs(season, player_id):
    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"
    querystring = {"id":player_id,"season":season}
    
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
    
    df = drop_cols(df, cols_to_drop_for_player_stats)
    df = zero_non_numeric_values(df)

    played_games = df[df["min"] > 0]    
    return played_games.mean()
#########################################################

# %%
#########################################################
def get_players_season_stats_avgs(season, player_ids):
    player_stats_avgs = []
    for i in player_ids:
        player_stats_avgs.append(get_player_season_stats_avgs(season, i))
    
    df = pd.DataFrame(player_stats_avgs)
    return df.sort_values(by=["plusMinus"], ascending=False)
#########################################################

# %%
#########################################################
def get_player_lineups_for_tn():
    url = "https://www.rotowire.com/basketball/nba-lineups.php"
    response = requests.get(url, verify=False)
    soup = BeautifulSoup(response.text, "html.parser")
    players_by_team = {}
    button_divs = soup.find_all("button", class_="see-court-on-off")

    for div in button_divs:
        nickname = div["data-nickname"]
        players_by_team.update({ nickname: [] })
        player_ids = div["data-lineup"].split(",")[:5]
        for player_id in player_ids:
            player_divs = soup.find_all("li", class_="lineup__player")
            for player_div in player_divs:
                a_tags = player_div.find_all("a", href=lambda href: href and player_id in href)
                for a_tag in a_tags:
                    if a_tag["title"] not in players_by_team.get(nickname):
                        players_by_team[nickname].append(a_tag["title"])

    return players_by_team
#########################################################

# %%
#########################################################
def get_players_by_team_and_season(team_id, season):
    url = "https://api-nba-v1.p.rapidapi.com/players"
    querystring = {"team": team_id,"season":season}
    return pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
#########################################################

# %%
#########################################################
def get_team_latest_stats(team_id, season):
    url = "https://api-nba-v1.p.rapidapi.com/teams/statistics"
    querystring = {"id": team_id,"season": season}
    return pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
#########################################################

# %%
#########################################################
def make_alphanum(str):
    return "".join(char.lower() for char in str if char.isalnum())
#########################################################

# %%
#########################################################
def filter_list_not_contain_substrs(list, substrs):
    res = []
    for i in substrs:
        for j in list:
            if make_alphanum(i) in make_alphanum(j):
                res.append(j)
                
    # bug in rapid api, they have Jamie Jaquez Jr. listed as Jamie Jr. Jaquez
    if 'Jaime Jaquez' in substrs:
        res.append('Jamie Jr. Jaquez')
        
    return res
#########################################################

# %%
#########################################################
def get_prediction_feature_map(
    training_data_tail,
    season,
    team_nickname,
    o_team_nickname,
    home
):   
    team_id = team_nickname_to_id_map.get(team_nickname)
    o_team_id = team_nickname_to_id_map.get(o_team_nickname)
    
    # getting player attributes
    df = get_players_by_team_and_season(team_id, season)  
    o_df = get_players_by_team_and_season(o_team_id, season)

    concat_names = df["firstname"] + " " + df["lastname"]
    o_concat_names = o_df["firstname"] + " " + o_df["lastname"]

    name_list = players_name_map.get(team_nickname)    
    o_name_list = players_name_map.get(o_team_nickname)

    filtered_names = filter_list_not_contain_substrs(concat_names, name_list)
    o_filtered_names = filter_list_not_contain_substrs(o_concat_names, o_name_list)
    
    df_players = df[concat_names.isin(set(filtered_names))]
    o_df_players = o_df[o_concat_names.isin(set(o_filtered_names))]
    
    team_latest_stats = get_team_latest_stats(team_id, season)
    o_team_latest_stats = get_team_latest_stats(o_team_id, season)

    team_avg_ppg = team_latest_stats.iloc[0]["points"] / team_latest_stats.iloc[0]["games"]
    o_team_avg_ppg = o_team_latest_stats.iloc[0]["points"] / o_team_latest_stats.iloc[0]["games"]
    
    player_ids = np.array(df_players["id"])
    o_player_ids = np.array(o_df_players["id"])
    
    players_stats_avgs = get_players_season_stats_avgs(season, player_ids)
    o_players_stats_avgs = get_players_season_stats_avgs(season, o_player_ids)
    o_players_stats_avgs = o_players_stats_avgs.add_prefix("opponent.")

    players_stats_avgs = flatten_df(players_stats_avgs)
    o_players_stats_avgs = flatten_df(o_players_stats_avgs)

    players_stats = pd.concat(
        [o_players_stats_avgs, players_stats_avgs], 
        axis=1
    )
    
    games_col_headers = [
        "points",
        "opponent.points", 
        "opponent.team_id",
        "home", 
        "last_ten_w_prc", 
        "w_prc", 
        "games_played"
    ]
    
    games_data = [
        team_avg_ppg, 
        o_team_avg_ppg, 
        o_team_id,
        home, 
        training_data_tail["last_ten_w_prc"].iloc[0], 
        training_data_tail["w_prc"].iloc[0],
        training_data_tail["games_played"].iloc[0] + 1
    ]
        
    feature_map_col_headers = games_col_headers + list(players_stats)
    feature_map_data_row = np.concatenate((games_data, players_stats.iloc[0]))
    return pd.DataFrame([feature_map_data_row], columns=feature_map_col_headers)    
#########################################################

# %%
players_name_map = get_player_lineups_for_tn()
# Out:
# /opt/homebrew/lib/python3.9/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.rotowire.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
# Get models for teams ##################################
season = "2023"
# print("76ers")
# get_data_and_xgb_rf_models(season, "76ers")
# print()

print("Knicks")
get_data_and_xgb_rf_models(season, "Knicks")
print()

print("Pacers")
get_data_and_xgb_rf_models(season, "Pacers")
print()

# print("Thunder")
# get_data_and_xgb_rf_models(season, "Thunder")
# print()

# print("Wizards")
# get_data_and_xgb_rf_models(season, "Wizards")
# print()

# print("Grizzlies")
# get_data_and_xgb_rf_models(season, "Grizzlies")
# print()

# print("Rockets")
# get_data_and_xgb_rf_models(season, "Rockets")
# print()

# print("Spurs")
# get_data_and_xgb_rf_models(season, "Spurs")
# print()

# print("Celtics")
# get_data_and_xgb_rf_models(season, "Celtics")
# print()

# print("Jazz")
# get_data_and_xgb_rf_models(season, "Jazz")
# print()

print("Timberwolves")
get_data_and_xgb_rf_models(season, "Timberwolves")
print()

# print("Clippers")
# get_data_and_xgb_rf_models(season, "Clippers")
# print()

# print("Bucks")
# get_data_and_xgb_rf_models(season, "Bucks")
# print()

# print("Kings")
# get_data_and_xgb_rf_models(season, "Kings")
# print()

# print("Raptors")
# get_data_and_xgb_rf_models(season, "Raptors")
# print()
#########################################################
# Out:
# Knicks
# [0]	Test-logloss:0.65569
# [1]	Test-logloss:0.64042
# [2]	Test-logloss:0.62708
# [3]	Test-logloss:0.61544
# [4]	Test-logloss:0.58525
# [5]	Test-logloss:0.57616
# [6]	Test-logloss:0.55003
# [7]	Test-logloss:0.54266
# [8]	Test-logloss:0.51986
# [9]	Test-logloss:0.49738
# [10]	Test-logloss:0.47854
# [11]	Test-logloss:0.47382
# [12]	Test-logloss:0.45480
# [13]	Test-logloss:0.43662
# [14]	Test-logloss:0.42206
# [15]	Test-logloss:0.40597
# [16]	Test-logloss:0.40322
# [17]	Test-logloss:0.38928
# [18]	Test-logloss:0.37519
# [19]	Test-logloss:0.37337
# [20]	Test-logloss:0.36037
# [21]	Test-logloss:0.34771
# [22]	Test-logloss:0.33858
# [23]	Test-logloss:0.33770
# [24]	Test-logloss:0.32655
# [25]	Test-logloss:0.31785
# [26]	Test-logloss:0.31747
# [27]	Test-logloss:0.30743
# [28]	Test-logloss:0.30738
# [29]	Test-logloss:0.29799
# [30]	Test-logloss:0.29822
# [31]	Test-logloss:0.28943
# [32]	Test-logloss:0.28275
# [33]	Test-logloss:0.27468
# [34]	Test-logloss:0.27522
# [35]	Test-logloss:0.26762
# [36]	Test-logloss:0.26836
# [37]	Test-logloss:0.26317
# [38]	Test-logloss:0.25825
# [39]	Test-logloss:0.25913
# [40]	Test-logloss:0.26018
# [41]	Test-logloss:0.25569
# [42]	Test-logloss:0.25048
# [43]	Test-logloss:0.24554
# [44]	Test-logloss:0.24086
# [45]	Test-logloss:0.24213
# [46]	Test-logloss:0.23539
# [47]	Test-logloss:0.23003
# [48]	Test-logloss:0.22377
# [49]	Test-logloss:0.22072
# [50]	Test-logloss:0.21494
# [51]	Test-logloss:0.21621
# [52]	Test-logloss:0.21065
# [53]	Test-logloss:0.20647
# [54]	Test-logloss:0.20504
# [55]	Test-logloss:0.20514
# [56]	Test-logloss:0.20388
# [57]	Test-logloss:0.20409
# [58]	Test-logloss:0.19923
# [59]	Test-logloss:0.19952
# [60]	Test-logloss:0.19537
# [61]	Test-logloss:0.19239
# [62]	Test-logloss:0.19273
# [63]	Test-logloss:0.19069
# [64]	Test-logloss:0.18650
# [65]	Test-logloss:0.18542
# [66]	Test-logloss:0.18528
# [67]	Test-logloss:0.18144
# [68]	Test-logloss:0.17969
# [69]	Test-logloss:0.17960
# [70]	Test-logloss:0.17777
# [71]	Test-logloss:0.17586
# [72]	Test-logloss:0.17237
# [73]	Test-logloss:0.17233
# [74]	Test-logloss:0.17096
# [75]	Test-logloss:0.16771
# [76]	Test-logloss:0.16671
# [77]	Test-logloss:0.16589
# [78]	Test-logloss:0.16286
# [79]	Test-logloss:0.16287
# [80]	Test-logloss:0.16134
# [81]	Test-logloss:0.16032
# [82]	Test-logloss:0.15804
# [83]	Test-logloss:0.15750
# [84]	Test-logloss:0.15611
# [85]	Test-logloss:0.15531
# [86]	Test-logloss:0.15321
# [87]	Test-logloss:0.15179
# [88]	Test-logloss:0.15114
# [89]	Test-logloss:0.14990
# [90]	Test-logloss:0.14797
# [91]	Test-logloss:0.14739
# [92]	Test-logloss:0.14625
# [93]	Test-logloss:0.14499
# [94]	Test-logloss:0.14445
# [95]	Test-logloss:0.14290
# [96]	Test-logloss:0.14185
# [97]	Test-logloss:0.14328
# [98]	Test-logloss:0.14214
# [99]	Test-logloss:0.14066
# [100]	Test-logloss:0.14206
# [101]	Test-logloss:0.14110
# [102]	Test-logloss:0.13969
# [103]	Test-logloss:0.13865
# [104]	Test-logloss:0.14002
# [105]	Test-logloss:0.13912
# [106]	Test-logloss:0.14048
# [107]	Test-logloss:0.13962
# [108]	Test-logloss:0.13859
# [109]	Test-logloss:0.13736
# [110]	Test-logloss:0.13644
# [111]	Test-logloss:0.13776
# [112]	Test-logloss:0.13697
# [113]	Test-logloss:0.13622
# [114]	Test-logloss:0.13752
# [115]	Test-logloss:0.13636
# [116]	Test-logloss:0.13764
# [117]	Test-logloss:0.13672
# [118]	Test-logloss:0.13597
# [119]	Test-logloss:0.13510
# [120]	Test-logloss:0.13439
# [121]	Test-logloss:0.13371
# [122]	Test-logloss:0.13307
# [123]	Test-logloss:0.13250
# [124]	Test-logloss:0.13195
# [125]	Test-logloss:0.13199
# [126]	Test-logloss:0.13199
# [127]	Test-logloss:0.13199
# [128]	Test-logloss:0.13198
# [129]	Test-logloss:0.13198
# [130]	Test-logloss:0.13198
# [131]	Test-logloss:0.13198
# [132]	Test-logloss:0.13198
# [133]	Test-logloss:0.13198
# ROC AUC Score: 1.0
# Accuracy: 0.95
#
# Pacers
# [0]	Test-logloss:0.64059
# [1]	Test-logloss:0.60781
# [2]	Test-logloss:0.57786
# [3]	Test-logloss:0.55042
# [4]	Test-logloss:0.52519
# [5]	Test-logloss:0.50196
# [6]	Test-logloss:0.48051
# [7]	Test-logloss:0.46067
# [8]	Test-logloss:0.44229
# [9]	Test-logloss:0.42523
# [10]	Test-logloss:0.40806
# [11]	Test-logloss:0.39324
# [12]	Test-logloss:0.37818
# [13]	Test-logloss:0.36524
# [14]	Test-logloss:0.35196
# [15]	Test-logloss:0.33951
# [16]	Test-logloss:0.32885
# [17]	Test-logloss:0.31781
# [18]	Test-logloss:0.30842
# [19]	Test-logloss:0.29893
# [20]	Test-logloss:0.28622
# [21]	Test-logloss:0.27725
# [22]	Test-logloss:0.26574
# [23]	Test-logloss:0.25773
# [24]	Test-logloss:0.24967
# [25]	Test-logloss:0.24326
# [26]	Test-logloss:0.23362
# [27]	Test-logloss:0.22708
# [28]	Test-logloss:0.21829
# [29]	Test-logloss:0.21313
# [30]	Test-logloss:0.20509
# [31]	Test-logloss:0.19975
# [32]	Test-logloss:0.19239
# [33]	Test-logloss:0.18757
# [34]	Test-logloss:0.18126
# [35]	Test-logloss:0.17550
# [36]	Test-logloss:0.16927
# [37]	Test-logloss:0.16529
# [38]	Test-logloss:0.16130
# [39]	Test-logloss:0.15641
# [40]	Test-logloss:0.15172
# [41]	Test-logloss:0.14837
# [42]	Test-logloss:0.14403
# [43]	Test-logloss:0.14080
# [44]	Test-logloss:0.13681
# [45]	Test-logloss:0.13297
# [46]	Test-logloss:0.12931
# [47]	Test-logloss:0.12659
# [48]	Test-logloss:0.12323
# [49]	Test-logloss:0.11950
# [50]	Test-logloss:0.11645
# [51]	Test-logloss:0.11327
# [52]	Test-logloss:0.11047
# [53]	Test-logloss:0.10752
# [54]	Test-logloss:0.10467
# [55]	Test-logloss:0.10313
# [56]	Test-logloss:0.10025
# [57]	Test-logloss:0.09869
# [58]	Test-logloss:0.09621
# [59]	Test-logloss:0.09480
# [60]	Test-logloss:0.09312
# [61]	Test-logloss:0.09097
# [62]	Test-logloss:0.08887
# [63]	Test-logloss:0.08676
# [64]	Test-logloss:0.08475
# [65]	Test-logloss:0.08281
# [66]	Test-logloss:0.08104
# [67]	Test-logloss:0.08003
# [68]	Test-logloss:0.07908
# [69]	Test-logloss:0.07746
# [70]	Test-logloss:0.07628
# [71]	Test-logloss:0.07494
# [72]	Test-logloss:0.07386
# [73]	Test-logloss:0.07265
# [74]	Test-logloss:0.07187
# [75]	Test-logloss:0.07071
# [76]	Test-logloss:0.07020
# [77]	Test-logloss:0.06894
# [78]	Test-logloss:0.06848
# [79]	Test-logloss:0.06726
# [80]	Test-logloss:0.06638
# [81]	Test-logloss:0.06523
# [82]	Test-logloss:0.06454
# [83]	Test-logloss:0.06346
# [84]	Test-logloss:0.06282
# [85]	Test-logloss:0.06178
# [86]	Test-logloss:0.06164
# [87]	Test-logloss:0.06067
# [88]	Test-logloss:0.06000
# [89]	Test-logloss:0.05908
# [90]	Test-logloss:0.05818
# [91]	Test-logloss:0.05791
# [92]	Test-logloss:0.05731
# [93]	Test-logloss:0.05647
# [94]	Test-logloss:0.05565
# [95]	Test-logloss:0.05541
# [96]	Test-logloss:0.05566
# [97]	Test-logloss:0.05512
# [98]	Test-logloss:0.05435
# [99]	Test-logloss:0.05415
# [100]	Test-logloss:0.05440
# [101]	Test-logloss:0.05421
# [102]	Test-logloss:0.05446
# [103]	Test-logloss:0.05429
# [104]	Test-logloss:0.05380
# [105]	Test-logloss:0.05406
# [106]	Test-logloss:0.05391
# [107]	Test-logloss:0.05345
# [108]	Test-logloss:0.05318
# [109]	Test-logloss:0.05297
# [110]	Test-logloss:0.05253
# [111]	Test-logloss:0.05229
# [112]	Test-logloss:0.05187
# [113]	Test-logloss:0.05168
# [114]	Test-logloss:0.05128
# [115]	Test-logloss:0.05116
# [116]	Test-logloss:0.05099
# [117]	Test-logloss:0.05090
# [118]	Test-logloss:0.05082
# [119]	Test-logloss:0.05065
# [120]	Test-logloss:0.05049
# [121]	Test-logloss:0.05035
# [122]	Test-logloss:0.05022
# [123]	Test-logloss:0.05010
# [124]	Test-logloss:0.04999
# [125]	Test-logloss:0.04989
# [126]	Test-logloss:0.04987
# [127]	Test-logloss:0.04985
# [128]	Test-logloss:0.04986
# [129]	Test-logloss:0.04986
# [130]	Test-logloss:0.04987
# [131]	Test-logloss:0.04987
# [132]	Test-logloss:0.04988
# [133]	Test-logloss:0.04988
# [134]	Test-logloss:0.04989
# [135]	Test-logloss:0.04989
# [136]	Test-logloss:0.04989
# ROC AUC Score: 1.0
# Accuracy: 0.95
#
# Timberwolves
# [0]	Test-logloss:0.69084
# [1]	Test-logloss:0.66073
# [2]	Test-logloss:0.63742
# [3]	Test-logloss:0.61670
# [4]	Test-logloss:0.59820
# [5]	Test-logloss:0.58164
# [6]	Test-logloss:0.56265
# [7]	Test-logloss:0.54038
# [8]	Test-logloss:0.51926
# [9]	Test-logloss:0.49929
# [10]	Test-logloss:0.48123
# [11]	Test-logloss:0.47333
# [12]	Test-logloss:0.45738
# [13]	Test-logloss:0.45166
# [14]	Test-logloss:0.43776
# [15]	Test-logloss:0.42424
# [16]	Test-logloss:0.41614
# [17]	Test-logloss:0.40416
# [18]	Test-logloss:0.39798
# [19]	Test-logloss:0.39209
# [20]	Test-logloss:0.38174
# [21]	Test-logloss:0.37672
# [22]	Test-logloss:0.36733
# [23]	Test-logloss:0.36298
# [24]	Test-logloss:0.35456
# [25]	Test-logloss:0.35063
# [26]	Test-logloss:0.34297
# [27]	Test-logloss:0.33714
# [28]	Test-logloss:0.33021
# [29]	Test-logloss:0.31896
# [30]	Test-logloss:0.30837
# [31]	Test-logloss:0.30559
# [32]	Test-logloss:0.29981
# [33]	Test-logloss:0.29004
# [34]	Test-logloss:0.28742
# [35]	Test-logloss:0.27997
# [36]	Test-logloss:0.27514
# [37]	Test-logloss:0.27034
# [38]	Test-logloss:0.26459
# [39]	Test-logloss:0.26124
# [40]	Test-logloss:0.25716
# [41]	Test-logloss:0.24943
# [42]	Test-logloss:0.24579
# [43]	Test-logloss:0.24403
# [44]	Test-logloss:0.24195
# [45]	Test-logloss:0.23685
# [46]	Test-logloss:0.23545
# [47]	Test-logloss:0.22878
# [48]	Test-logloss:0.22500
# [49]	Test-logloss:0.22228
# [50]	Test-logloss:0.21768
# [51]	Test-logloss:0.21527
# [52]	Test-logloss:0.21426
# [53]	Test-logloss:0.21301
# [54]	Test-logloss:0.20958
# [55]	Test-logloss:0.20861
# [56]	Test-logloss:0.20521
# [57]	Test-logloss:0.20410
# [58]	Test-logloss:0.20245
# [59]	Test-logloss:0.19899
# [60]	Test-logloss:0.19836
# [61]	Test-logloss:0.19654
# [62]	Test-logloss:0.19387
# [63]	Test-logloss:0.19257
# [64]	Test-logloss:0.19095
# [65]	Test-logloss:0.18925
# [66]	Test-logloss:0.18787
# [67]	Test-logloss:0.18726
# [68]	Test-logloss:0.18561
# [69]	Test-logloss:0.18438
# [70]	Test-logloss:0.18416
# [71]	Test-logloss:0.18199
# [72]	Test-logloss:0.18040
# [73]	Test-logloss:0.18041
# [74]	Test-logloss:0.17904
# [75]	Test-logloss:0.17616
# [76]	Test-logloss:0.17423
# [77]	Test-logloss:0.17344
# [78]	Test-logloss:0.17076
# [79]	Test-logloss:0.16977
# [80]	Test-logloss:0.16841
# [81]	Test-logloss:0.16855
# [82]	Test-logloss:0.16567
# [83]	Test-logloss:0.16373
# [84]	Test-logloss:0.16391
# [85]	Test-logloss:0.16116
# [86]	Test-logloss:0.15993
# [87]	Test-logloss:0.15911
# [88]	Test-logloss:0.15736
# [89]	Test-logloss:0.15667
# [90]	Test-logloss:0.15673
# [91]	Test-logloss:0.15422
# [92]	Test-logloss:0.15258
# [93]	Test-logloss:0.15188
# [94]	Test-logloss:0.15078
# [95]	Test-logloss:0.15193
# [96]	Test-logloss:0.15217
# [97]	Test-logloss:0.15130
# [98]	Test-logloss:0.15246
# [99]	Test-logloss:0.15143
# [100]	Test-logloss:0.15156
# [101]	Test-logloss:0.15075
# [102]	Test-logloss:0.14980
# [103]	Test-logloss:0.15095
# [104]	Test-logloss:0.15112
# [105]	Test-logloss:0.14907
# [106]	Test-logloss:0.14814
# [107]	Test-logloss:0.14929
# [108]	Test-logloss:0.14749
# [109]	Test-logloss:0.14676
# [110]	Test-logloss:0.14789
# [111]	Test-logloss:0.14808
# [112]	Test-logloss:0.14723
# [113]	Test-logloss:0.14654
# [114]	Test-logloss:0.14767
# [115]	Test-logloss:0.14789
# [116]	Test-logloss:0.14724
# [117]	Test-logloss:0.14837
# [118]	Test-logloss:0.14861
# [119]	Test-logloss:0.14688
# [120]	Test-logloss:0.14800
# [121]	Test-logloss:0.14825
# [122]	Test-logloss:0.14767
# ROC AUC Score: 1.0
# Accuracy: 0.89

# %%
# Get models for teams ##################################
# print("Pistons")
# get_data_and_xgb_rf_models(season, "Pistons")
# print()

# print("Nets")
# get_data_and_xgb_rf_models(season, "Nets")
# print()

# print("Magic")
# get_data_and_xgb_rf_models(season, "Magic")
# print()

print("Nuggets")
get_data_and_xgb_rf_models(season, "Nuggets")
print()

# print("Heat")
# get_data_and_xgb_rf_models(season, "Heat")
# print()

# print("Bulls")
# get_data_and_xgb_rf_models(season, "Bulls")
# print()

# print("Hornets")
# get_data_and_xgb_rf_models(season, "Hornets")
# print()

# print("Cavaliers")
# get_data_and_xgb_rf_models(season, "Cavaliers")
# print()

# print("Pelicans")
# get_data_and_xgb_rf_models(season, "Pelicans")
# print()

# print("Warriors")
# get_data_and_xgb_rf_models(season, "Warriors")
# print()

# print("Suns")
# get_data_and_xgb_rf_models(season, "Suns")
# print()

# print("Mavericks")
# get_data_and_xgb_rf_models(season, "Mavericks")
# print()

# print("Lakers")
# get_data_and_xgb_rf_models(season, "Lakers")
# print()

# print("Hawks")
# get_data_and_xgb_rf_models(season, "Hawks")
# print()

# print("Trail Blazers")
# get_data_and_xgb_rf_models(season, "Trail Blazers")
# print()
#########################################################
# Out:
# Nuggets
# [0]	Test-logloss:0.55351
# [1]	Test-logloss:0.52765
# [2]	Test-logloss:0.50670
# [3]	Test-logloss:0.48782
# [4]	Test-logloss:0.47076
# [5]	Test-logloss:0.45687
# [6]	Test-logloss:0.44263
# [7]	Test-logloss:0.42064
# [8]	Test-logloss:0.40911
# [9]	Test-logloss:0.39152
# [10]	Test-logloss:0.37391
# [11]	Test-logloss:0.36428
# [12]	Test-logloss:0.34862
# [13]	Test-logloss:0.33512
# [14]	Test-logloss:0.32734
# [15]	Test-logloss:0.31518
# [16]	Test-logloss:0.30380
# [17]	Test-logloss:0.29835
# [18]	Test-logloss:0.28860
# [19]	Test-logloss:0.27769
# [20]	Test-logloss:0.26809
# [21]	Test-logloss:0.25654
# [22]	Test-logloss:0.24633
# [23]	Test-logloss:0.24008
# [24]	Test-logloss:0.23219
# [25]	Test-logloss:0.22625
# [26]	Test-logloss:0.21691
# [27]	Test-logloss:0.21084
# [28]	Test-logloss:0.20627
# [29]	Test-logloss:0.19799
# [30]	Test-logloss:0.19167
# [31]	Test-logloss:0.18773
# [32]	Test-logloss:0.18132
# [33]	Test-logloss:0.17694
# [34]	Test-logloss:0.17403
# [35]	Test-logloss:0.16829
# [36]	Test-logloss:0.16450
# [37]	Test-logloss:0.16181
# [38]	Test-logloss:0.15798
# [39]	Test-logloss:0.15458
# [40]	Test-logloss:0.15199
# [41]	Test-logloss:0.14799
# [42]	Test-logloss:0.14614
# [43]	Test-logloss:0.14260
# [44]	Test-logloss:0.13898
# [45]	Test-logloss:0.13591
# [46]	Test-logloss:0.13352
# [47]	Test-logloss:0.13242
# [48]	Test-logloss:0.12838
# [49]	Test-logloss:0.12563
# [50]	Test-logloss:0.12382
# [51]	Test-logloss:0.12153
# [52]	Test-logloss:0.11900
# [53]	Test-logloss:0.11739
# [54]	Test-logloss:0.11649
# [55]	Test-logloss:0.11314
# [56]	Test-logloss:0.11138
# [57]	Test-logloss:0.10905
# [58]	Test-logloss:0.10761
# [59]	Test-logloss:0.10579
# [60]	Test-logloss:0.10288
# [61]	Test-logloss:0.10129
# [62]	Test-logloss:0.09857
# [63]	Test-logloss:0.09704
# [64]	Test-logloss:0.09545
# [65]	Test-logloss:0.09295
# [66]	Test-logloss:0.09157
# [67]	Test-logloss:0.08940
# [68]	Test-logloss:0.08713
# [69]	Test-logloss:0.08616
# [70]	Test-logloss:0.08436
# [71]	Test-logloss:0.08288
# [72]	Test-logloss:0.08191
# [73]	Test-logloss:0.07990
# [74]	Test-logloss:0.07892
# [75]	Test-logloss:0.07782
# [76]	Test-logloss:0.07599
# [77]	Test-logloss:0.07512
# [78]	Test-logloss:0.07339
# [79]	Test-logloss:0.07236
# [80]	Test-logloss:0.07166
# [81]	Test-logloss:0.07023
# [82]	Test-logloss:0.06962
# [83]	Test-logloss:0.06865
# [84]	Test-logloss:0.06817
# [85]	Test-logloss:0.06725
# [86]	Test-logloss:0.06673
# [87]	Test-logloss:0.06585
# [88]	Test-logloss:0.06525
# [89]	Test-logloss:0.06476
# [90]	Test-logloss:0.06439
# [91]	Test-logloss:0.06356
# [92]	Test-logloss:0.06252
# [93]	Test-logloss:0.06197
# [94]	Test-logloss:0.06163
# [95]	Test-logloss:0.06087
# [96]	Test-logloss:0.06047
# [97]	Test-logloss:0.05996
# [98]	Test-logloss:0.05891
# [99]	Test-logloss:0.05821
# [100]	Test-logloss:0.05774
# [101]	Test-logloss:0.05707
# [102]	Test-logloss:0.05675
# [103]	Test-logloss:0.05579
# [104]	Test-logloss:0.05538
# [105]	Test-logloss:0.05475
# [106]	Test-logloss:0.05385
# [107]	Test-logloss:0.05347
# [108]	Test-logloss:0.05288
# [109]	Test-logloss:0.05203
# [110]	Test-logloss:0.05168
# [111]	Test-logloss:0.05087
# [112]	Test-logloss:0.05054
# [113]	Test-logloss:0.05066
# [114]	Test-logloss:0.05035
# [115]	Test-logloss:0.04959
# [116]	Test-logloss:0.04971
# [117]	Test-logloss:0.04899
# [118]	Test-logloss:0.04912
# [119]	Test-logloss:0.04889
# [120]	Test-logloss:0.04902
# [121]	Test-logloss:0.04881
# [122]	Test-logloss:0.04895
# [123]	Test-logloss:0.04875
# [124]	Test-logloss:0.04865
# [125]	Test-logloss:0.04880
# [126]	Test-logloss:0.04861
# [127]	Test-logloss:0.04876
# [128]	Test-logloss:0.04858
# [129]	Test-logloss:0.04874
# [130]	Test-logloss:0.04890
# [131]	Test-logloss:0.04891
# [132]	Test-logloss:0.04891
# [133]	Test-logloss:0.04891
# [134]	Test-logloss:0.04891
# [135]	Test-logloss:0.04891
# [136]	Test-logloss:0.04892
# [137]	Test-logloss:0.04892
# [138]	Test-logloss:0.04892
# ROC AUC Score: 1.0
# Accuracy: 1.00

# %%
games_pred = []
def predict(
    season,
    nickname_0, 
    nickname_1
):
    xgb_rf_pred_map_0 = {}
    xgb_rf_pred_map_1 = {}
    
    x_0 = get_prediction_feature_map(xgb_rf_model_and_data_map.get(nickname_0)[2].tail(1), season, nickname_0, nickname_1, 0)
    x_1 = get_prediction_feature_map(xgb_rf_model_and_data_map.get(nickname_1)[2].tail(1), season, nickname_1, nickname_0, 1)
    normalization_func_0 = normalization_func_by_team_nickname.get(nickname_0)[0]
    normalization_func_1 = normalization_func_by_team_nickname.get(nickname_1)[0]
    
    x_0_normalized = pd.DataFrame(normalization_func_0.transform(x_0), columns=x_0.columns)
    x_1_normalized = pd.DataFrame(normalization_func_1.transform(x_1), columns=x_1.columns)
    dnew_0 = xgb.DMatrix(x_0_normalized)
    dnew_1 = xgb.DMatrix(x_1_normalized)

    xgb_res_0 = xgb_rf_model_and_data_map.get(nickname_0)[0].predict(dnew_0)
    xgb_res_1 = xgb_rf_model_and_data_map.get(nickname_1)[0].predict(dnew_1)

    rf_res_0 = xgb_rf_model_and_data_map.get(nickname_0)[1].predict(x_0_normalized)
    rf_res_1 = xgb_rf_model_and_data_map.get(nickname_1)[1].predict(x_1_normalized)

    xgb_rf_pred_map_0[nickname_0] = {
        "xgb_proba": xgb_res_0,
        "rf_clf": rf_res_0
    }
    xgb_rf_pred_map_1[nickname_1] = {
        "xgb_proba": xgb_res_1,
        "rf_clf": rf_res_1
    }

    games_pred.append([xgb_rf_pred_map_0, xgb_rf_pred_map_1])
    
    print(nickname_0, " Xgb Proba: ", xgb_res_0)
    print(nickname_1, " Xgb Proba: ", xgb_res_1)
    print(nickname_0, " Classifier: ", rf_res_0)
    print(nickname_1, " Classifier: ", rf_res_1)

# %%
predict(season, "Pacers", "Knicks")
# Out:
# Pacers  Xgb Proba:  [0.7784517]
# Knicks  Xgb Proba:  [0.61178756]
# Pacers  Classifier:  [1]
# Knicks  Classifier:  [1]

# %%
predict(season, "Timberwolves", "Nuggets")
# Out:
# Timberwolves  Xgb Proba:  [0.4071974]
# Nuggets  Xgb Proba:  [0.8435904]
# Timberwolves  Classifier:  [1]
# Nuggets  Classifier:  [1]

# %%
#########################################################
# get probability of games hitting in set ###############
def get_proba_from_set(nickname_set, nickname_to_proba_map):
    proba = 1
    for nickname in nickname_set:
        proba = proba * nickname_to_proba_map.get(nickname)
    return proba

# Get combination of games that have 
# highest probablity of winning
def sort_probable_games(games_pred):
    confident_games = []
    for game in games_pred:
        nickname_0 = list(game[0].keys())[0]
        nickname_1 = list(game[1].keys())[0]
        xgb_0 = game[0].get(nickname_0).get("xgb_proba")[0]
        xgb_1 = game[1].get(nickname_1).get("xgb_proba")[0]
        rf_clf_0 = game[0].get(nickname_0).get("rf_clf")[0]
        rf_clf_1 = game[1].get(nickname_1).get("rf_clf")[0]

        spread = abs(xgb_0 - xgb_1)
        if xgb_0 > xgb_1 and rf_clf_0 == 1 and rf_clf_1 == 0 and spread > .15:
            confident_games.append({ "proba": xgb_0, "spread": spread, "nickname": nickname_0})
        if xgb_0 < xgb_1 and rf_clf_0 == 0 and rf_clf_1 == 1 and spread > .15:
            confident_games.append({ "proba": xgb_1, "spread": spread, "nickname": nickname_1 })

    confident_games = list(filter(lambda game: game.get("proba") > .5, confident_games))
    
    nickname_to_proba_map = {}
    parlays_set = set()
    for game in confident_games:
        nickname_to_proba_map.update({ game.get("nickname"): game.get("proba")})    
        parlays_set.add(frozenset([game.get("nickname")]))
        
    for game in confident_games:
        for parlay in parlays_set.copy():            
            if game.get("nickname") not in parlay and game.get("proba") * get_proba_from_set(parlay, nickname_to_proba_map) > .5:
                parlays_set.add(parlay.union([game.get("nickname")]))
    
    
    parlay_probas = {}
    for parlay in parlays_set:
        parlay_probas.update({ parlay: get_proba_from_set(parlay, nickname_to_proba_map)})
    return nickname_to_proba_map, dict(sorted(parlay_probas.items(), key=lambda item: item[1], reverse=True))
#########################################################

# %%
proba_map, parlay_probas = sort_probable_games(games_pred) 
pprint(proba_map)
print()
pprint(parlay_probas)
# Out:
# {}
#
# {}

# %%
# knicks, lakers, Rockets, suns
