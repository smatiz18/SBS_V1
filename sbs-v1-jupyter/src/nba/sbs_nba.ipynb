# %%
# Written by Sebastian Matiz
import pandas as pd
import requests
import json
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, roc_auc_score
from bs4 import BeautifulSoup
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
from pprint import pprint

cols_to_drop_for_player_stats = [
    "comment",
    "player.firstname",
    "player.lastname",
    "player.id",
    "team.id",
    "team.nickname",
    "team.code",
    "team.name",
    "team.logo",
    "game.id",
    "pos"
]

cols_to_drop_for_game_stats = [
    "league",
    "season",
    "stage",
    "officials",
    "timesTied",
    "leadChanges",
    "nugget",
    "date.start",
    "date.end",
    "date.duration",
    "status.clock",
    "status.halftime",
    "status.short",
    "status.long",
    "periods.current",
    "periods.total",
    "periods.endOfPeriod",
    "arena.name",
    "arena.city",
    "arena.state",
    "arena.country",
    "teams.visitors.id",
    "teams.visitors.name",
    "teams.visitors.nickname",
    "teams.visitors.code",
    "teams.visitors.logo",
    "teams.home.id",
    "teams.home.name",
    "teams.home.nickname",
    "teams.home.code",
    "teams.home.logo",
    "scores.visitors.points",
    "scores.visitors.win",
    "scores.visitors.loss",
    "scores.visitors.series.win",
    "scores.visitors.series.loss",
    "scores.visitors.linescore",
    "scores.home.points",
    "scores.home.win",
    "scores.home.loss",
    "scores.home.series.win",
    "scores.home.series.loss",
    "scores.home.linescore"
]

# %%
# rapidApi headers
headers = {
    "X-RapidAPI-Key": "REDACTED_RAPIDAPI_KEY",
    "X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
}

# %%
#########################################################
# games by game ids #####################################
def get_team_nicknames_by_id():
    # team code by id
    url = "https://api-nba-v1.p.rapidapi.com/teams"
    response = requests.get(url, headers=headers).json()["response"]
    df = pd.DataFrame(response)
    df = df.loc[(df["nbaFranchise"] == True) & (df["allStar"] == False)]
    
    team_nickname_to_id_map = {}
    
    for index, row in df.iterrows():
        team_nickname_to_id_map.update({row["nickname"]: row["id"]})
    return team_nickname_to_id_map
#########################################################

# %%
team_nickname_to_id_map = get_team_nicknames_by_id()

# %%
#########################################################
# games by game ids #####################################
def get_games_by_game_ids(season, team_id):
    url = "https://api-nba-v1.p.rapidapi.com/games"
    querystring = {"season":season,"team":team_id}

    response = requests.get(url, headers=headers, params=querystring)
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
    df = df.loc[(df["status.long"] == "Finished")]
    df = df.sort_values(by=["date.start"])
    
    # adding win col to df
    df["win"] = ""

    df.loc[
        ((df["scores.home.points"] > df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.home.id"])) |
        ((df["scores.home.points"] < df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.visitors.id"])),
        "win"
    ] = 1

    df.loc[
        ((df["scores.home.points"] < df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.home.id"])) |
        ((df["scores.home.points"] > df["scores.visitors.points"]) & 
        (int(team_id) == df["teams.visitors.id"])),
        "win"
    ] = 0

    df["points"] = np.where(
        df["teams.home.id"] == team_id, 
        df["scores.home.points"], 
        df["scores.visitors.points"]
    )
    df["opponent.points"] = np.where(
        df["teams.home.id"] != team_id, 
        df["scores.home.points"], 
        df["scores.visitors.points"]
    )
    df["opponent.team_id"] = np.where(
        df["teams.home.id"] != team_id, 
        df["teams.home.id"], 
        df["teams.visitors.id"]
    )

    # adding home col to df
    df["home"] = ""
    
    df.loc[(int(team_id) == df["teams.home.id"]), "home"] = 1
        
    df.loc[(int(team_id) == df["teams.visitors.id"]), "home"] = 0    
    
    return drop_cols(df, cols_to_drop_for_game_stats)
#########################################################

# %%
#########################################################
# drop all cols from a df ###############################
def drop_cols(df, cols):
    for col in cols:
        df = df.drop(col, axis=1)
    return df
#########################################################

# %%
#########################################################
# get top n player stats by game by #####################
def get_top_players_per_game_df(n, team_id, game_id):    
    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"

    querystring = {"game": game_id }
    
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )

    df_opponent = df.loc[df["team.id"] != team_id]
    df = df.loc[df["team.id"] == team_id]
    
    df_opponent = drop_cols(df_opponent, cols_to_drop_for_player_stats)
    df = drop_cols(df, cols_to_drop_for_player_stats)
    
    df_opponent = zero_non_numeric_values(df_opponent)
    df = zero_non_numeric_values(df)
    
    df_opponent = df_opponent.add_prefix("opponent.")

    return df_opponent.nlargest(n, "opponent.plusMinus"), df.nlargest(n, "plusMinus")
#########################################################

# %%
#########################################################
# flatten data frames ###################################
def flatten_df(df):
    # Flatten the DataFrame
    flattened_data = {}
    for col in df.columns:
        for row in range(df.shape[0]):
            new_col_name = f"{col}{row}"
            flattened_data[new_col_name] = df[col].iloc[row]

    # Convert to DataFrame
    return pd.DataFrame([flattened_data])
#########################################################

# %%
#########################################################
# per game, get top 5 players by plusMinus metric #######
def get_top_five_players_per_game(team_id, game_ids): 
    top_5_players_on_team_per_game = {}
    for game_id in game_ids:
        # transform player_stats_df
        opponent_top_five_player_stats, friendly_top_five_player_stats = get_top_players_per_game_df(5, team_id, game_id)
        opponent_top_five_player_stats = flatten_df(opponent_top_five_player_stats)
        friendly_top_five_player_stats = flatten_df(friendly_top_five_player_stats)
        top_five_players_stats = pd.concat(
            [opponent_top_five_player_stats, friendly_top_five_player_stats], 
            axis=1
        )
        ###########################
        top_5_players_on_team_per_game[game_id] = top_five_players_stats          
    return top_5_players_on_team_per_game
#########################################################

# %%
#########################################################
# get win prc, and last 10 win prc ######################
def get_win_prc(game_df):
    total_win_prc = []
    last_ten_win_prc = []
    last_ten_games_win_loss = []
    total_games_played = []
    last_ten_win_count = 0
    total_win_count = 0
    total_game_count = 0
    
    for index, row in game_df.iterrows():
        total_game_count += 1
        last_ten_games_win_loss.append(row["win"])
        
        if row["win"]:
            total_win_count += 1
            last_ten_win_count += 1
            
        total_win_prc.append(total_win_count/total_game_count)
               
        if total_game_count >= 10:
            if last_ten_games_win_loss[0]:
                last_ten_win_count -= 1
            last_ten_games_win_loss.pop(0)
            last_ten_win_prc.append(last_ten_win_count/10)
        else:
            last_ten_win_prc.append(last_ten_win_count/total_game_count)
        
        total_games_played.append(total_game_count)            
    return last_ten_win_prc, total_win_prc, total_games_played
#########################################################

# %%
#########################################################
# combine player stats and games features ###############
def combine_player_stats_and_games_data(games_df, player_stats_per_game):
    feature_map = []
    feature_map_cols_header = []
    for index, row in games_df.iterrows():
        game_id = row["id"]
        game_df = pd.DataFrame(row).transpose()
        players_stats_df = player_stats_per_game.get(game_id)
        if len(feature_map_cols_header) < 1:
            feature_map_cols_header = list(game_df) + list(players_stats_df)

        game_data = np.array(game_df.iloc[0])
        player_stats_data = np.array(players_stats_df.iloc[0])
        feature_map_data_row = np.concatenate((game_data, player_stats_data))
        feature_map.append(feature_map_data_row)
    return pd.DataFrame(feature_map, columns=feature_map_cols_header)
#########################################################

# %%
#########################################################
def get_feature_map_and_y(season, team_id):
    games_df = get_games_by_game_ids(season, team_id) 
    
    players_stats_per_games = get_top_five_players_per_game(
        team_id, 
        games_df["id"].array
    )
    
    last_ten_win_prc, total_win_prc, total_games_played = get_win_prc(games_df)
    games_df = games_df.assign(last_ten_w_prc=last_ten_win_prc)
    games_df = games_df.assign(w_prc=total_win_prc)
    games_df = games_df.assign(games_played=total_games_played)
    
    df = combine_player_stats_and_games_data(games_df, players_stats_per_games)
    df = zero_non_numeric_values(df)
    x = drop_cols(df, ["win", "id"])
    y = df["win"]
    return x, y 
#########################################################

# %%
#########################################################
normalization_func_by_team_nickname = {}
def get_xgb_model_and_rf_classifier_model(team_nickname, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

    # normalize feature map
    scaler = MinMaxScaler()
    x_train_normalized = pd.DataFrame(scaler.fit_transform(x_train), columns=x.columns)
    x_test_normalized = pd.DataFrame(scaler.transform(x_test), columns=x.columns)
    normalization_func_by_team_nickname.update({team_nickname: [scaler]})

    # XGB ###################################################
    dtrain = xgb.DMatrix(x_train_normalized, label=y_train)
    dtest = xgb.DMatrix(x_test_normalized, label=y_test)

    params = {
        "objective": "binary:logistic",
        "max_depth": 5,
        "eta": 0.05,
        "eval_metric": "logloss",
    }

    num_boost_round = 999

    bst = xgb.train(
        params, 
        dtrain, 
        num_boost_round, 
        evals=[(dtest, "Test")], 
        early_stopping_rounds=10
    )
    
    # Predict probabilities on the test set
    y_pred_proba = bst.predict(dtest)
    
    # Calculate ROC AUC
    auc_score = roc_auc_score(y_test, y_pred_proba)
    print(f"ROC AUC Score: {auc_score}")
    #########################################################

    # Classifier ############################################
    # training random forest classifier 
    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

    # Train the model on the training set
    rf_classifier.fit(x_train_normalized, y_train)
    
    # Make predictions on the test set
    rf_classifier_predictions = rf_classifier.predict(x_test_normalized)

    # Evaluate the model
    rf_classifier_accuracy = accuracy_score(y_test, rf_classifier_predictions)
    print(f"Accuracy: {rf_classifier_accuracy:.2f}")
    #########################################################
    
    return bst, rf_classifier
#########################################################

# %%
#########################################################
def zero_non_numeric_values(df):
    for col in df.columns:
        df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0)
    return df
#########################################################

# %%
#########################################################
xgb_rf_model_and_data_map = {}
def get_data_and_xgb_rf_models(season, team_nickname):
    team_id = team_nickname_to_id_map.get(team_nickname)
    x, y = get_feature_map_and_y(season, team_id)
   
    xgb, classifier = get_xgb_model_and_rf_classifier_model(team_nickname, x, y)
    xgb_rf_model_and_data_map.update({team_nickname: [xgb, classifier, x, y]})
#########################################################

# %%
#########################################################
def get_player_season_stats_avgs(season, player_id):
    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"
    querystring = {"id":player_id,"season":season}
    
    df = pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
    
    df = drop_cols(df, cols_to_drop_for_player_stats)
    df = zero_non_numeric_values(df)

    played_games = df[df["min"] > 0]    
    return played_games.mean()
#########################################################

# %%
#########################################################
def get_players_season_stats_avgs(season, player_ids):
    player_stats_avgs = []
    for i in player_ids:
        player_stats_avgs.append(get_player_season_stats_avgs(season, i))
    
    df = pd.DataFrame(player_stats_avgs)
    return df.sort_values(by=["plusMinus"], ascending=False)
#########################################################

# %%
#########################################################
def get_player_lineups_for_tn():
    url = "https://www.rotowire.com/basketball/nba-lineups.php"
    response = requests.get(url, verify=False)
    soup = BeautifulSoup(response.text, "html.parser")
    players_by_team = {}
    button_divs = soup.find_all("button", class_="see-court-on-off")

    for div in button_divs:
        nickname = div["data-nickname"]
        players_by_team.update({ nickname: [] })
        player_ids = div["data-lineup"].split(",")[:5]
        for player_id in player_ids:
            player_divs = soup.find_all("li", class_="lineup__player")
            for player_div in player_divs:
                a_tags = player_div.find_all("a", href=lambda href: href and player_id in href)
                for a_tag in a_tags:
                    if a_tag["title"] not in players_by_team.get(nickname):
                        players_by_team[nickname].append(a_tag["title"])

    return players_by_team
#########################################################

# %%
#########################################################
def get_players_by_team_and_season(team_id, season):
    url = "https://api-nba-v1.p.rapidapi.com/players"
    querystring = {"team": team_id,"season":season}
    return pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
#########################################################

# %%
#########################################################
def get_team_latest_stats(team_id, season):
    url = "https://api-nba-v1.p.rapidapi.com/teams/statistics"
    querystring = {"id": team_id,"season": season}
    return pd.json_normalize(
        requests.get(url, headers=headers, params=querystring)
        .json()["response"]
    )
#########################################################

# %%
#########################################################
def make_alphanum(str):
    return "".join(char.lower() for char in str if char.isalnum())
#########################################################

# %%
#########################################################
def filter_list_not_contain_substrs(list, substrs):
    res = []
    for i in substrs:
        for j in list:
            if make_alphanum(i) in make_alphanum(j):
                res.append(j)
    return res
#########################################################

# %%
#########################################################
def get_prediction_feature_map(
    training_data_tail,
    season,
    team_nickname,
    o_team_nickname,
    home
):   
    team_id = team_nickname_to_id_map.get(team_nickname)
    o_team_id = team_nickname_to_id_map.get(o_team_nickname)
    
    # getting player attributes
    df = get_players_by_team_and_season(team_id, season)  
    o_df = get_players_by_team_and_season(o_team_id, season)

    concat_names = df["firstname"] + " " + df["lastname"]
    o_concat_names = o_df["firstname"] + " " + o_df["lastname"]

    name_list = players_name_map.get(team_nickname)    
    o_name_list = players_name_map.get(o_team_nickname)

    filtered_names = filter_list_not_contain_substrs(concat_names, name_list)
    o_filtered_names = filter_list_not_contain_substrs(o_concat_names, o_name_list)
    
    df_players = df[concat_names.isin(set(filtered_names))]
    o_df_players = o_df[o_concat_names.isin(set(o_filtered_names))]
    
    team_latest_stats = get_team_latest_stats(team_id, season)
    o_team_latest_stats = get_team_latest_stats(o_team_id, season)

    team_avg_ppg = team_latest_stats.iloc[0]["points"] / team_latest_stats.iloc[0]["games"]
    o_team_avg_ppg = o_team_latest_stats.iloc[0]["points"] / o_team_latest_stats.iloc[0]["games"]
    
    player_ids = np.array(df_players["id"])
    o_player_ids = np.array(o_df_players["id"])
    
    players_stats_avgs = get_players_season_stats_avgs(season, player_ids)
    o_players_stats_avgs = get_players_season_stats_avgs(season, o_player_ids)
    o_players_stats_avgs = o_players_stats_avgs.add_prefix("opponent.")

    players_stats_avgs = flatten_df(players_stats_avgs)
    o_players_stats_avgs = flatten_df(o_players_stats_avgs)

    players_stats = pd.concat(
        [o_players_stats_avgs, players_stats_avgs], 
        axis=1
    )
    
    games_col_headers = [
        "points",
        "opponent.points", 
        "opponent.team_id",
        "home", 
        "last_ten_w_prc", 
        "w_prc", 
        "games_played"
    ]
    
    games_data = [
        team_avg_ppg, 
        o_team_avg_ppg, 
        o_team_id,
        home, 
        training_data_tail["last_ten_w_prc"].iloc[0], 
        training_data_tail["w_prc"].iloc[0],
        training_data_tail["games_played"].iloc[0] + 1
    ]
        
    feature_map_col_headers = games_col_headers + list(players_stats)
    feature_map_data_row = np.concatenate((games_data, players_stats.iloc[0]))
    return pd.DataFrame([feature_map_data_row], columns=feature_map_col_headers)    
#########################################################

# %%
players_name_map = get_player_lineups_for_tn()
# Out:
# /Users/smati/SBS_V1/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.rotowire.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Get models for teams ##################################
season = "2023"
# print("76ers")
# get_data_and_xgb_rf_models(season, "76ers")
# print()

# print("Knicks")
# get_data_and_xgb_rf_models(season, "Knicks")
# print()

# print("Pacers")
# get_data_and_xgb_rf_models(season, "Pacers")
# print()

print("Thunder")
get_data_and_xgb_rf_models(season, "Thunder")
print()

# print("Wizards")
# get_data_and_xgb_rf_models(season, "Wizards")
# print()

print("Grizzlies")
get_data_and_xgb_rf_models(season, "Grizzlies")
print()

print("Rockets")
get_data_and_xgb_rf_models(season, "Rockets")
print()

print("Spurs")
get_data_and_xgb_rf_models(season, "Spurs")
print()

# print("Celtics")
# get_data_and_xgb_rf_models(season, "Celtics")
# print()

print("Jazz")
get_data_and_xgb_rf_models(season, "Jazz")
print()

print("Timberwolves")
get_data_and_xgb_rf_models(season, "Timberwolves")
print()

print("Clippers")
get_data_and_xgb_rf_models(season, "Clippers")
print()

# print("Bucks")
# get_data_and_xgb_rf_models(season, "Bucks")
# print()

print("Kings")
get_data_and_xgb_rf_models(season, "Kings")
print()

# print("Raptors")
# get_data_and_xgb_rf_models(season, "Raptors")
# print()
#########################################################
# Out:
# Thunder
# [0]	Test-logloss:0.53048
# [1]	Test-logloss:0.50578
# [2]	Test-logloss:0.48185
# [3]	Test-logloss:0.46356
# [4]	Test-logloss:0.44011
# [5]	Test-logloss:0.41827
# [6]	Test-logloss:0.40031
# [7]	Test-logloss:0.38572
# [8]	Test-logloss:0.36772
# [9]	Test-logloss:0.35385
# [10]	Test-logloss:0.34037
# [11]	Test-logloss:0.32995
# [12]	Test-logloss:0.31817
# [13]	Test-logloss:0.30574
# [14]	Test-logloss:0.29885
# [15]	Test-logloss:0.28922
# [16]	Test-logloss:0.27877
# [17]	Test-logloss:0.27200
# [18]	Test-logloss:0.26095
# [19]	Test-logloss:0.25089
# [20]	Test-logloss:0.24538
# [21]	Test-logloss:0.23467
# [22]	Test-logloss:0.23042
# [23]	Test-logloss:0.22543
# [24]	Test-logloss:0.21783
# [25]	Test-logloss:0.21020
# [26]	Test-logloss:0.20461
# [27]	Test-logloss:0.19721
# [28]	Test-logloss:0.19398
# [29]	Test-logloss:0.18675
# [30]	Test-logloss:0.18032
# [31]	Test-logloss:0.17507
# [32]	Test-logloss:0.17319
# [33]	Test-logloss:0.16932
# [34]	Test-logloss:0.16650
# [35]	Test-logloss:0.16167
# [36]	Test-logloss:0.15891
# [37]	Test-logloss:0.15689
# [38]	Test-logloss:0.15527
# [39]	Test-logloss:0.15109
# [40]	Test-logloss:0.14915
# [41]	Test-logloss:0.14622
# [42]	Test-logloss:0.14457
# [43]	Test-logloss:0.14205
# [44]	Test-logloss:0.13859
# [45]	Test-logloss:0.13686
# [46]	Test-logloss:0.13343
# [47]	Test-logloss:0.13215
# [48]	Test-logloss:0.12972
# [49]	Test-logloss:0.12776
# [50]	Test-logloss:0.12456
# [51]	Test-logloss:0.12237
# [52]	Test-logloss:0.12063
# [53]	Test-logloss:0.11813
# [54]	Test-logloss:0.11649
# [55]	Test-logloss:0.11506
# [56]	Test-logloss:0.11245
# [57]	Test-logloss:0.11096
# [58]	Test-logloss:0.10951
# [59]	Test-logloss:0.10790
# [60]	Test-logloss:0.10658
# [61]	Test-logloss:0.10523
# [62]	Test-logloss:0.10460
# [63]	Test-logloss:0.10241
# [64]	Test-logloss:0.10175
# [65]	Test-logloss:0.10068
# [66]	Test-logloss:0.09911
# [67]	Test-logloss:0.09788
# [68]	Test-logloss:0.09612
# [69]	Test-logloss:0.09504
# [70]	Test-logloss:0.09412
# [71]	Test-logloss:0.09410
# [72]	Test-logloss:0.09241
# [73]	Test-logloss:0.09245
# [74]	Test-logloss:0.09189
# [75]	Test-logloss:0.09200
# [76]	Test-logloss:0.09042
# [77]	Test-logloss:0.08919
# [78]	Test-logloss:0.08771
# [79]	Test-logloss:0.08727
# [80]	Test-logloss:0.08684
# [81]	Test-logloss:0.08520
# [82]	Test-logloss:0.08531
# [83]	Test-logloss:0.08497
# [84]	Test-logloss:0.08384
# [85]	Test-logloss:0.08278
# [86]	Test-logloss:0.08146
# [87]	Test-logloss:0.08115
# [88]	Test-logloss:0.08088
# [89]	Test-logloss:0.07967
# [90]	Test-logloss:0.07984
# [91]	Test-logloss:0.07847
# [92]	Test-logloss:0.07827
# [93]	Test-logloss:0.07734
# [94]	Test-logloss:0.07619
# [95]	Test-logloss:0.07602
# [96]	Test-logloss:0.07624
# [97]	Test-logloss:0.07530
# [98]	Test-logloss:0.07513
# [99]	Test-logloss:0.07501
# [100]	Test-logloss:0.07395
# [101]	Test-logloss:0.07313
# [102]	Test-logloss:0.07337
# [103]	Test-logloss:0.07328
# [104]	Test-logloss:0.07215
# [105]	Test-logloss:0.07206
# [106]	Test-logloss:0.07111
# [107]	Test-logloss:0.07028
# [108]	Test-logloss:0.06954
# [109]	Test-logloss:0.06949
# [110]	Test-logloss:0.06858
# [111]	Test-logloss:0.06787
# [112]	Test-logloss:0.06784
# [113]	Test-logloss:0.06697
# [114]	Test-logloss:0.06630
# [115]	Test-logloss:0.06628
# [116]	Test-logloss:0.06536
# [117]	Test-logloss:0.06472
# [118]	Test-logloss:0.06471
# [119]	Test-logloss:0.06392
# [120]	Test-logloss:0.06331
# [121]	Test-logloss:0.06255
# [122]	Test-logloss:0.06182
# [123]	Test-logloss:0.06111
# [124]	Test-logloss:0.06042
# [125]	Test-logloss:0.06022
# [126]	Test-logloss:0.06003
# [127]	Test-logloss:0.05950
# [128]	Test-logloss:0.05933
# [129]	Test-logloss:0.05883
# [130]	Test-logloss:0.05882
# [131]	Test-logloss:0.05882
# [132]	Test-logloss:0.05882
# [133]	Test-logloss:0.05882
# [134]	Test-logloss:0.05882
# [135]	Test-logloss:0.05881
# [136]	Test-logloss:0.05881
# [137]	Test-logloss:0.05881
# [138]	Test-logloss:0.05881
# [139]	Test-logloss:0.05881
# [140]	Test-logloss:0.05881
# [141]	Test-logloss:0.05880
# [142]	Test-logloss:0.05880
# [143]	Test-logloss:0.05880
# [144]	Test-logloss:0.05880
# [145]	Test-logloss:0.05880
# [146]	Test-logloss:0.05880
# [147]	Test-logloss:0.05880
# [148]	Test-logloss:0.05880
# [149]	Test-logloss:0.05879
# [150]	Test-logloss:0.05879
# [151]	Test-logloss:0.05879
# [152]	Test-logloss:0.05879
# [153]	Test-logloss:0.05879
# [154]	Test-logloss:0.05879
# [155]	Test-logloss:0.05879
# [156]	Test-logloss:0.05879
# [157]	Test-logloss:0.05879
# [158]	Test-logloss:0.05879
# [159]	Test-logloss:0.05879
# [160]	Test-logloss:0.05878
# [161]	Test-logloss:0.05878
# [162]	Test-logloss:0.05878
# [163]	Test-logloss:0.05878
# [164]	Test-logloss:0.05878
# [165]	Test-logloss:0.05878
# [166]	Test-logloss:0.05878
# [167]	Test-logloss:0.05878
# [168]	Test-logloss:0.05878
# [169]	Test-logloss:0.05878
# [170]	Test-logloss:0.05878
# [171]	Test-logloss:0.05878
# [172]	Test-logloss:0.05878
# [173]	Test-logloss:0.05878
# [174]	Test-logloss:0.05878
# [175]	Test-logloss:0.05878
# [176]	Test-logloss:0.05878
# [177]	Test-logloss:0.05878
# [178]	Test-logloss:0.05878
# [179]	Test-logloss:0.05877
# [180]	Test-logloss:0.05877
# [181]	Test-logloss:0.05877
# [182]	Test-logloss:0.05877
# [183]	Test-logloss:0.05877
# [184]	Test-logloss:0.05877
# [185]	Test-logloss:0.05877
# [186]	Test-logloss:0.05877
# [187]	Test-logloss:0.05877
# [188]	Test-logloss:0.05877
# [189]	Test-logloss:0.05877
# [190]	Test-logloss:0.05877
# [191]	Test-logloss:0.05877
# [192]	Test-logloss:0.05877
# [193]	Test-logloss:0.05877
# [194]	Test-logloss:0.05877
# [195]	Test-logloss:0.05877
# [196]	Test-logloss:0.05877
# [197]	Test-logloss:0.05877
# [198]	Test-logloss:0.05877
# [199]	Test-logloss:0.05877
# [200]	Test-logloss:0.05877
# [201]	Test-logloss:0.05877
# [202]	Test-logloss:0.05877
# [203]	Test-logloss:0.05877
# [204]	Test-logloss:0.05877
# [205]	Test-logloss:0.05877
# [206]	Test-logloss:0.05877
# [207]	Test-logloss:0.05877
# [208]	Test-logloss:0.05877
# [209]	Test-logloss:0.05877
# [210]	Test-logloss:0.05877
# [211]	Test-logloss:0.05877
# [212]	Test-logloss:0.05877
# [213]	Test-logloss:0.05877
# [214]	Test-logloss:0.05877
# [215]	Test-logloss:0.05877
# [216]	Test-logloss:0.05877
# [217]	Test-logloss:0.05877
# [218]	Test-logloss:0.05877
# [219]	Test-logloss:0.05877
# [220]	Test-logloss:0.05877
# [221]	Test-logloss:0.05877
# [222]	Test-logloss:0.05877
# [223]	Test-logloss:0.05877
# [224]	Test-logloss:0.05877
# [225]	Test-logloss:0.05877
# [226]	Test-logloss:0.05877
# [227]	Test-logloss:0.05877
# [228]	Test-logloss:0.05877
# [229]	Test-logloss:0.05877
# [230]	Test-logloss:0.05877
# [231]	Test-logloss:0.05877
# [232]	Test-logloss:0.05877
# [233]	Test-logloss:0.05877
# [234]	Test-logloss:0.05877
# [235]	Test-logloss:0.05877
# [236]	Test-logloss:0.05877
# [237]	Test-logloss:0.05877
# [238]	Test-logloss:0.05876
# [239]	Test-logloss:0.05876
# [240]	Test-logloss:0.05876
# [241]	Test-logloss:0.05876
# [242]	Test-logloss:0.05876
# [243]	Test-logloss:0.05876
# [244]	Test-logloss:0.05876
# [245]	Test-logloss:0.05876
# [246]	Test-logloss:0.05876
# [247]	Test-logloss:0.05876
# [248]	Test-logloss:0.05876
# [249]	Test-logloss:0.05876
# [250]	Test-logloss:0.05876
# [251]	Test-logloss:0.05876
# [252]	Test-logloss:0.05876
# [253]	Test-logloss:0.05876
# [254]	Test-logloss:0.05876
# [255]	Test-logloss:0.05876
# [256]	Test-logloss:0.05876
# [257]	Test-logloss:0.05876
# [258]	Test-logloss:0.05876
# [259]	Test-logloss:0.05876
# [260]	Test-logloss:0.05876
# [261]	Test-logloss:0.05876
# [262]	Test-logloss:0.05876
# [263]	Test-logloss:0.05876
# [264]	Test-logloss:0.05876
# [265]	Test-logloss:0.05876
# [266]	Test-logloss:0.05876
# [267]	Test-logloss:0.05876
# [268]	Test-logloss:0.05876
# [269]	Test-logloss:0.05876
# [270]	Test-logloss:0.05876
# [271]	Test-logloss:0.05876
# [272]	Test-logloss:0.05876
# [273]	Test-logloss:0.05876
# [274]	Test-logloss:0.05876
# [275]	Test-logloss:0.05876
# [276]	Test-logloss:0.05876
# [277]	Test-logloss:0.05876
# [278]	Test-logloss:0.05876
# [279]	Test-logloss:0.05876
# [280]	Test-logloss:0.05876
# [281]	Test-logloss:0.05876
# [282]	Test-logloss:0.05876
# [283]	Test-logloss:0.05876
# [284]	Test-logloss:0.05876
# [285]	Test-logloss:0.05876
# [286]	Test-logloss:0.05876
# [287]	Test-logloss:0.05876
# [288]	Test-logloss:0.05876
# [289]	Test-logloss:0.05876
# [290]	Test-logloss:0.05876
# [291]	Test-logloss:0.05876
# [292]	Test-logloss:0.05876
# [293]	Test-logloss:0.05876
# [294]	Test-logloss:0.05876
# [295]	Test-logloss:0.05876
# [296]	Test-logloss:0.05876
# [297]	Test-logloss:0.05876
# [298]	Test-logloss:0.05876
# [299]	Test-logloss:0.05876
# [300]	Test-logloss:0.05876
# [301]	Test-logloss:0.05876
# [302]	Test-logloss:0.05876
# [303]	Test-logloss:0.05876
# [304]	Test-logloss:0.05876
# [305]	Test-logloss:0.05876
# [306]	Test-logloss:0.05876
# [307]	Test-logloss:0.05876
# [308]	Test-logloss:0.05876
# [309]	Test-logloss:0.05876
# [310]	Test-logloss:0.05876
# [311]	Test-logloss:0.05876
# [312]	Test-logloss:0.05876
# [313]	Test-logloss:0.05876
# [314]	Test-logloss:0.05876
# [315]	Test-logloss:0.05876
# [316]	Test-logloss:0.05876
# [317]	Test-logloss:0.05876
# [318]	Test-logloss:0.05876
# [319]	Test-logloss:0.05876
# [320]	Test-logloss:0.05876
# [321]	Test-logloss:0.05876
# [322]	Test-logloss:0.05876
# [323]	Test-logloss:0.05876
# [324]	Test-logloss:0.05876
# [325]	Test-logloss:0.05876
# [326]	Test-logloss:0.05876
# [327]	Test-logloss:0.05876
# [328]	Test-logloss:0.05876
# [329]	Test-logloss:0.05876
# [330]	Test-logloss:0.05876
# [331]	Test-logloss:0.05876
# [332]	Test-logloss:0.05876
# [333]	Test-logloss:0.05876
# [334]	Test-logloss:0.05876
# [335]	Test-logloss:0.05876
# [336]	Test-logloss:0.05876
# [337]	Test-logloss:0.05876
# [338]	Test-logloss:0.05876
# [339]	Test-logloss:0.05876
# [340]	Test-logloss:0.05876
# [341]	Test-logloss:0.05876
# [342]	Test-logloss:0.05876
# [343]	Test-logloss:0.05876
# [344]	Test-logloss:0.05876
# [345]	Test-logloss:0.05876
# [346]	Test-logloss:0.05876
# [347]	Test-logloss:0.05876
# [348]	Test-logloss:0.05876
# [349]	Test-logloss:0.05876
# [350]	Test-logloss:0.05876
# [351]	Test-logloss:0.05876
# [352]	Test-logloss:0.05876
# [353]	Test-logloss:0.05876
# [354]	Test-logloss:0.05876
# [355]	Test-logloss:0.05876
# [356]	Test-logloss:0.05876
# [357]	Test-logloss:0.05876
# [358]	Test-logloss:0.05876
# [359]	Test-logloss:0.05876
# [360]	Test-logloss:0.05876
# [361]	Test-logloss:0.05876
# [362]	Test-logloss:0.05876
# [363]	Test-logloss:0.05876
# [364]	Test-logloss:0.05876
# [365]	Test-logloss:0.05876
# [366]	Test-logloss:0.05876
# [367]	Test-logloss:0.05876
# [368]	Test-logloss:0.05876
# [369]	Test-logloss:0.05876
# [370]	Test-logloss:0.05876
# [371]	Test-logloss:0.05876
# [372]	Test-logloss:0.05876
# [373]	Test-logloss:0.05876
# [374]	Test-logloss:0.05876
# [375]	Test-logloss:0.05876
# [376]	Test-logloss:0.05876
# [377]	Test-logloss:0.05876
# [378]	Test-logloss:0.05876
# [379]	Test-logloss:0.05876
# [380]	Test-logloss:0.05876
# [381]	Test-logloss:0.05876
# [382]	Test-logloss:0.05876
# [383]	Test-logloss:0.05876
# [384]	Test-logloss:0.05876
# [385]	Test-logloss:0.05876
# [386]	Test-logloss:0.05876
# [387]	Test-logloss:0.05876
# [388]	Test-logloss:0.05876
# [389]	Test-logloss:0.05876
# [390]	Test-logloss:0.05876
# [391]	Test-logloss:0.05876
# [392]	Test-logloss:0.05876
# [393]	Test-logloss:0.05876
# [394]	Test-logloss:0.05876
# [395]	Test-logloss:0.05876
# [396]	Test-logloss:0.05876
# [397]	Test-logloss:0.05876
# [398]	Test-logloss:0.05876
# [399]	Test-logloss:0.05876
# [400]	Test-logloss:0.05876
# [401]	Test-logloss:0.05876
# [402]	Test-logloss:0.05876
# [403]	Test-logloss:0.05876
# [404]	Test-logloss:0.05876
# [405]	Test-logloss:0.05876
# [406]	Test-logloss:0.05876
# [407]	Test-logloss:0.05876
# [408]	Test-logloss:0.05876
# [409]	Test-logloss:0.05876
# [410]	Test-logloss:0.05876
# [411]	Test-logloss:0.05876
# [412]	Test-logloss:0.05876
# [413]	Test-logloss:0.05876
# [414]	Test-logloss:0.05876
# [415]	Test-logloss:0.05876
# [416]	Test-logloss:0.05876
# [417]	Test-logloss:0.05876
# [418]	Test-logloss:0.05876
# [419]	Test-logloss:0.05876
# [420]	Test-logloss:0.05876
# [421]	Test-logloss:0.05876
# [422]	Test-logloss:0.05876
# [423]	Test-logloss:0.05876
# [424]	Test-logloss:0.05876
# [425]	Test-logloss:0.05876
# [426]	Test-logloss:0.05876
# [427]	Test-logloss:0.05876
# [428]	Test-logloss:0.05876
# [429]	Test-logloss:0.05876
# [430]	Test-logloss:0.05876
# [431]	Test-logloss:0.05876
# [432]	Test-logloss:0.05876
# [433]	Test-logloss:0.05876
# [434]	Test-logloss:0.05876
# [435]	Test-logloss:0.05876
# [436]	Test-logloss:0.05876
# [437]	Test-logloss:0.05876
# [438]	Test-logloss:0.05876
# [439]	Test-logloss:0.05876
# [440]	Test-logloss:0.05876
# [441]	Test-logloss:0.05876
# [442]	Test-logloss:0.05876
# [443]	Test-logloss:0.05876
# [444]	Test-logloss:0.05876
# [445]	Test-logloss:0.05876
# [446]	Test-logloss:0.05876
# [447]	Test-logloss:0.05876
# [448]	Test-logloss:0.05876
# [449]	Test-logloss:0.05876
# [450]	Test-logloss:0.05876
# [451]	Test-logloss:0.05876
# [452]	Test-logloss:0.05876
# [453]	Test-logloss:0.05876
# [454]	Test-logloss:0.05876
# [455]	Test-logloss:0.05876
# [456]	Test-logloss:0.05876
# [457]	Test-logloss:0.05876
# [458]	Test-logloss:0.05876
# [459]	Test-logloss:0.05876
# [460]	Test-logloss:0.05876
# [461]	Test-logloss:0.05876
# [462]	Test-logloss:0.05876
# [463]	Test-logloss:0.05876
# [464]	Test-logloss:0.05876
# [465]	Test-logloss:0.05876
# [466]	Test-logloss:0.05876
# [467]	Test-logloss:0.05876
# [468]	Test-logloss:0.05876
# [469]	Test-logloss:0.05876
# [470]	Test-logloss:0.05876
# [471]	Test-logloss:0.05876
# [472]	Test-logloss:0.05876
# [473]	Test-logloss:0.05876
# [474]	Test-logloss:0.05876
# [475]	Test-logloss:0.05876
# [476]	Test-logloss:0.05876
# [477]	Test-logloss:0.05876
# [478]	Test-logloss:0.05876
# [479]	Test-logloss:0.05876
# [480]	Test-logloss:0.05876
# [481]	Test-logloss:0.05876
# [482]	Test-logloss:0.05876
# [483]	Test-logloss:0.05876
# [484]	Test-logloss:0.05876
# [485]	Test-logloss:0.05876
# [486]	Test-logloss:0.05876
# [487]	Test-logloss:0.05876
# [488]	Test-logloss:0.05876
# [489]	Test-logloss:0.05876
# [490]	Test-logloss:0.05876
# [491]	Test-logloss:0.05876
# [492]	Test-logloss:0.05876
# [493]	Test-logloss:0.05876
# [494]	Test-logloss:0.05876
# [495]	Test-logloss:0.05876
# [496]	Test-logloss:0.05876
# [497]	Test-logloss:0.05876
# [498]	Test-logloss:0.05876
# [499]	Test-logloss:0.05876
# [500]	Test-logloss:0.05876
# [501]	Test-logloss:0.05876
# [502]	Test-logloss:0.05876
# [503]	Test-logloss:0.05876
# [504]	Test-logloss:0.05876
# [505]	Test-logloss:0.05876
# [506]	Test-logloss:0.05876
# [507]	Test-logloss:0.05876
# [508]	Test-logloss:0.05876
# [509]	Test-logloss:0.05876
# [510]	Test-logloss:0.05876
# [511]	Test-logloss:0.05876
# [512]	Test-logloss:0.05876
# [513]	Test-logloss:0.05876
# [514]	Test-logloss:0.05876
# [515]	Test-logloss:0.05876
# [516]	Test-logloss:0.05876
# [517]	Test-logloss:0.05876
# [518]	Test-logloss:0.05876
# [519]	Test-logloss:0.05876
# [520]	Test-logloss:0.05876
# [521]	Test-logloss:0.05876
# [522]	Test-logloss:0.05876
# [523]	Test-logloss:0.05876
# [524]	Test-logloss:0.05876
# [525]	Test-logloss:0.05876
# [526]	Test-logloss:0.05876
# [527]	Test-logloss:0.05876
# [528]	Test-logloss:0.05876
# [529]	Test-logloss:0.05876
# [530]	Test-logloss:0.05876
# [531]	Test-logloss:0.05876
# [532]	Test-logloss:0.05876
# [533]	Test-logloss:0.05876
# [534]	Test-logloss:0.05876
# [535]	Test-logloss:0.05876
# [536]	Test-logloss:0.05876
# [537]	Test-logloss:0.05876
# [538]	Test-logloss:0.05876
# [539]	Test-logloss:0.05876
# [540]	Test-logloss:0.05876
# [541]	Test-logloss:0.05876
# [542]	Test-logloss:0.05876
# [543]	Test-logloss:0.05876
# [544]	Test-logloss:0.05876
# [545]	Test-logloss:0.05876
# [546]	Test-logloss:0.05876
# [547]	Test-logloss:0.05876
# [548]	Test-logloss:0.05876
# [549]	Test-logloss:0.05876
# [550]	Test-logloss:0.05876
# [551]	Test-logloss:0.05876
# [552]	Test-logloss:0.05876
# [553]	Test-logloss:0.05876
# [554]	Test-logloss:0.05876
# [555]	Test-logloss:0.05876
# [556]	Test-logloss:0.05876
# [557]	Test-logloss:0.05876
# [558]	Test-logloss:0.05876
# [559]	Test-logloss:0.05876
# [560]	Test-logloss:0.05876
# [561]	Test-logloss:0.05876
# [562]	Test-logloss:0.05876
# [563]	Test-logloss:0.05876
# [564]	Test-logloss:0.05876
# [565]	Test-logloss:0.05876
# [566]	Test-logloss:0.05876
# [567]	Test-logloss:0.05876
# [568]	Test-logloss:0.05876
# [569]	Test-logloss:0.05876
# [570]	Test-logloss:0.05876
# [571]	Test-logloss:0.05876
# [572]	Test-logloss:0.05876
# [573]	Test-logloss:0.05876
# [574]	Test-logloss:0.05876
# [575]	Test-logloss:0.05876
# [576]	Test-logloss:0.05876
# [577]	Test-logloss:0.05876
# [578]	Test-logloss:0.05876
# [579]	Test-logloss:0.05876
# [580]	Test-logloss:0.05876
# [581]	Test-logloss:0.05876
# [582]	Test-logloss:0.05876
# [583]	Test-logloss:0.05876
# [584]	Test-logloss:0.05876
# [585]	Test-logloss:0.05876
# [586]	Test-logloss:0.05876
# [587]	Test-logloss:0.05876
# [588]	Test-logloss:0.05876
# [589]	Test-logloss:0.05876
# [590]	Test-logloss:0.05876
# [591]	Test-logloss:0.05876
# [592]	Test-logloss:0.05876
# [593]	Test-logloss:0.05876
# [594]	Test-logloss:0.05876
# [595]	Test-logloss:0.05876
# [596]	Test-logloss:0.05876
# [597]	Test-logloss:0.05876
# [598]	Test-logloss:0.05876
# [599]	Test-logloss:0.05876
# [600]	Test-logloss:0.05876
# [601]	Test-logloss:0.05876
# [602]	Test-logloss:0.05876
# [603]	Test-logloss:0.05876
# [604]	Test-logloss:0.05876
# [605]	Test-logloss:0.05876
# [606]	Test-logloss:0.05876
# [607]	Test-logloss:0.05876
# [608]	Test-logloss:0.05876
# [609]	Test-logloss:0.05876
# [610]	Test-logloss:0.05876
# [611]	Test-logloss:0.05876
# [612]	Test-logloss:0.05876
# [613]	Test-logloss:0.05876
# [614]	Test-logloss:0.05876
# [615]	Test-logloss:0.05876
# [616]	Test-logloss:0.05876
# [617]	Test-logloss:0.05876
# [618]	Test-logloss:0.05876
# [619]	Test-logloss:0.05876
# [620]	Test-logloss:0.05876
# [621]	Test-logloss:0.05876
# [622]	Test-logloss:0.05876
# [623]	Test-logloss:0.05876
# [624]	Test-logloss:0.05876
# [625]	Test-logloss:0.05876
# [626]	Test-logloss:0.05876
# [627]	Test-logloss:0.05876
# [628]	Test-logloss:0.05876
# [629]	Test-logloss:0.05876
# [630]	Test-logloss:0.05876
# [631]	Test-logloss:0.05876
# [632]	Test-logloss:0.05876
# [633]	Test-logloss:0.05876
# [634]	Test-logloss:0.05876
# [635]	Test-logloss:0.05876
# [636]	Test-logloss:0.05876
# [637]	Test-logloss:0.05876
# [638]	Test-logloss:0.05876
# [639]	Test-logloss:0.05876
# [640]	Test-logloss:0.05876
# [641]	Test-logloss:0.05876
# [642]	Test-logloss:0.05876
# [643]	Test-logloss:0.05876
# [644]	Test-logloss:0.05876
# [645]	Test-logloss:0.05876
# [646]	Test-logloss:0.05876
# [647]	Test-logloss:0.05876
# [648]	Test-logloss:0.05876
# [649]	Test-logloss:0.05876
# [650]	Test-logloss:0.05876
# [651]	Test-logloss:0.05876
# [652]	Test-logloss:0.05876
# [653]	Test-logloss:0.05876
# [654]	Test-logloss:0.05876
# [655]	Test-logloss:0.05876
# [656]	Test-logloss:0.05876
# [657]	Test-logloss:0.05876
# [658]	Test-logloss:0.05876
# [659]	Test-logloss:0.05876
# [660]	Test-logloss:0.05876
# [661]	Test-logloss:0.05876
# [662]	Test-logloss:0.05876
# [663]	Test-logloss:0.05876
# [664]	Test-logloss:0.05876
# [665]	Test-logloss:0.05876
# [666]	Test-logloss:0.05876
# [667]	Test-logloss:0.05876
# [668]	Test-logloss:0.05876
# [669]	Test-logloss:0.05876
# [670]	Test-logloss:0.05876
# [671]	Test-logloss:0.05876
# [672]	Test-logloss:0.05876
# [673]	Test-logloss:0.05876
# [674]	Test-logloss:0.05876
# [675]	Test-logloss:0.05876
# [676]	Test-logloss:0.05876
# [677]	Test-logloss:0.05876
# [678]	Test-logloss:0.05876
# [679]	Test-logloss:0.05876
# [680]	Test-logloss:0.05876
# [681]	Test-logloss:0.05876
# [682]	Test-logloss:0.05876
# [683]	Test-logloss:0.05876
# [684]	Test-logloss:0.05876
# [685]	Test-logloss:0.05876
# [686]	Test-logloss:0.05876
# [687]	Test-logloss:0.05876
# [688]	Test-logloss:0.05876
# [689]	Test-logloss:0.05876
# [690]	Test-logloss:0.05876
# [691]	Test-logloss:0.05876
# [692]	Test-logloss:0.05876
# [693]	Test-logloss:0.05876
# [694]	Test-logloss:0.05876
# [695]	Test-logloss:0.05876
# [696]	Test-logloss:0.05876
# [697]	Test-logloss:0.05876
# [698]	Test-logloss:0.05876
# [699]	Test-logloss:0.05876
# [700]	Test-logloss:0.05876
# [701]	Test-logloss:0.05876
# [702]	Test-logloss:0.05876
# [703]	Test-logloss:0.05876
# [704]	Test-logloss:0.05876
# [705]	Test-logloss:0.05876
# [706]	Test-logloss:0.05876
# [707]	Test-logloss:0.05876
# [708]	Test-logloss:0.05876
# [709]	Test-logloss:0.05876
# [710]	Test-logloss:0.05876
# [711]	Test-logloss:0.05876
# [712]	Test-logloss:0.05876
# [713]	Test-logloss:0.05876
# [714]	Test-logloss:0.05876
# [715]	Test-logloss:0.05876
# [716]	Test-logloss:0.05876
# [717]	Test-logloss:0.05876
# [718]	Test-logloss:0.05876
# [719]	Test-logloss:0.05876
# [720]	Test-logloss:0.05876
# [721]	Test-logloss:0.05876
# [722]	Test-logloss:0.05876
# [723]	Test-logloss:0.05876
# [724]	Test-logloss:0.05876
# [725]	Test-logloss:0.05876
# [726]	Test-logloss:0.05876
# [727]	Test-logloss:0.05876
# [728]	Test-logloss:0.05876
# [729]	Test-logloss:0.05876
# [730]	Test-logloss:0.05876
# [731]	Test-logloss:0.05876
# [732]	Test-logloss:0.05876
# [733]	Test-logloss:0.05876
# [734]	Test-logloss:0.05876
# [735]	Test-logloss:0.05876
# [736]	Test-logloss:0.05876
# [737]	Test-logloss:0.05876
# [738]	Test-logloss:0.05876
# [739]	Test-logloss:0.05876
# [740]	Test-logloss:0.05876
# [741]	Test-logloss:0.05876
# [742]	Test-logloss:0.05876
# [743]	Test-logloss:0.05876
# [744]	Test-logloss:0.05876
# [745]	Test-logloss:0.05876
# [746]	Test-logloss:0.05876
# [747]	Test-logloss:0.05876
# [748]	Test-logloss:0.05876
# [749]	Test-logloss:0.05876
# [750]	Test-logloss:0.05876
# [751]	Test-logloss:0.05876
# [752]	Test-logloss:0.05876
# [753]	Test-logloss:0.05876
# [754]	Test-logloss:0.05876
# [755]	Test-logloss:0.05876
# [756]	Test-logloss:0.05876
# [757]	Test-logloss:0.05876
# [758]	Test-logloss:0.05876
# [759]	Test-logloss:0.05876
# [760]	Test-logloss:0.05876
# [761]	Test-logloss:0.05876
# [762]	Test-logloss:0.05876
# [763]	Test-logloss:0.05876
# [764]	Test-logloss:0.05876
# [765]	Test-logloss:0.05876
# [766]	Test-logloss:0.05876
# [767]	Test-logloss:0.05876
# [768]	Test-logloss:0.05876
# [769]	Test-logloss:0.05876
# [770]	Test-logloss:0.05876
# [771]	Test-logloss:0.05876
# [772]	Test-logloss:0.05876
# [773]	Test-logloss:0.05876
# [774]	Test-logloss:0.05876
# [775]	Test-logloss:0.05876
# [776]	Test-logloss:0.05876
# [777]	Test-logloss:0.05876
# [778]	Test-logloss:0.05876
# [779]	Test-logloss:0.05876
# [780]	Test-logloss:0.05876
# [781]	Test-logloss:0.05876
# [782]	Test-logloss:0.05876
# [783]	Test-logloss:0.05876
# [784]	Test-logloss:0.05876
# [785]	Test-logloss:0.05876
# [786]	Test-logloss:0.05876
# [787]	Test-logloss:0.05876
# [788]	Test-logloss:0.05876
# [789]	Test-logloss:0.05876
# [790]	Test-logloss:0.05876
# [791]	Test-logloss:0.05876
# [792]	Test-logloss:0.05876
# [793]	Test-logloss:0.05876
# [794]	Test-logloss:0.05876
# [795]	Test-logloss:0.05876
# [796]	Test-logloss:0.05876
# [797]	Test-logloss:0.05876
# [798]	Test-logloss:0.05876
# [799]	Test-logloss:0.05876
# [800]	Test-logloss:0.05876
# [801]	Test-logloss:0.05876
# [802]	Test-logloss:0.05876
# [803]	Test-logloss:0.05876
# [804]	Test-logloss:0.05876
# [805]	Test-logloss:0.05876
# [806]	Test-logloss:0.05876
# [807]	Test-logloss:0.05876
# [808]	Test-logloss:0.05876
# [809]	Test-logloss:0.05876
# [810]	Test-logloss:0.05876
# [811]	Test-logloss:0.05876
# [812]	Test-logloss:0.05876
# [813]	Test-logloss:0.05876
# [814]	Test-logloss:0.05876
# [815]	Test-logloss:0.05876
# [816]	Test-logloss:0.05876
# [817]	Test-logloss:0.05876
# [818]	Test-logloss:0.05876
# [819]	Test-logloss:0.05876
# [820]	Test-logloss:0.05876
# [821]	Test-logloss:0.05876
# [822]	Test-logloss:0.05876
# [823]	Test-logloss:0.05876
# [824]	Test-logloss:0.05876
# [825]	Test-logloss:0.05876
# [826]	Test-logloss:0.05876
# [827]	Test-logloss:0.05876
# [828]	Test-logloss:0.05876
# [829]	Test-logloss:0.05876
# [830]	Test-logloss:0.05876
# [831]	Test-logloss:0.05876
# [832]	Test-logloss:0.05876
# [833]	Test-logloss:0.05876
# [834]	Test-logloss:0.05876
# [835]	Test-logloss:0.05876
# [836]	Test-logloss:0.05876
# [837]	Test-logloss:0.05876
# [838]	Test-logloss:0.05876
# [839]	Test-logloss:0.05876
# [840]	Test-logloss:0.05876
# [841]	Test-logloss:0.05876
# [842]	Test-logloss:0.05876
# [843]	Test-logloss:0.05876
# [844]	Test-logloss:0.05876
# [845]	Test-logloss:0.05876
# [846]	Test-logloss:0.05876
# [847]	Test-logloss:0.05876
# [848]	Test-logloss:0.05876
# [849]	Test-logloss:0.05876
# [850]	Test-logloss:0.05876
# [851]	Test-logloss:0.05876
# [852]	Test-logloss:0.05876
# [853]	Test-logloss:0.05876
# [854]	Test-logloss:0.05876
# [855]	Test-logloss:0.05876
# [856]	Test-logloss:0.05876
# [857]	Test-logloss:0.05876
# [858]	Test-logloss:0.05876
# [859]	Test-logloss:0.05876
# [860]	Test-logloss:0.05876
# [861]	Test-logloss:0.05876
# [862]	Test-logloss:0.05876
# [863]	Test-logloss:0.05876
# [864]	Test-logloss:0.05876
# [865]	Test-logloss:0.05876
# [866]	Test-logloss:0.05876
# [867]	Test-logloss:0.05876
# [868]	Test-logloss:0.05876
# [869]	Test-logloss:0.05876
# [870]	Test-logloss:0.05876
# [871]	Test-logloss:0.05876
# [872]	Test-logloss:0.05876
# [873]	Test-logloss:0.05876
# [874]	Test-logloss:0.05876
# [875]	Test-logloss:0.05876
# [876]	Test-logloss:0.05876
# [877]	Test-logloss:0.05876
# [878]	Test-logloss:0.05876
# [879]	Test-logloss:0.05876
# [880]	Test-logloss:0.05876
# [881]	Test-logloss:0.05876
# [882]	Test-logloss:0.05876
# [883]	Test-logloss:0.05876
# [884]	Test-logloss:0.05876
# [885]	Test-logloss:0.05876
# [886]	Test-logloss:0.05876
# [887]	Test-logloss:0.05876
# [888]	Test-logloss:0.05876
# [889]	Test-logloss:0.05876
# [890]	Test-logloss:0.05876
# [891]	Test-logloss:0.05876
# [892]	Test-logloss:0.05876
# [893]	Test-logloss:0.05876
# [894]	Test-logloss:0.05876
# [895]	Test-logloss:0.05876
# [896]	Test-logloss:0.05876
# [897]	Test-logloss:0.05876
# [898]	Test-logloss:0.05876
# [899]	Test-logloss:0.05876
# [900]	Test-logloss:0.05876
# [901]	Test-logloss:0.05876
# [902]	Test-logloss:0.05876
# [903]	Test-logloss:0.05876
# [904]	Test-logloss:0.05876
# [905]	Test-logloss:0.05876
# [906]	Test-logloss:0.05876
# [907]	Test-logloss:0.05876
# [908]	Test-logloss:0.05876
# [909]	Test-logloss:0.05876
# [910]	Test-logloss:0.05876
# [911]	Test-logloss:0.05876
# [912]	Test-logloss:0.05876
# [913]	Test-logloss:0.05876
# [914]	Test-logloss:0.05876
# [915]	Test-logloss:0.05876
# [916]	Test-logloss:0.05876
# [917]	Test-logloss:0.05876
# [918]	Test-logloss:0.05876
# [919]	Test-logloss:0.05876
# [920]	Test-logloss:0.05876
# [921]	Test-logloss:0.05876
# [922]	Test-logloss:0.05876
# [923]	Test-logloss:0.05876
# [924]	Test-logloss:0.05876
# [925]	Test-logloss:0.05876
# [926]	Test-logloss:0.05876
# [927]	Test-logloss:0.05876
# [928]	Test-logloss:0.05876
# [929]	Test-logloss:0.05876
# [930]	Test-logloss:0.05876
# [931]	Test-logloss:0.05876
# [932]	Test-logloss:0.05876
# [933]	Test-logloss:0.05876
# [934]	Test-logloss:0.05876
# [935]	Test-logloss:0.05876
# [936]	Test-logloss:0.05876
# [937]	Test-logloss:0.05876
# [938]	Test-logloss:0.05876
# [939]	Test-logloss:0.05876
# [940]	Test-logloss:0.05876
# [941]	Test-logloss:0.05876
# [942]	Test-logloss:0.05876
# [943]	Test-logloss:0.05876
# [944]	Test-logloss:0.05876
# [945]	Test-logloss:0.05876
# [946]	Test-logloss:0.05876
# [947]	Test-logloss:0.05876
# [948]	Test-logloss:0.05876
# [949]	Test-logloss:0.05876
# [950]	Test-logloss:0.05876
# [951]	Test-logloss:0.05876
# [952]	Test-logloss:0.05876
# [953]	Test-logloss:0.05876
# [954]	Test-logloss:0.05876
# [955]	Test-logloss:0.05876
# [956]	Test-logloss:0.05876
# [957]	Test-logloss:0.05876
# [958]	Test-logloss:0.05876
# [959]	Test-logloss:0.05876
# [960]	Test-logloss:0.05876
# [961]	Test-logloss:0.05876
# [962]	Test-logloss:0.05876
# [963]	Test-logloss:0.05876
# [964]	Test-logloss:0.05876
# [965]	Test-logloss:0.05876
# [966]	Test-logloss:0.05876
# [967]	Test-logloss:0.05876
# [968]	Test-logloss:0.05876
# [969]	Test-logloss:0.05876
# [970]	Test-logloss:0.05876
# [971]	Test-logloss:0.05876
# [972]	Test-logloss:0.05876
# [973]	Test-logloss:0.05876
# [974]	Test-logloss:0.05876
# [975]	Test-logloss:0.05876
# [976]	Test-logloss:0.05876
# [977]	Test-logloss:0.05876
# [978]	Test-logloss:0.05876
# [979]	Test-logloss:0.05876
# [980]	Test-logloss:0.05876
# [981]	Test-logloss:0.05876
# [982]	Test-logloss:0.05876
# [983]	Test-logloss:0.05876
# [984]	Test-logloss:0.05876
# [985]	Test-logloss:0.05876
# [986]	Test-logloss:0.05876
# [987]	Test-logloss:0.05876
# [988]	Test-logloss:0.05876
# [989]	Test-logloss:0.05876
# [990]	Test-logloss:0.05876
# [991]	Test-logloss:0.05876
# [992]	Test-logloss:0.05876
# [993]	Test-logloss:0.05876
# [994]	Test-logloss:0.05876
# [995]	Test-logloss:0.05876
# [996]	Test-logloss:0.05876
# [997]	Test-logloss:0.05876
# [998]	Test-logloss:0.05876
# ROC AUC Score: 1.0
# Accuracy: 1.00
#
# Grizzlies
# [0]	Test-logloss:0.64562
# [1]	Test-logloss:0.61246
# [2]	Test-logloss:0.58242
# [3]	Test-logloss:0.56015
# [4]	Test-logloss:0.53495
# [5]	Test-logloss:0.51643
# [6]	Test-logloss:0.48963
# [7]	Test-logloss:0.47388
# [8]	Test-logloss:0.45099
# [9]	Test-logloss:0.43744
# [10]	Test-logloss:0.41779
# [11]	Test-logloss:0.40819
# [12]	Test-logloss:0.39725
# [13]	Test-logloss:0.38355
# [14]	Test-logloss:0.37588
# [15]	Test-logloss:0.36337
# [16]	Test-logloss:0.35486
# [17]	Test-logloss:0.34872
# [18]	Test-logloss:0.33406
# [19]	Test-logloss:0.32876
# [20]	Test-logloss:0.31673
# [21]	Test-logloss:0.31048
# [22]	Test-logloss:0.29980
# [23]	Test-logloss:0.29582
# [24]	Test-logloss:0.29067
# [25]	Test-logloss:0.28001
# [26]	Test-logloss:0.27692
# [27]	Test-logloss:0.26838
# [28]	Test-logloss:0.26434
# [29]	Test-logloss:0.26195
# [30]	Test-logloss:0.25408
# [31]	Test-logloss:0.25073
# [32]	Test-logloss:0.25070
# [33]	Test-logloss:0.24909
# [34]	Test-logloss:0.24147
# [35]	Test-logloss:0.23925
# [36]	Test-logloss:0.23540
# [37]	Test-logloss:0.23126
# [38]	Test-logloss:0.22409
# [39]	Test-logloss:0.22251
# [40]	Test-logloss:0.21935
# [41]	Test-logloss:0.22006
# [42]	Test-logloss:0.21716
# [43]	Test-logloss:0.21603
# [44]	Test-logloss:0.20987
# [45]	Test-logloss:0.20742
# [46]	Test-logloss:0.20658
# [47]	Test-logloss:0.20287
# [48]	Test-logloss:0.19734
# [49]	Test-logloss:0.19668
# [50]	Test-logloss:0.19328
# [51]	Test-logloss:0.19134
# [52]	Test-logloss:0.19244
# [53]	Test-logloss:0.19066
# [54]	Test-logloss:0.18972
# [55]	Test-logloss:0.18668
# [56]	Test-logloss:0.18202
# [57]	Test-logloss:0.18067
# [58]	Test-logloss:0.17713
# [59]	Test-logloss:0.17516
# [60]	Test-logloss:0.17524
# [61]	Test-logloss:0.17107
# [62]	Test-logloss:0.16785
# [63]	Test-logloss:0.16776
# [64]	Test-logloss:0.16387
# [65]	Test-logloss:0.16383
# [66]	Test-logloss:0.16087
# [67]	Test-logloss:0.15877
# [68]	Test-logloss:0.15806
# [69]	Test-logloss:0.15456
# [70]	Test-logloss:0.15189
# [71]	Test-logloss:0.15148
# [72]	Test-logloss:0.14822
# [73]	Test-logloss:0.14917
# [74]	Test-logloss:0.14669
# [75]	Test-logloss:0.14636
# [76]	Test-logloss:0.14448
# [77]	Test-logloss:0.14545
# [78]	Test-logloss:0.14313
# [79]	Test-logloss:0.14023
# [80]	Test-logloss:0.14000
# [81]	Test-logloss:0.13783
# [82]	Test-logloss:0.13878
# [83]	Test-logloss:0.13606
# [84]	Test-logloss:0.13588
# [85]	Test-logloss:0.13386
# [86]	Test-logloss:0.13480
# [87]	Test-logloss:0.13225
# [88]	Test-logloss:0.13035
# [89]	Test-logloss:0.13128
# [90]	Test-logloss:0.13223
# [91]	Test-logloss:0.12985
# [92]	Test-logloss:0.13078
# [93]	Test-logloss:0.12899
# [94]	Test-logloss:0.12993
# [95]	Test-logloss:0.12768
# [96]	Test-logloss:0.12861
# [97]	Test-logloss:0.12936
# [98]	Test-logloss:0.12721
# [99]	Test-logloss:0.12796
# [100]	Test-logloss:0.12589
# [101]	Test-logloss:0.12684
# [102]	Test-logloss:0.12761
# [103]	Test-logloss:0.12840
# [104]	Test-logloss:0.12864
# [105]	Test-logloss:0.12864
# [106]	Test-logloss:0.12864
# [107]	Test-logloss:0.12865
# [108]	Test-logloss:0.12865
# [109]	Test-logloss:0.12865
# ROC AUC Score: 1.0
# Accuracy: 0.89
#
# Rockets
# [0]	Test-logloss:0.66884
# [1]	Test-logloss:0.63444
# [2]	Test-logloss:0.60238
# [3]	Test-logloss:0.57275
# [4]	Test-logloss:0.54509
# [5]	Test-logloss:0.51944
# [6]	Test-logloss:0.49441
# [7]	Test-logloss:0.47582
# [8]	Test-logloss:0.45843
# [9]	Test-logloss:0.43769
# [10]	Test-logloss:0.41887
# [11]	Test-logloss:0.40217
# [12]	Test-logloss:0.38856
# [13]	Test-logloss:0.37273
# [14]	Test-logloss:0.35640
# [15]	Test-logloss:0.34466
# [16]	Test-logloss:0.33116
# [17]	Test-logloss:0.31917
# [18]	Test-logloss:0.30659
# [19]	Test-logloss:0.29783
# [20]	Test-logloss:0.28953
# [21]	Test-logloss:0.27892
# [22]	Test-logloss:0.26784
# [23]	Test-logloss:0.25792
# [24]	Test-logloss:0.25081
# [25]	Test-logloss:0.24179
# [26]	Test-logloss:0.23328
# [27]	Test-logloss:0.22530
# [28]	Test-logloss:0.21773
# [29]	Test-logloss:0.21039
# [30]	Test-logloss:0.20694
# [31]	Test-logloss:0.20272
# [32]	Test-logloss:0.19619
# [33]	Test-logloss:0.18961
# [34]	Test-logloss:0.18608
# [35]	Test-logloss:0.18181
# [36]	Test-logloss:0.17628
# [37]	Test-logloss:0.17113
# [38]	Test-logloss:0.16517
# [39]	Test-logloss:0.16036
# [40]	Test-logloss:0.15492
# [41]	Test-logloss:0.14975
# [42]	Test-logloss:0.14728
# [43]	Test-logloss:0.14252
# [44]	Test-logloss:0.13801
# [45]	Test-logloss:0.13444
# [46]	Test-logloss:0.13062
# [47]	Test-logloss:0.12660
# [48]	Test-logloss:0.12382
# [49]	Test-logloss:0.12013
# [50]	Test-logloss:0.11663
# [51]	Test-logloss:0.11347
# [52]	Test-logloss:0.11061
# [53]	Test-logloss:0.10901
# [54]	Test-logloss:0.10634
# [55]	Test-logloss:0.10429
# [56]	Test-logloss:0.10159
# [57]	Test-logloss:0.09923
# [58]	Test-logloss:0.09788
# [59]	Test-logloss:0.09569
# [60]	Test-logloss:0.09417
# [61]	Test-logloss:0.09253
# [62]	Test-logloss:0.09054
# [63]	Test-logloss:0.08952
# [64]	Test-logloss:0.08828
# [65]	Test-logloss:0.08642
# [66]	Test-logloss:0.08544
# [67]	Test-logloss:0.08385
# [68]	Test-logloss:0.08215
# [69]	Test-logloss:0.08094
# [70]	Test-logloss:0.07935
# [71]	Test-logloss:0.07751
# [72]	Test-logloss:0.07642
# [73]	Test-logloss:0.07497
# [74]	Test-logloss:0.07376
# [75]	Test-logloss:0.07243
# [76]	Test-logloss:0.07110
# [77]	Test-logloss:0.06942
# [78]	Test-logloss:0.06819
# [79]	Test-logloss:0.06746
# [80]	Test-logloss:0.06635
# [81]	Test-logloss:0.06492
# [82]	Test-logloss:0.06394
# [83]	Test-logloss:0.06260
# [84]	Test-logloss:0.06199
# [85]	Test-logloss:0.06103
# [86]	Test-logloss:0.06010
# [87]	Test-logloss:0.05888
# [88]	Test-logloss:0.05835
# [89]	Test-logloss:0.05730
# [90]	Test-logloss:0.05618
# [91]	Test-logloss:0.05570
# [92]	Test-logloss:0.05506
# [93]	Test-logloss:0.05416
# [94]	Test-logloss:0.05339
# [95]	Test-logloss:0.05239
# [96]	Test-logloss:0.05196
# [97]	Test-logloss:0.05119
# [98]	Test-logloss:0.05026
# [99]	Test-logloss:0.04986
# [100]	Test-logloss:0.04899
# [101]	Test-logloss:0.04828
# [102]	Test-logloss:0.04763
# [103]	Test-logloss:0.04697
# [104]	Test-logloss:0.04635
# [105]	Test-logloss:0.04601
# [106]	Test-logloss:0.04550
# [107]	Test-logloss:0.04503
# [108]	Test-logloss:0.04472
# [109]	Test-logloss:0.04411
# [110]	Test-logloss:0.04352
# [111]	Test-logloss:0.04297
# [112]	Test-logloss:0.04268
# [113]	Test-logloss:0.04217
# [114]	Test-logloss:0.04190
# [115]	Test-logloss:0.04136
# [116]	Test-logloss:0.04083
# [117]	Test-logloss:0.04058
# [118]	Test-logloss:0.04016
# [119]	Test-logloss:0.03967
# [120]	Test-logloss:0.03943
# [121]	Test-logloss:0.03918
# [122]	Test-logloss:0.03882
# [123]	Test-logloss:0.03838
# [124]	Test-logloss:0.03806
# [125]	Test-logloss:0.03784
# [126]	Test-logloss:0.03761
# [127]	Test-logloss:0.03716
# [128]	Test-logloss:0.03686
# [129]	Test-logloss:0.03665
# [130]	Test-logloss:0.03630
# [131]	Test-logloss:0.03608
# [132]	Test-logloss:0.03566
# [133]	Test-logloss:0.03547
# [134]	Test-logloss:0.03519
# [135]	Test-logloss:0.03488
# [136]	Test-logloss:0.03451
# [137]	Test-logloss:0.03431
# [138]	Test-logloss:0.03405
# [139]	Test-logloss:0.03387
# [140]	Test-logloss:0.03352
# [141]	Test-logloss:0.03316
# [142]	Test-logloss:0.03297
# [143]	Test-logloss:0.03260
# [144]	Test-logloss:0.03236
# [145]	Test-logloss:0.03219
# [146]	Test-logloss:0.03204
# [147]	Test-logloss:0.03172
# [148]	Test-logloss:0.03137
# [149]	Test-logloss:0.03115
# [150]	Test-logloss:0.03097
# [151]	Test-logloss:0.03064
# [152]	Test-logloss:0.03049
# [153]	Test-logloss:0.03035
# [154]	Test-logloss:0.03002
# [155]	Test-logloss:0.02988
# [156]	Test-logloss:0.02967
# [157]	Test-logloss:0.02938
# [158]	Test-logloss:0.02925
# [159]	Test-logloss:0.02912
# [160]	Test-logloss:0.02896
# [161]	Test-logloss:0.02866
# [162]	Test-logloss:0.02853
# [163]	Test-logloss:0.02833
# [164]	Test-logloss:0.02804
# [165]	Test-logloss:0.02797
# [166]	Test-logloss:0.02785
# [167]	Test-logloss:0.02764
# [168]	Test-logloss:0.02752
# [169]	Test-logloss:0.02724
# [170]	Test-logloss:0.02710
# [171]	Test-logloss:0.02692
# [172]	Test-logloss:0.02685
# [173]	Test-logloss:0.02674
# [174]	Test-logloss:0.02657
# [175]	Test-logloss:0.02638
# [176]	Test-logloss:0.02624
# [177]	Test-logloss:0.02614
# [178]	Test-logloss:0.02597
# [179]	Test-logloss:0.02593
# [180]	Test-logloss:0.02587
# [181]	Test-logloss:0.02571
# [182]	Test-logloss:0.02559
# [183]	Test-logloss:0.02549
# [184]	Test-logloss:0.02545
# [185]	Test-logloss:0.02530
# [186]	Test-logloss:0.02521
# [187]	Test-logloss:0.02509
# [188]	Test-logloss:0.02500
# [189]	Test-logloss:0.02489
# [190]	Test-logloss:0.02484
# [191]	Test-logloss:0.02476
# [192]	Test-logloss:0.02465
# [193]	Test-logloss:0.02458
# [194]	Test-logloss:0.02454
# [195]	Test-logloss:0.02447
# [196]	Test-logloss:0.02444
# [197]	Test-logloss:0.02440
# [198]	Test-logloss:0.02438
# [199]	Test-logloss:0.02435
# [200]	Test-logloss:0.02432
# [201]	Test-logloss:0.02430
# [202]	Test-logloss:0.02439
# [203]	Test-logloss:0.02436
# [204]	Test-logloss:0.02436
# [205]	Test-logloss:0.02436
# [206]	Test-logloss:0.02436
# [207]	Test-logloss:0.02436
# [208]	Test-logloss:0.02436
# [209]	Test-logloss:0.02436
# [210]	Test-logloss:0.02436
# ROC AUC Score: 1.0
# Accuracy: 1.00
#
# Spurs
# [0]	Test-logloss:0.49842
# [1]	Test-logloss:0.49313
# [2]	Test-logloss:0.48239
# [3]	Test-logloss:0.47837
# [4]	Test-logloss:0.46538
# [5]	Test-logloss:0.45942
# [6]	Test-logloss:0.45326
# [7]	Test-logloss:0.44282
# [8]	Test-logloss:0.43507
# [9]	Test-logloss:0.43259
# [10]	Test-logloss:0.42824
# [11]	Test-logloss:0.42499
# [12]	Test-logloss:0.42145
# [13]	Test-logloss:0.41721
# [14]	Test-logloss:0.40940
# [15]	Test-logloss:0.40229
# [16]	Test-logloss:0.39481
# [17]	Test-logloss:0.38774
# [18]	Test-logloss:0.38107
# [19]	Test-logloss:0.37477
# [20]	Test-logloss:0.36882
# [21]	Test-logloss:0.36319
# [22]	Test-logloss:0.35787
# [23]	Test-logloss:0.35430
# [24]	Test-logloss:0.35041
# [25]	Test-logloss:0.34714
# [26]	Test-logloss:0.34268
# [27]	Test-logloss:0.34258
# [28]	Test-logloss:0.33979
# [29]	Test-logloss:0.33719
# [30]	Test-logloss:0.33410
# [31]	Test-logloss:0.33171
# [32]	Test-logloss:0.33368
# [33]	Test-logloss:0.33152
# [34]	Test-logloss:0.32950
# [35]	Test-logloss:0.33153
# [36]	Test-logloss:0.32967
# [37]	Test-logloss:0.32845
# [38]	Test-logloss:0.32673
# [39]	Test-logloss:0.32398
# [40]	Test-logloss:0.32607
# [41]	Test-logloss:0.32460
# [42]	Test-logloss:0.32324
# [43]	Test-logloss:0.32204
# [44]	Test-logloss:0.32080
# [45]	Test-logloss:0.32160
# [46]	Test-logloss:0.32049
# [47]	Test-logloss:0.31868
# [48]	Test-logloss:0.31765
# [49]	Test-logloss:0.31810
# [50]	Test-logloss:0.31717
# [51]	Test-logloss:0.31632
# [52]	Test-logloss:0.31569
# [53]	Test-logloss:0.31330
# [54]	Test-logloss:0.31252
# [55]	Test-logloss:0.31030
# [56]	Test-logloss:0.30961
# [57]	Test-logloss:0.30754
# [58]	Test-logloss:0.30692
# [59]	Test-logloss:0.30501
# [60]	Test-logloss:0.30444
# [61]	Test-logloss:0.30370
# [62]	Test-logloss:0.30226
# [63]	Test-logloss:0.30093
# [64]	Test-logloss:0.29963
# [65]	Test-logloss:0.29857
# [66]	Test-logloss:0.29734
# [67]	Test-logloss:0.29616
# [68]	Test-logloss:0.29504
# [69]	Test-logloss:0.29359
# [70]	Test-logloss:0.29247
# [71]	Test-logloss:0.28936
# [72]	Test-logloss:0.28844
# [73]	Test-logloss:0.28712
# [74]	Test-logloss:0.28542
# [75]	Test-logloss:0.28602
# [76]	Test-logloss:0.28441
# [77]	Test-logloss:0.28506
# [78]	Test-logloss:0.28380
# [79]	Test-logloss:0.28228
# [80]	Test-logloss:0.28295
# [81]	Test-logloss:0.28151
# [82]	Test-logloss:0.28031
# [83]	Test-logloss:0.28084
# [84]	Test-logloss:0.27857
# [85]	Test-logloss:0.27747
# [86]	Test-logloss:0.27529
# [87]	Test-logloss:0.27624
# [88]	Test-logloss:0.27680
# [89]	Test-logloss:0.27470
# [90]	Test-logloss:0.27626
# [91]	Test-logloss:0.27684
# [92]	Test-logloss:0.27840
# [93]	Test-logloss:0.27611
# [94]	Test-logloss:0.27765
# [95]	Test-logloss:0.27825
# [96]	Test-logloss:0.27729
# [97]	Test-logloss:0.27639
# [98]	Test-logloss:0.27553
# ROC AUC Score: 0.8666666666666667
# Accuracy: 0.89
#
# Jazz
# [0]	Test-logloss:0.62446
# [1]	Test-logloss:0.60972
# [2]	Test-logloss:0.59680
# [3]	Test-logloss:0.57707
# [4]	Test-logloss:0.56672
# [5]	Test-logloss:0.54997
# [6]	Test-logloss:0.53475
# [7]	Test-logloss:0.52715
# [8]	Test-logloss:0.52053
# [9]	Test-logloss:0.50605
# [10]	Test-logloss:0.49477
# [11]	Test-logloss:0.48995
# [12]	Test-logloss:0.48583
# [13]	Test-logloss:0.47446
# [14]	Test-logloss:0.46398
# [15]	Test-logloss:0.46110
# [16]	Test-logloss:0.45874
# [17]	Test-logloss:0.44976
# [18]	Test-logloss:0.44810
# [19]	Test-logloss:0.44009
# [20]	Test-logloss:0.43448
# [21]	Test-logloss:0.43364
# [22]	Test-logloss:0.42694
# [23]	Test-logloss:0.42763
# [24]	Test-logloss:0.42341
# [25]	Test-logloss:0.42350
# [26]	Test-logloss:0.41803
# [27]	Test-logloss:0.41958
# [28]	Test-logloss:0.41645
# [29]	Test-logloss:0.40835
# [30]	Test-logloss:0.41035
# [31]	Test-logloss:0.40273
# [32]	Test-logloss:0.39851
# [33]	Test-logloss:0.39673
# [34]	Test-logloss:0.39806
# [35]	Test-logloss:0.39675
# [36]	Test-logloss:0.39526
# [37]	Test-logloss:0.39465
# [38]	Test-logloss:0.39180
# [39]	Test-logloss:0.38829
# [40]	Test-logloss:0.39094
# [41]	Test-logloss:0.38849
# [42]	Test-logloss:0.38850
# [43]	Test-logloss:0.39062
# [44]	Test-logloss:0.39093
# [45]	Test-logloss:0.38887
# [46]	Test-logloss:0.39179
# [47]	Test-logloss:0.39301
# [48]	Test-logloss:0.39120
# ROC AUC Score: 0.9444444444444444
# Accuracy: 0.94
#
# Timberwolves
# [0]	Test-logloss:0.68770
# [1]	Test-logloss:0.66197
# [2]	Test-logloss:0.63261
# [3]	Test-logloss:0.61237
# [4]	Test-logloss:0.58279
# [5]	Test-logloss:0.56633
# [6]	Test-logloss:0.55163
# [7]	Test-logloss:0.53847
# [8]	Test-logloss:0.51560
# [9]	Test-logloss:0.50529
# [10]	Test-logloss:0.48358
# [11]	Test-logloss:0.47262
# [12]	Test-logloss:0.45763
# [13]	Test-logloss:0.44933
# [14]	Test-logloss:0.43183
# [15]	Test-logloss:0.43084
# [16]	Test-logloss:0.41300
# [17]	Test-logloss:0.39792
# [18]	Test-logloss:0.39273
# [19]	Test-logloss:0.37870
# [20]	Test-logloss:0.36495
# [21]	Test-logloss:0.35214
# [22]	Test-logloss:0.34431
# [23]	Test-logloss:0.33266
# [24]	Test-logloss:0.32730
# [25]	Test-logloss:0.31795
# [26]	Test-logloss:0.31006
# [27]	Test-logloss:0.30119
# [28]	Test-logloss:0.29170
# [29]	Test-logloss:0.28526
# [30]	Test-logloss:0.27871
# [31]	Test-logloss:0.27036
# [32]	Test-logloss:0.26694
# [33]	Test-logloss:0.25936
# [34]	Test-logloss:0.25455
# [35]	Test-logloss:0.25262
# [36]	Test-logloss:0.24495
# [37]	Test-logloss:0.23847
# [38]	Test-logloss:0.23339
# [39]	Test-logloss:0.23353
# [40]	Test-logloss:0.22726
# [41]	Test-logloss:0.22420
# [42]	Test-logloss:0.21875
# [43]	Test-logloss:0.21253
# [44]	Test-logloss:0.21134
# [45]	Test-logloss:0.20738
# [46]	Test-logloss:0.20387
# [47]	Test-logloss:0.20043
# [48]	Test-logloss:0.19958
# [49]	Test-logloss:0.19630
# [50]	Test-logloss:0.19413
# [51]	Test-logloss:0.18985
# [52]	Test-logloss:0.18811
# [53]	Test-logloss:0.18760
# [54]	Test-logloss:0.18446
# [55]	Test-logloss:0.18260
# [56]	Test-logloss:0.17800
# [57]	Test-logloss:0.17777
# [58]	Test-logloss:0.17596
# [59]	Test-logloss:0.17497
# [60]	Test-logloss:0.17486
# [61]	Test-logloss:0.17295
# [62]	Test-logloss:0.17084
# [63]	Test-logloss:0.16822
# [64]	Test-logloss:0.16763
# [65]	Test-logloss:0.16769
# [66]	Test-logloss:0.16434
# [67]	Test-logloss:0.16103
# [68]	Test-logloss:0.16131
# [69]	Test-logloss:0.16107
# [70]	Test-logloss:0.15763
# [71]	Test-logloss:0.15446
# [72]	Test-logloss:0.15472
# [73]	Test-logloss:0.15149
# [74]	Test-logloss:0.14928
# [75]	Test-logloss:0.14902
# [76]	Test-logloss:0.14671
# [77]	Test-logloss:0.14465
# [78]	Test-logloss:0.14522
# [79]	Test-logloss:0.14389
# [80]	Test-logloss:0.14183
# [81]	Test-logloss:0.13906
# [82]	Test-logloss:0.13881
# [83]	Test-logloss:0.13674
# [84]	Test-logloss:0.13733
# [85]	Test-logloss:0.13515
# [86]	Test-logloss:0.13456
# [87]	Test-logloss:0.13448
# [88]	Test-logloss:0.13257
# [89]	Test-logloss:0.13069
# [90]	Test-logloss:0.13129
# [91]	Test-logloss:0.13079
# [92]	Test-logloss:0.12898
# [93]	Test-logloss:0.12959
# [94]	Test-logloss:0.12959
# [95]	Test-logloss:0.12763
# [96]	Test-logloss:0.12593
# [97]	Test-logloss:0.12426
# [98]	Test-logloss:0.12486
# [99]	Test-logloss:0.12341
# [100]	Test-logloss:0.12346
# [101]	Test-logloss:0.12311
# [102]	Test-logloss:0.12155
# [103]	Test-logloss:0.12215
# [104]	Test-logloss:0.12061
# [105]	Test-logloss:0.12071
# [106]	Test-logloss:0.11924
# [107]	Test-logloss:0.11777
# [108]	Test-logloss:0.11836
# [109]	Test-logloss:0.11924
# [110]	Test-logloss:0.11799
# [111]	Test-logloss:0.11813
# [112]	Test-logloss:0.11873
# [113]	Test-logloss:0.11734
# [114]	Test-logloss:0.11750
# [115]	Test-logloss:0.11837
# [116]	Test-logloss:0.11722
# [117]	Test-logloss:0.11740
# [118]	Test-logloss:0.11826
# [119]	Test-logloss:0.11878
# [120]	Test-logloss:0.11747
# [121]	Test-logloss:0.11767
# [122]	Test-logloss:0.11640
# [123]	Test-logloss:0.11661
# [124]	Test-logloss:0.11712
# [125]	Test-logloss:0.11734
# [126]	Test-logloss:0.11612
# [127]	Test-logloss:0.11663
# [128]	Test-logloss:0.11686
# [129]	Test-logloss:0.11568
# [130]	Test-logloss:0.11466
# [131]	Test-logloss:0.11516
# [132]	Test-logloss:0.11540
# [133]	Test-logloss:0.11591
# [134]	Test-logloss:0.11472
# [135]	Test-logloss:0.11376
# [136]	Test-logloss:0.11425
# [137]	Test-logloss:0.11385
# [138]	Test-logloss:0.11384
# [139]	Test-logloss:0.11383
# [140]	Test-logloss:0.11383
# [141]	Test-logloss:0.11382
# [142]	Test-logloss:0.11381
# [143]	Test-logloss:0.11381
# [144]	Test-logloss:0.11380
# ROC AUC Score: 1.0
# Accuracy: 0.94
#
# Clippers
# [0]	Test-logloss:0.62856
# [1]	Test-logloss:0.60729
# [2]	Test-logloss:0.58946
# [3]	Test-logloss:0.57163
# [4]	Test-logloss:0.55462
# [5]	Test-logloss:0.54304
# [6]	Test-logloss:0.53200
# [7]	Test-logloss:0.52142
# [8]	Test-logloss:0.51208
# [9]	Test-logloss:0.50462
# [10]	Test-logloss:0.49814
# [11]	Test-logloss:0.48984
# [12]	Test-logloss:0.48464
# [13]	Test-logloss:0.47983
# [14]	Test-logloss:0.47683
# [15]	Test-logloss:0.47337
# [16]	Test-logloss:0.46844
# [17]	Test-logloss:0.46617
# [18]	Test-logloss:0.46442
# [19]	Test-logloss:0.46447
# [20]	Test-logloss:0.46400
# [21]	Test-logloss:0.46308
# [22]	Test-logloss:0.46414
# [23]	Test-logloss:0.45971
# [24]	Test-logloss:0.45674
# [25]	Test-logloss:0.45303
# [26]	Test-logloss:0.44970
# [27]	Test-logloss:0.44672
# [28]	Test-logloss:0.44627
# [29]	Test-logloss:0.44387
# [30]	Test-logloss:0.44658
# [31]	Test-logloss:0.44466
# [32]	Test-logloss:0.44298
# [33]	Test-logloss:0.44359
# [34]	Test-logloss:0.44234
# [35]	Test-logloss:0.44130
# [36]	Test-logloss:0.44267
# [37]	Test-logloss:0.44198
# [38]	Test-logloss:0.43964
# [39]	Test-logloss:0.44257
# [40]	Test-logloss:0.44230
# [41]	Test-logloss:0.44609
# [42]	Test-logloss:0.44421
# [43]	Test-logloss:0.44246
# [44]	Test-logloss:0.44628
# [45]	Test-logloss:0.44484
# [46]	Test-logloss:0.44353
# [47]	Test-logloss:0.44591
# ROC AUC Score: 0.8257575757575757
# Accuracy: 0.94
#
# Kings
# [0]	Test-logloss:0.74556
# [1]	Test-logloss:0.72824
# [2]	Test-logloss:0.71427
# [3]	Test-logloss:0.70237
# [4]	Test-logloss:0.69088
# [5]	Test-logloss:0.67902
# [6]	Test-logloss:0.67180
# [7]	Test-logloss:0.66431
# [8]	Test-logloss:0.65624
# [9]	Test-logloss:0.64929
# [10]	Test-logloss:0.63627
# [11]	Test-logloss:0.63200
# [12]	Test-logloss:0.61750
# [13]	Test-logloss:0.60598
# [14]	Test-logloss:0.60436
# [15]	Test-logloss:0.59216
# [16]	Test-logloss:0.57764
# [17]	Test-logloss:0.57017
# [18]	Test-logloss:0.55718
# [19]	Test-logloss:0.55762
# [20]	Test-logloss:0.54571
# [21]	Test-logloss:0.53344
# [22]	Test-logloss:0.52267
# [23]	Test-logloss:0.50636
# [24]	Test-logloss:0.50535
# [25]	Test-logloss:0.49624
# [26]	Test-logloss:0.48768
# [27]	Test-logloss:0.48803
# [28]	Test-logloss:0.48020
# [29]	Test-logloss:0.47082
# [30]	Test-logloss:0.47164
# [31]	Test-logloss:0.46008
# [32]	Test-logloss:0.45331
# [33]	Test-logloss:0.44704
# [34]	Test-logloss:0.44039
# [35]	Test-logloss:0.43164
# [36]	Test-logloss:0.42410
# [37]	Test-logloss:0.42677
# [38]	Test-logloss:0.42113
# [39]	Test-logloss:0.41189
# [40]	Test-logloss:0.40669
# [41]	Test-logloss:0.40054
# [42]	Test-logloss:0.39436
# [43]	Test-logloss:0.39110
# [44]	Test-logloss:0.38869
# [45]	Test-logloss:0.38099
# [46]	Test-logloss:0.38416
# [47]	Test-logloss:0.37715
# [48]	Test-logloss:0.37531
# [49]	Test-logloss:0.37656
# [50]	Test-logloss:0.37500
# [51]	Test-logloss:0.37251
# [52]	Test-logloss:0.37102
# [53]	Test-logloss:0.36729
# [54]	Test-logloss:0.36904
# [55]	Test-logloss:0.36567
# [56]	Test-logloss:0.36455
# [57]	Test-logloss:0.36220
# [58]	Test-logloss:0.36319
# [59]	Test-logloss:0.36008
# [60]	Test-logloss:0.35666
# [61]	Test-logloss:0.35777
# [62]	Test-logloss:0.35501
# [63]	Test-logloss:0.34994
# [64]	Test-logloss:0.35193
# [65]	Test-logloss:0.35049
# [66]	Test-logloss:0.34704
# [67]	Test-logloss:0.35050
# [68]	Test-logloss:0.34848
# [69]	Test-logloss:0.35184
# [70]	Test-logloss:0.34858
# [71]	Test-logloss:0.34403
# [72]	Test-logloss:0.34221
# [73]	Test-logloss:0.34368
# [74]	Test-logloss:0.34059
# [75]	Test-logloss:0.33887
# [76]	Test-logloss:0.33462
# [77]	Test-logloss:0.33533
# [78]	Test-logloss:0.33244
# [79]	Test-logloss:0.32998
# [80]	Test-logloss:0.33267
# [81]	Test-logloss:0.32870
# [82]	Test-logloss:0.32598
# [83]	Test-logloss:0.32388
# [84]	Test-logloss:0.32165
# [85]	Test-logloss:0.32423
# [86]	Test-logloss:0.32052
# [87]	Test-logloss:0.31798
# [88]	Test-logloss:0.31590
# [89]	Test-logloss:0.31840
# [90]	Test-logloss:0.31489
# [91]	Test-logloss:0.31248
# [92]	Test-logloss:0.31128
# [93]	Test-logloss:0.30937
# [94]	Test-logloss:0.31177
# [95]	Test-logloss:0.30947
# [96]	Test-logloss:0.30617
# [97]	Test-logloss:0.30852
# [98]	Test-logloss:0.30671
# [99]	Test-logloss:0.30454
# [100]	Test-logloss:0.30139
# [101]	Test-logloss:0.30036
# [102]	Test-logloss:0.29829
# [103]	Test-logloss:0.30051
# [104]	Test-logloss:0.29751
# [105]	Test-logloss:0.29589
# [106]	Test-logloss:0.29392
# [107]	Test-logloss:0.29607
# [108]	Test-logloss:0.29321
# [109]	Test-logloss:0.29169
# [110]	Test-logloss:0.28981
# [111]	Test-logloss:0.29190
# [112]	Test-logloss:0.28917
# [113]	Test-logloss:0.28774
# [114]	Test-logloss:0.28596
# [115]	Test-logloss:0.28471
# [116]	Test-logloss:0.28213
# [117]	Test-logloss:0.28079
# [118]	Test-logloss:0.27910
# [119]	Test-logloss:0.28105
# [120]	Test-logloss:0.27943
# [121]	Test-logloss:0.27700
# [122]	Test-logloss:0.27702
# [123]	Test-logloss:0.27542
# [124]	Test-logloss:0.27419
# [125]	Test-logloss:0.27188
# [126]	Test-logloss:0.27078
# [127]	Test-logloss:0.26926
# [128]	Test-logloss:0.26822
# [129]	Test-logloss:0.26676
# [130]	Test-logloss:0.26536
# [131]	Test-logloss:0.26329
# ...
# [409]	Test-logloss:0.26309
# [410]	Test-logloss:0.26309
# [411]	Test-logloss:0.26309
# [412]	Test-logloss:0.26309
# [413]	Test-logloss:0.26309
# [414]	Test-logloss:0.26309
# [415]	Test-logloss:0.26309
# [416]	Test-logloss:0.26309
# [417]	Test-logloss:0.26309
# [418]	Test-logloss:0.26309
# [419]	Test-logloss:0.26309
# [420]	Test-logloss:0.26309
# [421]	Test-logloss:0.26309
# [422]	Test-logloss:0.26309
# [423]	Test-logloss:0.26309
# [424]	Test-logloss:0.26309
# [425]	Test-logloss:0.26309
# [426]	Test-logloss:0.26309
# [427]	Test-logloss:0.26309
# [428]	Test-logloss:0.26309
# [429]	Test-logloss:0.26309
# [430]	Test-logloss:0.26309
# [431]	Test-logloss:0.26309
# [432]	Test-logloss:0.26309
# [433]	Test-logloss:0.26309
# [434]	Test-logloss:0.26309
# [435]	Test-logloss:0.26309
# [436]	Test-logloss:0.26309
# [437]	Test-logloss:0.26309
# [438]	Test-logloss:0.26309
# [439]	Test-logloss:0.26309
# [440]	Test-logloss:0.26309
# [441]	Test-logloss:0.26309
# [442]	Test-logloss:0.26309
# [443]	Test-logloss:0.26309
# [444]	Test-logloss:0.26309
# [445]	Test-logloss:0.26309
# [446]	Test-logloss:0.26309
# [447]	Test-logloss:0.26309
# [448]	Test-logloss:0.26309
# [449]	Test-logloss:0.26309
# [450]	Test-logloss:0.26309
# [451]	Test-logloss:0.26309
# [452]	Test-logloss:0.26309
# [453]	Test-logloss:0.26309
# [454]	Test-logloss:0.26309
# [455]	Test-logloss:0.26309
# [456]	Test-logloss:0.26309
# [457]	Test-logloss:0.26309
# [458]	Test-logloss:0.26309
# [459]	Test-logloss:0.26309
# [460]	Test-logloss:0.26309
# [461]	Test-logloss:0.26309
# [462]	Test-logloss:0.26309
# [463]	Test-logloss:0.26309
# [464]	Test-logloss:0.26309
# [465]	Test-logloss:0.26309
# [466]	Test-logloss:0.26309
# [467]	Test-logloss:0.26309
# [468]	Test-logloss:0.26309
# [469]	Test-logloss:0.26309
# [470]	Test-logloss:0.26309
# [471]	Test-logloss:0.26309
# [472]	Test-logloss:0.26309
# [473]	Test-logloss:0.26309
# [474]	Test-logloss:0.26309
# [475]	Test-logloss:0.26309
# [476]	Test-logloss:0.26309
# [477]	Test-logloss:0.26309
# [478]	Test-logloss:0.26309
# [479]	Test-logloss:0.26309
# [480]	Test-logloss:0.26309
# [481]	Test-logloss:0.26309
# [482]	Test-logloss:0.26309
# [483]	Test-logloss:0.26309
# [484]	Test-logloss:0.26309
# [485]	Test-logloss:0.26309
# [486]	Test-logloss:0.26309
# [487]	Test-logloss:0.26309
# [488]	Test-logloss:0.26309
# [489]	Test-logloss:0.26309
# [490]	Test-logloss:0.26309
# [491]	Test-logloss:0.26309
# [492]	Test-logloss:0.26309
# [493]	Test-logloss:0.26309
# [494]	Test-logloss:0.26309
# [495]	Test-logloss:0.26309
# [496]	Test-logloss:0.26309
# [497]	Test-logloss:0.26309
# [498]	Test-logloss:0.26309
# [499]	Test-logloss:0.26309
# [500]	Test-logloss:0.26309
# [501]	Test-logloss:0.26309
# [502]	Test-logloss:0.26309
# [503]	Test-logloss:0.26309
# [504]	Test-logloss:0.26309
# [505]	Test-logloss:0.26309
# [506]	Test-logloss:0.26309
# [507]	Test-logloss:0.26309
# [508]	Test-logloss:0.26309
# [509]	Test-logloss:0.26309
# [510]	Test-logloss:0.26309
# [511]	Test-logloss:0.26309
# [512]	Test-logloss:0.26309
# [513]	Test-logloss:0.26309
# [514]	Test-logloss:0.26309
# [515]	Test-logloss:0.26309
# [516]	Test-logloss:0.26309
# [517]	Test-logloss:0.26309
# [518]	Test-logloss:0.26309
# [519]	Test-logloss:0.26309
# [520]	Test-logloss:0.26309
# [521]	Test-logloss:0.26309
# [522]	Test-logloss:0.26309
# [523]	Test-logloss:0.26309
# [524]	Test-logloss:0.26309
# [525]	Test-logloss:0.26309
# [526]	Test-logloss:0.26309
# [527]	Test-logloss:0.26309
# [528]	Test-logloss:0.26309
# [529]	Test-logloss:0.26309
# [530]	Test-logloss:0.26309
# [531]	Test-logloss:0.26309
# [532]	Test-logloss:0.26309
# [533]	Test-logloss:0.26309
# [534]	Test-logloss:0.26309
# [535]	Test-logloss:0.26309
# [536]	Test-logloss:0.26309
# [537]	Test-logloss:0.26309
# [538]	Test-logloss:0.26309
# [539]	Test-logloss:0.26309
# [540]	Test-logloss:0.26309
# [541]	Test-logloss:0.26309
# [542]	Test-logloss:0.26309
# [543]	Test-logloss:0.26309
# [544]	Test-logloss:0.26309
# [545]	Test-logloss:0.26309
# [546]	Test-logloss:0.26309
# [547]	Test-logloss:0.26309
# [548]	Test-logloss:0.26309
# [549]	Test-logloss:0.26309
# [550]	Test-logloss:0.26309
# [551]	Test-logloss:0.26309
# [552]	Test-logloss:0.26309
# [553]	Test-logloss:0.26309
# [554]	Test-logloss:0.26309
# [555]	Test-logloss:0.26309
# [556]	Test-logloss:0.26309
# [557]	Test-logloss:0.26309
# [558]	Test-logloss:0.26309
# [559]	Test-logloss:0.26309
# [560]	Test-logloss:0.26309
# [561]	Test-logloss:0.26309
# [562]	Test-logloss:0.26309
# [563]	Test-logloss:0.26309
# [564]	Test-logloss:0.26309
# [565]	Test-logloss:0.26309
# [566]	Test-logloss:0.26309
# [567]	Test-logloss:0.26308
# [568]	Test-logloss:0.26308
# [569]	Test-logloss:0.26308
# [570]	Test-logloss:0.26309
# [571]	Test-logloss:0.26308
# [572]	Test-logloss:0.26308
# [573]	Test-logloss:0.26308
# [574]	Test-logloss:0.26308
# [575]	Test-logloss:0.26308
# [576]	Test-logloss:0.26308
# [577]	Test-logloss:0.26308
# [578]	Test-logloss:0.26308
# [579]	Test-logloss:0.26308
# [580]	Test-logloss:0.26308
# [581]	Test-logloss:0.26308
# [582]	Test-logloss:0.26308
# [583]	Test-logloss:0.26308
# [584]	Test-logloss:0.26308
# [585]	Test-logloss:0.26308
# [586]	Test-logloss:0.26308
# [587]	Test-logloss:0.26308
# [588]	Test-logloss:0.26308
# [589]	Test-logloss:0.26308
# [590]	Test-logloss:0.26308
# [591]	Test-logloss:0.26308
# [592]	Test-logloss:0.26308
# [593]	Test-logloss:0.26308
# [594]	Test-logloss:0.26308
# [595]	Test-logloss:0.26308
# [596]	Test-logloss:0.26308
# [597]	Test-logloss:0.26308
# [598]	Test-logloss:0.26308
# [599]	Test-logloss:0.26308
# [600]	Test-logloss:0.26308
# [601]	Test-logloss:0.26308
# [602]	Test-logloss:0.26308
# [603]	Test-logloss:0.26308
# [604]	Test-logloss:0.26308
# [605]	Test-logloss:0.26308
# [606]	Test-logloss:0.26308
# [607]	Test-logloss:0.26308
# [608]	Test-logloss:0.26308
# [609]	Test-logloss:0.26308
# [610]	Test-logloss:0.26308
# [611]	Test-logloss:0.26308
# [612]	Test-logloss:0.26308
# [613]	Test-logloss:0.26308
# [614]	Test-logloss:0.26308
# [615]	Test-logloss:0.26308
# [616]	Test-logloss:0.26308
# [617]	Test-logloss:0.26308
# [618]	Test-logloss:0.26308
# [619]	Test-logloss:0.26308
# [620]	Test-logloss:0.26308
# [621]	Test-logloss:0.26308
# [622]	Test-logloss:0.26308
# [623]	Test-logloss:0.26308
# [624]	Test-logloss:0.26308
# [625]	Test-logloss:0.26308
# [626]	Test-logloss:0.26308
# [627]	Test-logloss:0.26308
# [628]	Test-logloss:0.26308
# [629]	Test-logloss:0.26308
# [630]	Test-logloss:0.26308
# [631]	Test-logloss:0.26308
# [632]	Test-logloss:0.26308
# [633]	Test-logloss:0.26308
# [634]	Test-logloss:0.26308
# [635]	Test-logloss:0.26308
# [636]	Test-logloss:0.26308
# [637]	Test-logloss:0.26308
# [638]	Test-logloss:0.26308
# [639]	Test-logloss:0.26308
# [640]	Test-logloss:0.26308
# [641]	Test-logloss:0.26308
# [642]	Test-logloss:0.26308
# [643]	Test-logloss:0.26308
# [644]	Test-logloss:0.26308
# [645]	Test-logloss:0.26308
# [646]	Test-logloss:0.26308
# [647]	Test-logloss:0.26308
# [648]	Test-logloss:0.26308
# [649]	Test-logloss:0.26308
# [650]	Test-logloss:0.26308
# [651]	Test-logloss:0.26308
# [652]	Test-logloss:0.26308
# [653]	Test-logloss:0.26308
# [654]	Test-logloss:0.26308
# [655]	Test-logloss:0.26308
# [656]	Test-logloss:0.26308
# [657]	Test-logloss:0.26308
# [658]	Test-logloss:0.26308
# [659]	Test-logloss:0.26308
# [660]	Test-logloss:0.26308
# [661]	Test-logloss:0.26308
# [662]	Test-logloss:0.26308
# [663]	Test-logloss:0.26308
# [664]	Test-logloss:0.26308
# [665]	Test-logloss:0.26308
# [666]	Test-logloss:0.26308
# [667]	Test-logloss:0.26308
# [668]	Test-logloss:0.26308
# [669]	Test-logloss:0.26308
# [670]	Test-logloss:0.26308
# [671]	Test-logloss:0.26308
# [672]	Test-logloss:0.26308
# [673]	Test-logloss:0.26308
# [674]	Test-logloss:0.26308
# [675]	Test-logloss:0.26308
# [676]	Test-logloss:0.26308
# [677]	Test-logloss:0.26308
# [678]	Test-logloss:0.26308
# [679]	Test-logloss:0.26308
# [680]	Test-logloss:0.26308
# [681]	Test-logloss:0.26308
# [682]	Test-logloss:0.26308
# [683]	Test-logloss:0.26308
# [684]	Test-logloss:0.26308
# [685]	Test-logloss:0.26308
# [686]	Test-logloss:0.26308
# [687]	Test-logloss:0.26308
# [688]	Test-logloss:0.26308
# [689]	Test-logloss:0.26308
# [690]	Test-logloss:0.26308
# [691]	Test-logloss:0.26308
# [692]	Test-logloss:0.26308
# [693]	Test-logloss:0.26308
# [694]	Test-logloss:0.26308
# [695]	Test-logloss:0.26308
# [696]	Test-logloss:0.26308
# [697]	Test-logloss:0.26308
# [698]	Test-logloss:0.26308
# [699]	Test-logloss:0.26308
# [700]	Test-logloss:0.26308
# [701]	Test-logloss:0.26308
# [702]	Test-logloss:0.26308
# [703]	Test-logloss:0.26308
# [704]	Test-logloss:0.26308
# [705]	Test-logloss:0.26308
# [706]	Test-logloss:0.26308
# [707]	Test-logloss:0.26308
# [708]	Test-logloss:0.26308
# [709]	Test-logloss:0.26308
# [710]	Test-logloss:0.26308
# [711]	Test-logloss:0.26308
# [712]	Test-logloss:0.26308
# [713]	Test-logloss:0.26308
# [714]	Test-logloss:0.26308
# [715]	Test-logloss:0.26308
# [716]	Test-logloss:0.26308
# [717]	Test-logloss:0.26308
# [718]	Test-logloss:0.26308
# [719]	Test-logloss:0.26308
# [720]	Test-logloss:0.26308
# [721]	Test-logloss:0.26308
# [722]	Test-logloss:0.26308
# [723]	Test-logloss:0.26308
# [724]	Test-logloss:0.26308
# [725]	Test-logloss:0.26308
# [726]	Test-logloss:0.26308
# [727]	Test-logloss:0.26308
# [728]	Test-logloss:0.26308
# [729]	Test-logloss:0.26308
# [730]	Test-logloss:0.26308
# [731]	Test-logloss:0.26308
# [732]	Test-logloss:0.26308
# [733]	Test-logloss:0.26308
# [734]	Test-logloss:0.26308
# [735]	Test-logloss:0.26308
# [736]	Test-logloss:0.26308
# [737]	Test-logloss:0.26308
# [738]	Test-logloss:0.26308
# [739]	Test-logloss:0.26308
# [740]	Test-logloss:0.26308
# [741]	Test-logloss:0.26308
# [742]	Test-logloss:0.26308
# [743]	Test-logloss:0.26308
# [744]	Test-logloss:0.26308
# [745]	Test-logloss:0.26308
# [746]	Test-logloss:0.26308
# [747]	Test-logloss:0.26308
# [748]	Test-logloss:0.26308
# [749]	Test-logloss:0.26308
# [750]	Test-logloss:0.26308
# [751]	Test-logloss:0.26308
# [752]	Test-logloss:0.26308
# [753]	Test-logloss:0.26308
# [754]	Test-logloss:0.26308
# [755]	Test-logloss:0.26308
# [756]	Test-logloss:0.26308
# [757]	Test-logloss:0.26308
# [758]	Test-logloss:0.26308
# [759]	Test-logloss:0.26308
# [760]	Test-logloss:0.26308
# [761]	Test-logloss:0.26308
# [762]	Test-logloss:0.26308
# [763]	Test-logloss:0.26308
# [764]	Test-logloss:0.26308
# [765]	Test-logloss:0.26308
# [766]	Test-logloss:0.26308
# [767]	Test-logloss:0.26308
# [768]	Test-logloss:0.26308
# [769]	Test-logloss:0.26308
# [770]	Test-logloss:0.26308
# [771]	Test-logloss:0.26308
# [772]	Test-logloss:0.26308
# [773]	Test-logloss:0.26308
# [774]	Test-logloss:0.26308
# [775]	Test-logloss:0.26308
# [776]	Test-logloss:0.26308
# [777]	Test-logloss:0.26308
# [778]	Test-logloss:0.26308
# [779]	Test-logloss:0.26308
# [780]	Test-logloss:0.26308
# [781]	Test-logloss:0.26308
# [782]	Test-logloss:0.26308
# [783]	Test-logloss:0.26308
# [784]	Test-logloss:0.26308
# [785]	Test-logloss:0.26308
# [786]	Test-logloss:0.26308
# [787]	Test-logloss:0.26308
# [788]	Test-logloss:0.26308
# [789]	Test-logloss:0.26308
# [790]	Test-logloss:0.26308
# [791]	Test-logloss:0.26308
# [792]	Test-logloss:0.26308
# [793]	Test-logloss:0.26308
# [794]	Test-logloss:0.26308
# [795]	Test-logloss:0.26308
# [796]	Test-logloss:0.26308
# [797]	Test-logloss:0.26308
# [798]	Test-logloss:0.26308
# [799]	Test-logloss:0.26308
# [800]	Test-logloss:0.26308
# [801]	Test-logloss:0.26308
# [802]	Test-logloss:0.26308
# [803]	Test-logloss:0.26308
# [804]	Test-logloss:0.26308
# [805]	Test-logloss:0.26308
# [806]	Test-logloss:0.26308
# [807]	Test-logloss:0.26308
# [808]	Test-logloss:0.26308
# [809]	Test-logloss:0.26308
# [810]	Test-logloss:0.26308
# [811]	Test-logloss:0.26308
# [812]	Test-logloss:0.26308
# [813]	Test-logloss:0.26308
# [814]	Test-logloss:0.26308
# [815]	Test-logloss:0.26308
# [816]	Test-logloss:0.26308
# [817]	Test-logloss:0.26308
# [818]	Test-logloss:0.26308
# [819]	Test-logloss:0.26308
# [820]	Test-logloss:0.26308
# [821]	Test-logloss:0.26308
# [822]	Test-logloss:0.26308
# [823]	Test-logloss:0.26308
# [824]	Test-logloss:0.26308
# [825]	Test-logloss:0.26308
# [826]	Test-logloss:0.26308
# [827]	Test-logloss:0.26308
# [828]	Test-logloss:0.26308
# [829]	Test-logloss:0.26308
# [830]	Test-logloss:0.26308
# [831]	Test-logloss:0.26308
# [832]	Test-logloss:0.26308
# [833]	Test-logloss:0.26308
# [834]	Test-logloss:0.26308
# [835]	Test-logloss:0.26308
# [836]	Test-logloss:0.26308
# [837]	Test-logloss:0.26308
# [838]	Test-logloss:0.26308
# [839]	Test-logloss:0.26308
# [840]	Test-logloss:0.26308
# [841]	Test-logloss:0.26308
# [842]	Test-logloss:0.26308
# [843]	Test-logloss:0.26308
# [844]	Test-logloss:0.26308
# [845]	Test-logloss:0.26308
# [846]	Test-logloss:0.26308
# [847]	Test-logloss:0.26308
# [848]	Test-logloss:0.26308
# [849]	Test-logloss:0.26308
# [850]	Test-logloss:0.26308
# [851]	Test-logloss:0.26308
# [852]	Test-logloss:0.26308
# [853]	Test-logloss:0.26308
# [854]	Test-logloss:0.26308
# [855]	Test-logloss:0.26308
# [856]	Test-logloss:0.26308
# [857]	Test-logloss:0.26308
# [858]	Test-logloss:0.26308
# [859]	Test-logloss:0.26308
# [860]	Test-logloss:0.26308
# [861]	Test-logloss:0.26308
# [862]	Test-logloss:0.26308
# [863]	Test-logloss:0.26308
# [864]	Test-logloss:0.26308
# [865]	Test-logloss:0.26308
# [866]	Test-logloss:0.26308
# [867]	Test-logloss:0.26308
# [868]	Test-logloss:0.26308
# [869]	Test-logloss:0.26308
# [870]	Test-logloss:0.26308
# [871]	Test-logloss:0.26308
# [872]	Test-logloss:0.26308
# [873]	Test-logloss:0.26308
# [874]	Test-logloss:0.26308
# [875]	Test-logloss:0.26308
# [876]	Test-logloss:0.26308
# [877]	Test-logloss:0.26308
# [878]	Test-logloss:0.26308
# [879]	Test-logloss:0.26308
# [880]	Test-logloss:0.26308
# [881]	Test-logloss:0.26308
# [882]	Test-logloss:0.26308
# [883]	Test-logloss:0.26308
# [884]	Test-logloss:0.26308
# [885]	Test-logloss:0.26308
# [886]	Test-logloss:0.26308
# [887]	Test-logloss:0.26308
# [888]	Test-logloss:0.26308
# [889]	Test-logloss:0.26308
# [890]	Test-logloss:0.26308
# [891]	Test-logloss:0.26308
# [892]	Test-logloss:0.26308
# [893]	Test-logloss:0.26308
# [894]	Test-logloss:0.26308
# [895]	Test-logloss:0.26308
# [896]	Test-logloss:0.26308
# [897]	Test-logloss:0.26308
# [898]	Test-logloss:0.26308
# [899]	Test-logloss:0.26308
# [900]	Test-logloss:0.26308
# [901]	Test-logloss:0.26308
# [902]	Test-logloss:0.26308
# [903]	Test-logloss:0.26308
# [904]	Test-logloss:0.26308
# [905]	Test-logloss:0.26308
# [906]	Test-logloss:0.26308
# [907]	Test-logloss:0.26308
# [908]	Test-logloss:0.26308
# [909]	Test-logloss:0.26308
# [910]	Test-logloss:0.26308
# [911]	Test-logloss:0.26308
# [912]	Test-logloss:0.26308
# [913]	Test-logloss:0.26308
# [914]	Test-logloss:0.26308
# [915]	Test-logloss:0.26308
# [916]	Test-logloss:0.26308
# [917]	Test-logloss:0.26308
# [918]	Test-logloss:0.26308
# [919]	Test-logloss:0.26308
# [920]	Test-logloss:0.26308
# [921]	Test-logloss:0.26308
# [922]	Test-logloss:0.26308
# [923]	Test-logloss:0.26308
# [924]	Test-logloss:0.26308
# [925]	Test-logloss:0.26308
# [926]	Test-logloss:0.26308
# [927]	Test-logloss:0.26308
# [928]	Test-logloss:0.26308
# [929]	Test-logloss:0.26308
# [930]	Test-logloss:0.26308
# [931]	Test-logloss:0.26308
# [932]	Test-logloss:0.26308
# [933]	Test-logloss:0.26308
# [934]	Test-logloss:0.26308
# [935]	Test-logloss:0.26308
# [936]	Test-logloss:0.26308
# [937]	Test-logloss:0.26308
# [938]	Test-logloss:0.26308
# [939]	Test-logloss:0.26308
# [940]	Test-logloss:0.26308
# [941]	Test-logloss:0.26308
# [942]	Test-logloss:0.26308
# [943]	Test-logloss:0.26308
# [944]	Test-logloss:0.26308
# [945]	Test-logloss:0.26308
# [946]	Test-logloss:0.26308
# [947]	Test-logloss:0.26308
# [948]	Test-logloss:0.26308
# [949]	Test-logloss:0.26308
# [950]	Test-logloss:0.26308
# [951]	Test-logloss:0.26308
# [952]	Test-logloss:0.26308
# [953]	Test-logloss:0.26308
# [954]	Test-logloss:0.26308
# [955]	Test-logloss:0.26308
# [956]	Test-logloss:0.26308
# [957]	Test-logloss:0.26308
# [958]	Test-logloss:0.26308
# [959]	Test-logloss:0.26308
# [960]	Test-logloss:0.26308
# [961]	Test-logloss:0.26308
# [962]	Test-logloss:0.26308
# [963]	Test-logloss:0.26308
# [964]	Test-logloss:0.26308
# [965]	Test-logloss:0.26308
# [966]	Test-logloss:0.26308
# [967]	Test-logloss:0.26308
# [968]	Test-logloss:0.26308
# [969]	Test-logloss:0.26308
# [970]	Test-logloss:0.26308
# [971]	Test-logloss:0.26308
# [972]	Test-logloss:0.26308
# [973]	Test-logloss:0.26308
# [974]	Test-logloss:0.26308
# [975]	Test-logloss:0.26308
# [976]	Test-logloss:0.26308
# [977]	Test-logloss:0.26308
# [978]	Test-logloss:0.26308
# [979]	Test-logloss:0.26308
# [980]	Test-logloss:0.26308
# [981]	Test-logloss:0.26308
# [982]	Test-logloss:0.26308
# [983]	Test-logloss:0.26308
# [984]	Test-logloss:0.26308
# [985]	Test-logloss:0.26308
# [986]	Test-logloss:0.26308
# [987]	Test-logloss:0.26308
# [988]	Test-logloss:0.26308
# [989]	Test-logloss:0.26308
# [990]	Test-logloss:0.26308
# [991]	Test-logloss:0.26308
# [992]	Test-logloss:0.26308
# [993]	Test-logloss:0.26308
# [994]	Test-logloss:0.26308
# [995]	Test-logloss:0.26308
# [996]	Test-logloss:0.26308
# [997]	Test-logloss:0.26308
# [998]	Test-logloss:0.26308
# ROC AUC Score: 0.9722222222222222
# Accuracy: 0.89

# %%
# Get models for teams ##################################
print("Pistons")
get_data_and_xgb_rf_models(season, "Pistons")
print()

# print("Nets")
# get_data_and_xgb_rf_models(season, "Nets")
# print()

# print("Magic")
# get_data_and_xgb_rf_models(season, "Magic")
# print()

print("Nuggets")
get_data_and_xgb_rf_models(season, "Nuggets")
print()

# print("Heat")
# get_data_and_xgb_rf_models(season, "Heat")
# print()

# print("Bulls")
# get_data_and_xgb_rf_models(season, "Bulls")
# print()

# print("Hornets")
# get_data_and_xgb_rf_models(season, "Hornets")
# print()

# print("Cavaliers")
# get_data_and_xgb_rf_models(season, "Cavaliers")
# print()

print("Pelicans")
get_data_and_xgb_rf_models(season, "Pelicans")
print()

print("Warriors")
get_data_and_xgb_rf_models(season, "Warriors")
print()

print("Suns")
get_data_and_xgb_rf_models(season, "Suns")
print()

print("Mavericks")
get_data_and_xgb_rf_models(season, "Mavericks")
print()

print("Lakers")
get_data_and_xgb_rf_models(season, "Lakers")
print()

# print("Hawks")
# get_data_and_xgb_rf_models(season, "Hawks")
# print()

print("Trail Blazers")
get_data_and_xgb_rf_models(season, "Trail Blazers")
print()
#########################################################
# Out:
# Pistons
# [0]	Test-logloss:0.53321
# [1]	Test-logloss:0.52151
# [2]	Test-logloss:0.51142
# [3]	Test-logloss:0.50271
# [4]	Test-logloss:0.49523
# [5]	Test-logloss:0.48103
# [6]	Test-logloss:0.47484
# [7]	Test-logloss:0.46076
# [8]	Test-logloss:0.45566
# [9]	Test-logloss:0.44500
# [10]	Test-logloss:0.44024
# [11]	Test-logloss:0.43496
# [12]	Test-logloss:0.42461
# [13]	Test-logloss:0.42308
# [14]	Test-logloss:0.42050
# [15]	Test-logloss:0.41244
# [16]	Test-logloss:0.40794
# [17]	Test-logloss:0.40695
# [18]	Test-logloss:0.40043
# [19]	Test-logloss:0.39932
# [20]	Test-logloss:0.39935
# [21]	Test-logloss:0.39877
# [22]	Test-logloss:0.39255
# [23]	Test-logloss:0.39135
# [24]	Test-logloss:0.38908
# [25]	Test-logloss:0.38438
# [26]	Test-logloss:0.38446
# [27]	Test-logloss:0.38540
# [28]	Test-logloss:0.37909
# [29]	Test-logloss:0.37870
# [30]	Test-logloss:0.37812
# [31]	Test-logloss:0.37427
# [32]	Test-logloss:0.37320
# [33]	Test-logloss:0.37465
# [34]	Test-logloss:0.37125
# [35]	Test-logloss:0.37030
# [36]	Test-logloss:0.36976
# [37]	Test-logloss:0.36581
# [38]	Test-logloss:0.36602
# [39]	Test-logloss:0.36568
# [40]	Test-logloss:0.36610
# [41]	Test-logloss:0.36245
# [42]	Test-logloss:0.36378
# [43]	Test-logloss:0.36391
# [44]	Test-logloss:0.36049
# [45]	Test-logloss:0.36193
# [46]	Test-logloss:0.35872
# [47]	Test-logloss:0.35944
# [48]	Test-logloss:0.35485
# [49]	Test-logloss:0.35561
# [50]	Test-logloss:0.35121
# [51]	Test-logloss:0.35256
# [52]	Test-logloss:0.34835
# [53]	Test-logloss:0.34557
# [54]	Test-logloss:0.34637
# [55]	Test-logloss:0.34190
# [56]	Test-logloss:0.34276
# [57]	Test-logloss:0.33848
# [58]	Test-logloss:0.33987
# [59]	Test-logloss:0.33739
# [60]	Test-logloss:0.33829
# [61]	Test-logloss:0.33427
# [62]	Test-logloss:0.33196
# [63]	Test-logloss:0.33338
# [64]	Test-logloss:0.32961
# [65]	Test-logloss:0.33050
# [66]	Test-logloss:0.32687
# [67]	Test-logloss:0.32781
# [68]	Test-logloss:0.32573
# [69]	Test-logloss:0.32716
# [70]	Test-logloss:0.32374
# [71]	Test-logloss:0.32468
# [72]	Test-logloss:0.32138
# [73]	Test-logloss:0.32235
# [74]	Test-logloss:0.32046
# [75]	Test-logloss:0.31733
# [76]	Test-logloss:0.31873
# [77]	Test-logloss:0.31970
# [78]	Test-logloss:0.31614
# [79]	Test-logloss:0.31444
# [80]	Test-logloss:0.31107
# [81]	Test-logloss:0.30949
# [82]	Test-logloss:0.30629
# [83]	Test-logloss:0.30482
# [84]	Test-logloss:0.30549
# [85]	Test-logloss:0.30246
# [86]	Test-logloss:0.30314
# [87]	Test-logloss:0.30384
# [88]	Test-logloss:0.30456
# [89]	Test-logloss:0.30529
# [90]	Test-logloss:0.30604
# [91]	Test-logloss:0.30649
# [92]	Test-logloss:0.30726
# [93]	Test-logloss:0.30803
# [94]	Test-logloss:0.30881
# ROC AUC Score: 0.9134615384615384
# Accuracy: 0.88
#
# Nuggets
# [0]	Test-logloss:0.51761
# [1]	Test-logloss:0.50038
# [2]	Test-logloss:0.48074
# [3]	Test-logloss:0.46381
# [4]	Test-logloss:0.44309
# [5]	Test-logloss:0.42734
# [6]	Test-logloss:0.40949
# [7]	Test-logloss:0.39367
# [8]	Test-logloss:0.38056
# [9]	Test-logloss:0.36658
# [10]	Test-logloss:0.35353
# [11]	Test-logloss:0.34241
# [12]	Test-logloss:0.33105
# [13]	Test-logloss:0.31662
# [14]	Test-logloss:0.30992
# [15]	Test-logloss:0.29958
# [16]	Test-logloss:0.28987
# [17]	Test-logloss:0.28079
# [18]	Test-logloss:0.27449
# [19]	Test-logloss:0.26637
# [20]	Test-logloss:0.25878
# [21]	Test-logloss:0.25168
# [22]	Test-logloss:0.24456
# [23]	Test-logloss:0.23963
# [24]	Test-logloss:0.23357
# [25]	Test-logloss:0.22773
# [26]	Test-logloss:0.22226
# [27]	Test-logloss:0.21581
# [28]	Test-logloss:0.21158
# [29]	Test-logloss:0.20723
# [30]	Test-logloss:0.20160
# [31]	Test-logloss:0.19769
# [32]	Test-logloss:0.19404
# [33]	Test-logloss:0.18815
# [34]	Test-logloss:0.18310
# [35]	Test-logloss:0.17988
# [36]	Test-logloss:0.17680
# [37]	Test-logloss:0.17285
# [38]	Test-logloss:0.16997
# [39]	Test-logloss:0.16513
# [40]	Test-logloss:0.16264
# [41]	Test-logloss:0.16021
# [42]	Test-logloss:0.15777
# [43]	Test-logloss:0.15321
# [44]	Test-logloss:0.15113
# [45]	Test-logloss:0.14737
# [46]	Test-logloss:0.14379
# [47]	Test-logloss:0.14200
# [48]	Test-logloss:0.13882
# [49]	Test-logloss:0.13721
# [50]	Test-logloss:0.13447
# [51]	Test-logloss:0.13083
# [52]	Test-logloss:0.12925
# [53]	Test-logloss:0.12792
# [54]	Test-logloss:0.12633
# [55]	Test-logloss:0.12385
# [56]	Test-logloss:0.12271
# [57]	Test-logloss:0.12053
# [58]	Test-logloss:0.11950
# [59]	Test-logloss:0.11745
# [60]	Test-logloss:0.11652
# [61]	Test-logloss:0.11464
# [62]	Test-logloss:0.11383
# [63]	Test-logloss:0.11154
# [64]	Test-logloss:0.11024
# [65]	Test-logloss:0.10858
# [66]	Test-logloss:0.10690
# [67]	Test-logloss:0.10634
# [68]	Test-logloss:0.10396
# [69]	Test-logloss:0.10142
# [70]	Test-logloss:0.09976
# [71]	Test-logloss:0.09922
# [72]	Test-logloss:0.09776
# [73]	Test-logloss:0.09729
# [74]	Test-logloss:0.09626
# [75]	Test-logloss:0.09500
# [76]	Test-logloss:0.09366
# [77]	Test-logloss:0.09361
# [78]	Test-logloss:0.09245
# [79]	Test-logloss:0.09075
# [80]	Test-logloss:0.09070
# [81]	Test-logloss:0.08914
# [82]	Test-logloss:0.08825
# [83]	Test-logloss:0.08668
# [84]	Test-logloss:0.08552
# [85]	Test-logloss:0.08470
# [86]	Test-logloss:0.08323
# [87]	Test-logloss:0.08245
# [88]	Test-logloss:0.08138
# [89]	Test-logloss:0.08046
# [90]	Test-logloss:0.07910
# [91]	Test-logloss:0.07811
# [92]	Test-logloss:0.07743
# [93]	Test-logloss:0.07615
# [94]	Test-logloss:0.07521
# [95]	Test-logloss:0.07441
# [96]	Test-logloss:0.07321
# [97]	Test-logloss:0.07234
# [98]	Test-logloss:0.07175
# [99]	Test-logloss:0.07062
# [100]	Test-logloss:0.07007
# [101]	Test-logloss:0.06899
# [102]	Test-logloss:0.06847
# [103]	Test-logloss:0.06743
# [104]	Test-logloss:0.06695
# [105]	Test-logloss:0.06596
# [106]	Test-logloss:0.06579
# [107]	Test-logloss:0.06564
# [108]	Test-logloss:0.06577
# [109]	Test-logloss:0.06564
# [110]	Test-logloss:0.06579
# [111]	Test-logloss:0.06536
# [112]	Test-logloss:0.06525
# [113]	Test-logloss:0.06484
# [114]	Test-logloss:0.06500
# [115]	Test-logloss:0.06461
# [116]	Test-logloss:0.06478
# [117]	Test-logloss:0.06441
# [118]	Test-logloss:0.06459
# [119]	Test-logloss:0.06424
# [120]	Test-logloss:0.06391
# [121]	Test-logloss:0.06377
# [122]	Test-logloss:0.06346
# [123]	Test-logloss:0.06337
# [124]	Test-logloss:0.06337
# [125]	Test-logloss:0.06337
# [126]	Test-logloss:0.06337
# [127]	Test-logloss:0.06337
# [128]	Test-logloss:0.06337
# [129]	Test-logloss:0.06337
# [130]	Test-logloss:0.06337
# [131]	Test-logloss:0.06337
# [132]	Test-logloss:0.06337
# ROC AUC Score: 1.0
# Accuracy: 1.00
#
# Pelicans
# [0]	Test-logloss:0.66556
# [1]	Test-logloss:0.63245
# [2]	Test-logloss:0.60229
# [3]	Test-logloss:0.57473
# [4]	Test-logloss:0.54946
# [5]	Test-logloss:0.53301
# [6]	Test-logloss:0.51089
# [7]	Test-logloss:0.50205
# [8]	Test-logloss:0.48229
# [9]	Test-logloss:0.47038
# [10]	Test-logloss:0.45817
# [11]	Test-logloss:0.44124
# [12]	Test-logloss:0.42366
# [13]	Test-logloss:0.40734
# [14]	Test-logloss:0.39216
# [15]	Test-logloss:0.38376
# [16]	Test-logloss:0.37034
# [17]	Test-logloss:0.35806
# [18]	Test-logloss:0.34611
# [19]	Test-logloss:0.33498
# [20]	Test-logloss:0.32991
# [21]	Test-logloss:0.31996
# [22]	Test-logloss:0.31068
# [23]	Test-logloss:0.29973
# [24]	Test-logloss:0.29147
# [25]	Test-logloss:0.28376
# [26]	Test-logloss:0.27985
# [27]	Test-logloss:0.27285
# [28]	Test-logloss:0.26389
# [29]	Test-logloss:0.25766
# [30]	Test-logloss:0.25184
# [31]	Test-logloss:0.24374
# [32]	Test-logloss:0.24115
# [33]	Test-logloss:0.23465
# [34]	Test-logloss:0.22749
# [35]	Test-logloss:0.22367
# [36]	Test-logloss:0.21706
# [37]	Test-logloss:0.21359
# [38]	Test-logloss:0.20961
# [39]	Test-logloss:0.20348
# [40]	Test-logloss:0.20025
# [41]	Test-logloss:0.19685
# [42]	Test-logloss:0.19345
# [43]	Test-logloss:0.18775
# [44]	Test-logloss:0.18530
# [45]	Test-logloss:0.17989
# [46]	Test-logloss:0.17768
# [47]	Test-logloss:0.17520
# [48]	Test-logloss:0.17006
# [49]	Test-logloss:0.16746
# [50]	Test-logloss:0.16426
# [51]	Test-logloss:0.16393
# [52]	Test-logloss:0.15948
# [53]	Test-logloss:0.15687
# [54]	Test-logloss:0.15574
# [55]	Test-logloss:0.15243
# [56]	Test-logloss:0.15259
# [57]	Test-logloss:0.14866
# [58]	Test-logloss:0.14637
# [59]	Test-logloss:0.14509
# [60]	Test-logloss:0.14333
# [61]	Test-logloss:0.14221
# [62]	Test-logloss:0.13959
# [63]	Test-logloss:0.13705
# [64]	Test-logloss:0.13651
# [65]	Test-logloss:0.13502
# [66]	Test-logloss:0.13486
# [67]	Test-logloss:0.13250
# [68]	Test-logloss:0.12997
# [69]	Test-logloss:0.12948
# [70]	Test-logloss:0.12728
# [71]	Test-logloss:0.12474
# [72]	Test-logloss:0.12507
# [73]	Test-logloss:0.12301
# [74]	Test-logloss:0.12064
# [75]	Test-logloss:0.12077
# [76]	Test-logloss:0.11839
# [77]	Test-logloss:0.11624
# [78]	Test-logloss:0.11587
# [79]	Test-logloss:0.11407
# [80]	Test-logloss:0.11425
# [81]	Test-logloss:0.11445
# [82]	Test-logloss:0.11275
# [83]	Test-logloss:0.11100
# [84]	Test-logloss:0.10966
# [85]	Test-logloss:0.10988
# [86]	Test-logloss:0.10788
# [87]	Test-logloss:0.10634
# [88]	Test-logloss:0.10476
# [89]	Test-logloss:0.10500
# [90]	Test-logloss:0.10316
# [91]	Test-logloss:0.10173
# [92]	Test-logloss:0.10214
# [93]	Test-logloss:0.10240
# [94]	Test-logloss:0.10095
# [95]	Test-logloss:0.09960
# [96]	Test-logloss:0.09975
# [97]	Test-logloss:0.10019
# [98]	Test-logloss:0.10048
# [99]	Test-logloss:0.09920
# [100]	Test-logloss:0.09786
# [101]	Test-logloss:0.09830
# [102]	Test-logloss:0.09851
# [103]	Test-logloss:0.09727
# [104]	Test-logloss:0.09774
# [105]	Test-logloss:0.09798
# [106]	Test-logloss:0.09678
# [107]	Test-logloss:0.09554
# [108]	Test-logloss:0.09601
# [109]	Test-logloss:0.09487
# [110]	Test-logloss:0.09369
# [111]	Test-logloss:0.09416
# [112]	Test-logloss:0.09307
# [113]	Test-logloss:0.09195
# [114]	Test-logloss:0.09219
# [115]	Test-logloss:0.09266
# [116]	Test-logloss:0.09315
# [117]	Test-logloss:0.09363
# [118]	Test-logloss:0.09413
# [119]	Test-logloss:0.09368
# [120]	Test-logloss:0.09368
# [121]	Test-logloss:0.09368
# [122]	Test-logloss:0.09367
# ROC AUC Score: 1.0
# Accuracy: 0.94
#
# Warriors
# [0]	Test-logloss:0.65031
# [1]	Test-logloss:0.61554
# [2]	Test-logloss:0.58687
# [3]	Test-logloss:0.55741
# [4]	Test-logloss:0.53217
# [5]	Test-logloss:0.50788
# [6]	Test-logloss:0.48450
# [7]	Test-logloss:0.46381
# [8]	Test-logloss:0.44658
# [9]	Test-logloss:0.43072
# [10]	Test-logloss:0.41611
# [11]	Test-logloss:0.40224
# [12]	Test-logloss:0.38738
# [13]	Test-logloss:0.37572
# [14]	Test-logloss:0.36460
# [15]	Test-logloss:0.35011
# [16]	Test-logloss:0.34034
# [17]	Test-logloss:0.33126
# [18]	Test-logloss:0.32288
# [19]	Test-logloss:0.31511
# [20]	Test-logloss:0.30357
# [21]	Test-logloss:0.29681
# [22]	Test-logloss:0.28828
# [23]	Test-logloss:0.28239
# [24]	Test-logloss:0.27694
# [25]	Test-logloss:0.26730
# [26]	Test-logloss:0.26251
# [27]	Test-logloss:0.25808
# [28]	Test-logloss:0.25171
# [29]	Test-logloss:0.24462
# [30]	Test-logloss:0.24090
# [31]	Test-logloss:0.23283
# [32]	Test-logloss:0.22822
# [33]	Test-logloss:0.22238
# [34]	Test-logloss:0.21819
# [35]	Test-logloss:0.21344
# [36]	Test-logloss:0.20797
# [37]	Test-logloss:0.20561
# [38]	Test-logloss:0.20058
# [39]	Test-logloss:0.19857
# [40]	Test-logloss:0.19395
# [41]	Test-logloss:0.18945
# [42]	Test-logloss:0.18545
# [43]	Test-logloss:0.18127
# [44]	Test-logloss:0.17910
# [45]	Test-logloss:0.17589
# [46]	Test-logloss:0.17210
# [47]	Test-logloss:0.17080
# [48]	Test-logloss:0.16681
# [49]	Test-logloss:0.16356
# [50]	Test-logloss:0.16242
# [51]	Test-logloss:0.15917
# [52]	Test-logloss:0.15965
# [53]	Test-logloss:0.15596
# [54]	Test-logloss:0.15295
# [55]	Test-logloss:0.15211
# [56]	Test-logloss:0.14880
# [57]	Test-logloss:0.14806
# [58]	Test-logloss:0.14518
# [59]	Test-logloss:0.14257
# [60]	Test-logloss:0.14313
# [61]	Test-logloss:0.14123
# [62]	Test-logloss:0.14185
# [63]	Test-logloss:0.13947
# [64]	Test-logloss:0.13768
# [65]	Test-logloss:0.13830
# [66]	Test-logloss:0.13607
# [67]	Test-logloss:0.13580
# [68]	Test-logloss:0.13543
# [69]	Test-logloss:0.13336
# [70]	Test-logloss:0.13123
# [71]	Test-logloss:0.13103
# [72]	Test-logloss:0.13169
# [73]	Test-logloss:0.13031
# [74]	Test-logloss:0.12834
# [75]	Test-logloss:0.12820
# [76]	Test-logloss:0.12816
# [77]	Test-logloss:0.12692
# [78]	Test-logloss:0.12478
# [79]	Test-logloss:0.12496
# [80]	Test-logloss:0.12324
# [81]	Test-logloss:0.12159
# [82]	Test-logloss:0.12176
# [83]	Test-logloss:0.11979
# [84]	Test-logloss:0.12000
# [85]	Test-logloss:0.11799
# [86]	Test-logloss:0.11615
# [87]	Test-logloss:0.11638
# [88]	Test-logloss:0.11451
# [89]	Test-logloss:0.11476
# [90]	Test-logloss:0.11304
# [91]	Test-logloss:0.11331
# [92]	Test-logloss:0.11165
# [93]	Test-logloss:0.10994
# [94]	Test-logloss:0.11023
# [95]	Test-logloss:0.10867
# [96]	Test-logloss:0.10706
# [97]	Test-logloss:0.10559
# [98]	Test-logloss:0.10577
# [99]	Test-logloss:0.10425
# [100]	Test-logloss:0.10444
# [101]	Test-logloss:0.10298
# [102]	Test-logloss:0.10297
# [103]	Test-logloss:0.10162
# [104]	Test-logloss:0.10183
# [105]	Test-logloss:0.10045
# [106]	Test-logloss:0.09918
# [107]	Test-logloss:0.09948
# [108]	Test-logloss:0.10035
# [109]	Test-logloss:0.09904
# [110]	Test-logloss:0.09935
# [111]	Test-logloss:0.09814
# [112]	Test-logloss:0.09900
# [113]	Test-logloss:0.09774
# [114]	Test-logloss:0.09859
# [115]	Test-logloss:0.09891
# [116]	Test-logloss:0.09775
# [117]	Test-logloss:0.09858
# [118]	Test-logloss:0.09745
# [119]	Test-logloss:0.09827
# [120]	Test-logloss:0.09716
# [121]	Test-logloss:0.09720
# [122]	Test-logloss:0.09801
# [123]	Test-logloss:0.09693
# [124]	Test-logloss:0.09773
# [125]	Test-logloss:0.09667
# [126]	Test-logloss:0.09672
# [127]	Test-logloss:0.09750
# [128]	Test-logloss:0.09647
# [129]	Test-logloss:0.09653
# [130]	Test-logloss:0.09730
# [131]	Test-logloss:0.09805
# [132]	Test-logloss:0.09880
# [133]	Test-logloss:0.09955
# [134]	Test-logloss:0.10028
# [135]	Test-logloss:0.10028
# [136]	Test-logloss:0.10028
# [137]	Test-logloss:0.10028
# [138]	Test-logloss:0.10028
# ROC AUC Score: 1.0
# Accuracy: 1.00
#
# Suns
# [0]	Test-logloss:0.66136
# [1]	Test-logloss:0.63269
# [2]	Test-logloss:0.60550
# [3]	Test-logloss:0.58011
# [4]	Test-logloss:0.55832
# [5]	Test-logloss:0.53689
# [6]	Test-logloss:0.51854
# [7]	Test-logloss:0.50011
# [8]	Test-logloss:0.48277
# [9]	Test-logloss:0.46129
# [10]	Test-logloss:0.44777
# [11]	Test-logloss:0.42808
# [12]	Test-logloss:0.41647
# [13]	Test-logloss:0.40083
# [14]	Test-logloss:0.38911
# [15]	Test-logloss:0.37501
# [16]	Test-logloss:0.36079
# [17]	Test-logloss:0.35233
# [18]	Test-logloss:0.34067
# [19]	Test-logloss:0.33413
# [20]	Test-logloss:0.32153
# [21]	Test-logloss:0.31427
# [22]	Test-logloss:0.30220
# [23]	Test-logloss:0.29637
# [24]	Test-logloss:0.28456
# [25]	Test-logloss:0.27335
# [26]	Test-logloss:0.26787
# [27]	Test-logloss:0.25839
# [28]	Test-logloss:0.25458
# [29]	Test-logloss:0.25010
# [30]	Test-logloss:0.24738
# [31]	Test-logloss:0.23917
# [32]	Test-logloss:0.23504
# [33]	Test-logloss:0.23168
# [34]	Test-logloss:0.22431
# [35]	Test-logloss:0.22089
# [36]	Test-logloss:0.21677
# [37]	Test-logloss:0.21426
# [38]	Test-logloss:0.21038
# [39]	Test-logloss:0.20666
# [40]	Test-logloss:0.20450
# [41]	Test-logloss:0.20166
# [42]	Test-logloss:0.19983
# [43]	Test-logloss:0.19750
# [44]	Test-logloss:0.19205
# [45]	Test-logloss:0.19059
# [46]	Test-logloss:0.18867
# [47]	Test-logloss:0.18814
# [48]	Test-logloss:0.18645
# [49]	Test-logloss:0.18546
# [50]	Test-logloss:0.18080
# [51]	Test-logloss:0.17965
# [52]	Test-logloss:0.17823
# [53]	Test-logloss:0.17789
# [54]	Test-logloss:0.17691
# [55]	Test-logloss:0.17525
# [56]	Test-logloss:0.17446
# [57]	Test-logloss:0.17218
# [58]	Test-logloss:0.17193
# [59]	Test-logloss:0.16811
# [60]	Test-logloss:0.16606
# [61]	Test-logloss:0.16681
# [62]	Test-logloss:0.16490
# [63]	Test-logloss:0.16506
# [64]	Test-logloss:0.16208
# [65]	Test-logloss:0.16175
# [66]	Test-logloss:0.15891
# [67]	Test-logloss:0.15559
# [68]	Test-logloss:0.15589
# [69]	Test-logloss:0.15435
# [70]	Test-logloss:0.15177
# [71]	Test-logloss:0.15129
# [72]	Test-logloss:0.14834
# [73]	Test-logloss:0.14894
# [74]	Test-logloss:0.14606
# [75]	Test-logloss:0.14564
# [76]	Test-logloss:0.14534
# [77]	Test-logloss:0.14264
# [78]	Test-logloss:0.14231
# [79]	Test-logloss:0.14258
# [80]	Test-logloss:0.14236
# [81]	Test-logloss:0.13986
# [82]	Test-logloss:0.14020
# [83]	Test-logloss:0.13782
# [84]	Test-logloss:0.13581
# [85]	Test-logloss:0.13627
# [86]	Test-logloss:0.13395
# [87]	Test-logloss:0.13437
# [88]	Test-logloss:0.13351
# [89]	Test-logloss:0.13346
# [90]	Test-logloss:0.13267
# [91]	Test-logloss:0.13315
# [92]	Test-logloss:0.13240
# [93]	Test-logloss:0.13241
# [94]	Test-logloss:0.13196
# [95]	Test-logloss:0.13249
# [96]	Test-logloss:0.13190
# [97]	Test-logloss:0.13040
# [98]	Test-logloss:0.13082
# [99]	Test-logloss:0.13131
# [100]	Test-logloss:0.13018
# [101]	Test-logloss:0.12978
# [102]	Test-logloss:0.12985
# [103]	Test-logloss:0.13037
# [104]	Test-logloss:0.12928
# [105]	Test-logloss:0.12890
# [106]	Test-logloss:0.12909
# [107]	Test-logloss:0.12872
# [108]	Test-logloss:0.12769
# [109]	Test-logloss:0.12822
# [110]	Test-logloss:0.12834
# [111]	Test-logloss:0.12800
# [112]	Test-logloss:0.12696
# [113]	Test-logloss:0.12749
# [114]	Test-logloss:0.12717
# [115]	Test-logloss:0.12616
# [116]	Test-logloss:0.12669
# [117]	Test-logloss:0.12682
# [118]	Test-logloss:0.12652
# [119]	Test-logloss:0.12686
# [120]	Test-logloss:0.12739
# [121]	Test-logloss:0.12642
# [122]	Test-logloss:0.12613
# [123]	Test-logloss:0.12518
# [124]	Test-logloss:0.12571
# [125]	Test-logloss:0.12605
# [126]	Test-logloss:0.12658
# [127]	Test-logloss:0.12566
# [128]	Test-logloss:0.12600
# [129]	Test-logloss:0.12559
# [130]	Test-logloss:0.12611
# [131]	Test-logloss:0.12540
# [132]	Test-logloss:0.12452
# [133]	Test-logloss:0.12503
# [134]	Test-logloss:0.12465
# [135]	Test-logloss:0.12481
# [136]	Test-logloss:0.12412
# [137]	Test-logloss:0.12464
# [138]	Test-logloss:0.12379
# [139]	Test-logloss:0.12343
# [140]	Test-logloss:0.12277
# [141]	Test-logloss:0.12328
# [142]	Test-logloss:0.12247
# [143]	Test-logloss:0.12212
# [144]	Test-logloss:0.12228
# [145]	Test-logloss:0.12279
# [146]	Test-logloss:0.12215
# [147]	Test-logloss:0.12182
# [148]	Test-logloss:0.12105
# [149]	Test-logloss:0.12155
# [150]	Test-logloss:0.12123
# [151]	Test-logloss:0.12063
# [152]	Test-logloss:0.12112
# [153]	Test-logloss:0.12031
# [154]	Test-logloss:0.12001
# [155]	Test-logloss:0.11923
# [156]	Test-logloss:0.11895
# [157]	Test-logloss:0.11942
# [158]	Test-logloss:0.11867
# [159]	Test-logloss:0.11914
# [160]	Test-logloss:0.11841
# [161]	Test-logloss:0.11887
# [162]	Test-logloss:0.11816
# [163]	Test-logloss:0.11863
# [164]	Test-logloss:0.11793
# [165]	Test-logloss:0.11839
# [166]	Test-logloss:0.11787
# [167]	Test-logloss:0.11833
# [168]	Test-logloss:0.11783
# [169]	Test-logloss:0.11793
# [170]	Test-logloss:0.11715
# [171]	Test-logloss:0.11726
# [172]	Test-logloss:0.11651
# [173]	Test-logloss:0.11662
# [174]	Test-logloss:0.11664
# [175]	Test-logloss:0.11665
# [176]	Test-logloss:0.11666
# [177]	Test-logloss:0.11668
# [178]	Test-logloss:0.11669
# [179]	Test-logloss:0.11670
# [180]	Test-logloss:0.11671
# [181]	Test-logloss:0.11672
# [182]	Test-logloss:0.11673
# ROC AUC Score: 1.0
# Accuracy: 1.00
#
# Mavericks
# [0]	Test-logloss:0.66102
# [1]	Test-logloss:0.64401
# [2]	Test-logloss:0.62633
# [3]	Test-logloss:0.61246
# [4]	Test-logloss:0.59823
# [5]	Test-logloss:0.58744
# [6]	Test-logloss:0.57836
# [7]	Test-logloss:0.56861
# [8]	Test-logloss:0.55777
# [9]	Test-logloss:0.55121
# [10]	Test-logloss:0.54560
# [11]	Test-logloss:0.54143
# [12]	Test-logloss:0.53735
# [13]	Test-logloss:0.53584
# [14]	Test-logloss:0.53555
# [15]	Test-logloss:0.53529
# [16]	Test-logloss:0.53560
# [17]	Test-logloss:0.53386
# [18]	Test-logloss:0.53102
# [19]	Test-logloss:0.53312
# [20]	Test-logloss:0.53362
# [21]	Test-logloss:0.52185
# [22]	Test-logloss:0.52481
# [23]	Test-logloss:0.51339
# [24]	Test-logloss:0.50164
# [25]	Test-logloss:0.48944
# [26]	Test-logloss:0.47610
# [27]	Test-logloss:0.47981
# [28]	Test-logloss:0.46907
# [29]	Test-logloss:0.45712
# [30]	Test-logloss:0.44562
# [31]	Test-logloss:0.43727
# [32]	Test-logloss:0.42652
# [33]	Test-logloss:0.41882
# [34]	Test-logloss:0.40877
# [35]	Test-logloss:0.41099
# [36]	Test-logloss:0.40163
# [37]	Test-logloss:0.39494
# [38]	Test-logloss:0.38616
# [39]	Test-logloss:0.38939
# [40]	Test-logloss:0.38331
# [41]	Test-logloss:0.37871
# [42]	Test-logloss:0.37108
# [43]	Test-logloss:0.36703
# [44]	Test-logloss:0.35982
# [45]	Test-logloss:0.35397
# [46]	Test-logloss:0.35690
# [47]	Test-logloss:0.35207
# [48]	Test-logloss:0.34574
# [49]	Test-logloss:0.34209
# [50]	Test-logloss:0.33753
# [51]	Test-logloss:0.33392
# [52]	Test-logloss:0.33749
# [53]	Test-logloss:0.33399
# [54]	Test-logloss:0.33079
# [55]	Test-logloss:0.32548
# [56]	Test-logloss:0.32023
# [57]	Test-logloss:0.31639
# [58]	Test-logloss:0.31984
# [59]	Test-logloss:0.31637
# [60]	Test-logloss:0.31103
# [61]	Test-logloss:0.30527
# [62]	Test-logloss:0.30209
# [63]	Test-logloss:0.29891
# [64]	Test-logloss:0.30220
# [65]	Test-logloss:0.29736
# [66]	Test-logloss:0.29446
# [67]	Test-logloss:0.28935
# [68]	Test-logloss:0.29252
# [69]	Test-logloss:0.28962
# [70]	Test-logloss:0.28698
# [71]	Test-logloss:0.28263
# [72]	Test-logloss:0.28015
# [73]	Test-logloss:0.27557
# [74]	Test-logloss:0.27858
# [75]	Test-logloss:0.27376
# [76]	Test-logloss:0.27128
# [77]	Test-logloss:0.26906
# [78]	Test-logloss:0.26521
# [79]	Test-logloss:0.26076
# [80]	Test-logloss:0.26358
# [81]	Test-logloss:0.26155
# [82]	Test-logloss:0.25944
# [83]	Test-logloss:0.25562
# [84]	Test-logloss:0.25167
# [85]	Test-logloss:0.24966
# [86]	Test-logloss:0.24588
# [87]	Test-logloss:0.24231
# [88]	Test-logloss:0.24054
# [89]	Test-logloss:0.23697
# [90]	Test-logloss:0.23364
# [91]	Test-logloss:0.23023
# [92]	Test-logloss:0.22857
# [93]	Test-logloss:0.22531
# [94]	Test-logloss:0.22223
# [95]	Test-logloss:0.21911
# [96]	Test-logloss:0.21608
# [97]	Test-logloss:0.21606
# [98]	Test-logloss:0.21605
# [99]	Test-logloss:0.21604
# [100]	Test-logloss:0.21603
# [101]	Test-logloss:0.21602
# [102]	Test-logloss:0.21601
# [103]	Test-logloss:0.21600
# [104]	Test-logloss:0.21599
# [105]	Test-logloss:0.21598
# [106]	Test-logloss:0.21598
# [107]	Test-logloss:0.21597
# [108]	Test-logloss:0.21596
# [109]	Test-logloss:0.21595
# [110]	Test-logloss:0.21594
# [111]	Test-logloss:0.21594
# [112]	Test-logloss:0.21593
# [113]	Test-logloss:0.21592
# [114]	Test-logloss:0.21592
# [115]	Test-logloss:0.21591
# [116]	Test-logloss:0.21590
# [117]	Test-logloss:0.21590
# [118]	Test-logloss:0.21589
# [119]	Test-logloss:0.21589
# [120]	Test-logloss:0.21588
# [121]	Test-logloss:0.21588
# [122]	Test-logloss:0.21587
# [123]	Test-logloss:0.21587
# [124]	Test-logloss:0.21586
# [125]	Test-logloss:0.21586
# [126]	Test-logloss:0.21585
# [127]	Test-logloss:0.21585
# [128]	Test-logloss:0.21585
# [129]	Test-logloss:0.21584
# [130]	Test-logloss:0.21584
# [131]	Test-logloss:0.21583
# [132]	Test-logloss:0.21583
# [133]	Test-logloss:0.21583
# [134]	Test-logloss:0.21582
# [135]	Test-logloss:0.21582
# [136]	Test-logloss:0.21582
# [137]	Test-logloss:0.21582
# [138]	Test-logloss:0.21581
# [139]	Test-logloss:0.21581
# [140]	Test-logloss:0.21581
# [141]	Test-logloss:0.21580
# [142]	Test-logloss:0.21580
# [143]	Test-logloss:0.21580
# [144]	Test-logloss:0.21580
# [145]	Test-logloss:0.21579
# [146]	Test-logloss:0.21579
# [147]	Test-logloss:0.21579
# [148]	Test-logloss:0.21579
# [149]	Test-logloss:0.21579
# [150]	Test-logloss:0.21578
# [151]	Test-logloss:0.21578
# [152]	Test-logloss:0.21578
# [153]	Test-logloss:0.21578
# [154]	Test-logloss:0.21578
# [155]	Test-logloss:0.21578
# [156]	Test-logloss:0.21577
# [157]	Test-logloss:0.21577
# [158]	Test-logloss:0.21577
# [159]	Test-logloss:0.21577
# [160]	Test-logloss:0.21577
# [161]	Test-logloss:0.21577
# [162]	Test-logloss:0.21577
# [163]	Test-logloss:0.21576
# [164]	Test-logloss:0.21576
# [165]	Test-logloss:0.21576
# [166]	Test-logloss:0.21576
# [167]	Test-logloss:0.21576
# [168]	Test-logloss:0.21576
# [169]	Test-logloss:0.21576
# [170]	Test-logloss:0.21576
# [171]	Test-logloss:0.21576
# [172]	Test-logloss:0.21576
# [173]	Test-logloss:0.21575
# [174]	Test-logloss:0.21575
# [175]	Test-logloss:0.21575
# [176]	Test-logloss:0.21575
# [177]	Test-logloss:0.21575
# [178]	Test-logloss:0.21575
# [179]	Test-logloss:0.21575
# [180]	Test-logloss:0.21575
# [181]	Test-logloss:0.21575
# [182]	Test-logloss:0.21575
# [183]	Test-logloss:0.21575
# [184]	Test-logloss:0.21575
# [185]	Test-logloss:0.21575
# [186]	Test-logloss:0.21575
# [187]	Test-logloss:0.21574
# [188]	Test-logloss:0.21574
# [189]	Test-logloss:0.21574
# [190]	Test-logloss:0.21574
# [191]	Test-logloss:0.21574
# [192]	Test-logloss:0.21574
# [193]	Test-logloss:0.21574
# [194]	Test-logloss:0.21574
# [195]	Test-logloss:0.21574
# [196]	Test-logloss:0.21574
# [197]	Test-logloss:0.21574
# [198]	Test-logloss:0.21574
# [199]	Test-logloss:0.21574
# [200]	Test-logloss:0.21574
# [201]	Test-logloss:0.21574
# [202]	Test-logloss:0.21574
# [203]	Test-logloss:0.21574
# [204]	Test-logloss:0.21574
# [205]	Test-logloss:0.21574
# [206]	Test-logloss:0.21574
# [207]	Test-logloss:0.21574
# [208]	Test-logloss:0.21574
# [209]	Test-logloss:0.21574
# [210]	Test-logloss:0.21574
# [211]	Test-logloss:0.21574
# [212]	Test-logloss:0.21574
# [213]	Test-logloss:0.21574
# [214]	Test-logloss:0.21573
# [215]	Test-logloss:0.21573
# [216]	Test-logloss:0.21573
# [217]	Test-logloss:0.21573
# [218]	Test-logloss:0.21573
# [219]	Test-logloss:0.21573
# [220]	Test-logloss:0.21573
# [221]	Test-logloss:0.21573
# [222]	Test-logloss:0.21573
# [223]	Test-logloss:0.21573
# [224]	Test-logloss:0.21573
# [225]	Test-logloss:0.21573
# [226]	Test-logloss:0.21573
# [227]	Test-logloss:0.21573
# [228]	Test-logloss:0.21573
# [229]	Test-logloss:0.21573
# [230]	Test-logloss:0.21573
# [231]	Test-logloss:0.21573
# [232]	Test-logloss:0.21573
# [233]	Test-logloss:0.21573
# [234]	Test-logloss:0.21573
# [235]	Test-logloss:0.21573
# [236]	Test-logloss:0.21573
# [237]	Test-logloss:0.21573
# [238]	Test-logloss:0.21573
# [239]	Test-logloss:0.21573
# [240]	Test-logloss:0.21573
# [241]	Test-logloss:0.21573
# [242]	Test-logloss:0.21573
# [243]	Test-logloss:0.21573
# [244]	Test-logloss:0.21573
# [245]	Test-logloss:0.21573
# [246]	Test-logloss:0.21573
# [247]	Test-logloss:0.21573
# [248]	Test-logloss:0.21573
# [249]	Test-logloss:0.21573
# [250]	Test-logloss:0.21573
# [251]	Test-logloss:0.21573
# [252]	Test-logloss:0.21573
# [253]	Test-logloss:0.21573
# [254]	Test-logloss:0.21573
# [255]	Test-logloss:0.21573
# [256]	Test-logloss:0.21573
# [257]	Test-logloss:0.21573
# [258]	Test-logloss:0.21573
# [259]	Test-logloss:0.21573
# [260]	Test-logloss:0.21573
# [261]	Test-logloss:0.21573
# [262]	Test-logloss:0.21573
# [263]	Test-logloss:0.21573
# [264]	Test-logloss:0.21573
# [265]	Test-logloss:0.21573
# [266]	Test-logloss:0.21573
# [267]	Test-logloss:0.21573
# [268]	Test-logloss:0.21573
# [269]	Test-logloss:0.21573
# [270]	Test-logloss:0.21573
# [271]	Test-logloss:0.21573
# [272]	Test-logloss:0.21573
# [273]	Test-logloss:0.21573
# [274]	Test-logloss:0.21573
# [275]	Test-logloss:0.21573
# [276]	Test-logloss:0.21573
# [277]	Test-logloss:0.21573
# [278]	Test-logloss:0.21573
# [279]	Test-logloss:0.21573
# [280]	Test-logloss:0.21573
# [281]	Test-logloss:0.21573
# [282]	Test-logloss:0.21573
# [283]	Test-logloss:0.21573
# [284]	Test-logloss:0.21573
# [285]	Test-logloss:0.21573
# [286]	Test-logloss:0.21573
# [287]	Test-logloss:0.21573
# [288]	Test-logloss:0.21573
# [289]	Test-logloss:0.21573
# [290]	Test-logloss:0.21573
# [291]	Test-logloss:0.21573
# [292]	Test-logloss:0.21573
# [293]	Test-logloss:0.21573
# [294]	Test-logloss:0.21573
# [295]	Test-logloss:0.21573
# [296]	Test-logloss:0.21573
# [297]	Test-logloss:0.21573
# [298]	Test-logloss:0.21573
# [299]	Test-logloss:0.21573
# [300]	Test-logloss:0.21573
# [301]	Test-logloss:0.21573
# [302]	Test-logloss:0.21573
# [303]	Test-logloss:0.21573
# [304]	Test-logloss:0.21573
# [305]	Test-logloss:0.21573
# [306]	Test-logloss:0.21573
# [307]	Test-logloss:0.21573
# [308]	Test-logloss:0.21573
# [309]	Test-logloss:0.21573
# [310]	Test-logloss:0.21573
# [311]	Test-logloss:0.21573
# [312]	Test-logloss:0.21573
# [313]	Test-logloss:0.21573
# [314]	Test-logloss:0.21573
# [315]	Test-logloss:0.21573
# [316]	Test-logloss:0.21573
# [317]	Test-logloss:0.21573
# [318]	Test-logloss:0.21573
# [319]	Test-logloss:0.21573
# [320]	Test-logloss:0.21573
# [321]	Test-logloss:0.21573
# [322]	Test-logloss:0.21573
# [323]	Test-logloss:0.21573
# [324]	Test-logloss:0.21573
# [325]	Test-logloss:0.21573
# [326]	Test-logloss:0.21573
# [327]	Test-logloss:0.21573
# [328]	Test-logloss:0.21573
# [329]	Test-logloss:0.21573
# [330]	Test-logloss:0.21573
# [331]	Test-logloss:0.21573
# [332]	Test-logloss:0.21573
# [333]	Test-logloss:0.21573
# [334]	Test-logloss:0.21573
# [335]	Test-logloss:0.21573
# [336]	Test-logloss:0.21573
# [337]	Test-logloss:0.21573
# [338]	Test-logloss:0.21573
# [339]	Test-logloss:0.21573
# [340]	Test-logloss:0.21573
# [341]	Test-logloss:0.21573
# [342]	Test-logloss:0.21573
# [343]	Test-logloss:0.21573
# [344]	Test-logloss:0.21573
# [345]	Test-logloss:0.21573
# [346]	Test-logloss:0.21573
# [347]	Test-logloss:0.21573
# [348]	Test-logloss:0.21573
# [349]	Test-logloss:0.21573
# [350]	Test-logloss:0.21573
# [351]	Test-logloss:0.21573
# [352]	Test-logloss:0.21573
# [353]	Test-logloss:0.21573
# [354]	Test-logloss:0.21573
# [355]	Test-logloss:0.21573
# [356]	Test-logloss:0.21573
# [357]	Test-logloss:0.21573
# [358]	Test-logloss:0.21573
# [359]	Test-logloss:0.21573
# [360]	Test-logloss:0.21573
# [361]	Test-logloss:0.21573
# [362]	Test-logloss:0.21573
# [363]	Test-logloss:0.21573
# [364]	Test-logloss:0.21573
# [365]	Test-logloss:0.21573
# [366]	Test-logloss:0.21573
# [367]	Test-logloss:0.21573
# [368]	Test-logloss:0.21573
# [369]	Test-logloss:0.21573
# [370]	Test-logloss:0.21573
# [371]	Test-logloss:0.21573
# [372]	Test-logloss:0.21573
# [373]	Test-logloss:0.21573
# [374]	Test-logloss:0.21573
# [375]	Test-logloss:0.21573
# [376]	Test-logloss:0.21573
# [377]	Test-logloss:0.21573
# [378]	Test-logloss:0.21573
# [379]	Test-logloss:0.21573
# [380]	Test-logloss:0.21573
# [381]	Test-logloss:0.21573
# [382]	Test-logloss:0.21573
# [383]	Test-logloss:0.21573
# [384]	Test-logloss:0.21573
# [385]	Test-logloss:0.21573
# [386]	Test-logloss:0.21573
# [387]	Test-logloss:0.21573
# [388]	Test-logloss:0.21573
# [389]	Test-logloss:0.21573
# [390]	Test-logloss:0.21573
# [391]	Test-logloss:0.21573
# [392]	Test-logloss:0.21573
# [393]	Test-logloss:0.21573
# [394]	Test-logloss:0.21573
# [395]	Test-logloss:0.21573
# [396]	Test-logloss:0.21573
# [397]	Test-logloss:0.21573
# [398]	Test-logloss:0.21573
# [399]	Test-logloss:0.21573
# [400]	Test-logloss:0.21573
# [401]	Test-logloss:0.21573
# [402]	Test-logloss:0.21573
# [403]	Test-logloss:0.21573
# [404]	Test-logloss:0.21573
# [405]	Test-logloss:0.21573
# [406]	Test-logloss:0.21573
# [407]	Test-logloss:0.21573
# [408]	Test-logloss:0.21573
# [409]	Test-logloss:0.21573
# [410]	Test-logloss:0.21573
# [411]	Test-logloss:0.21573
# [412]	Test-logloss:0.21573
# [413]	Test-logloss:0.21573
# [414]	Test-logloss:0.21573
# [415]	Test-logloss:0.21573
# [416]	Test-logloss:0.21573
# [417]	Test-logloss:0.21573
# [418]	Test-logloss:0.21573
# [419]	Test-logloss:0.21573
# [420]	Test-logloss:0.21573
# [421]	Test-logloss:0.21573
# [422]	Test-logloss:0.21573
# [423]	Test-logloss:0.21573
# [424]	Test-logloss:0.21573
# [425]	Test-logloss:0.21573
# [426]	Test-logloss:0.21573
# [427]	Test-logloss:0.21573
# [428]	Test-logloss:0.21573
# [429]	Test-logloss:0.21573
# [430]	Test-logloss:0.21573
# [431]	Test-logloss:0.21573
# [432]	Test-logloss:0.21573
# [433]	Test-logloss:0.21573
# [434]	Test-logloss:0.21573
# [435]	Test-logloss:0.21573
# [436]	Test-logloss:0.21573
# [437]	Test-logloss:0.21573
# [438]	Test-logloss:0.21573
# [439]	Test-logloss:0.21573
# [440]	Test-logloss:0.21573
# [441]	Test-logloss:0.21573
# [442]	Test-logloss:0.21573
# [443]	Test-logloss:0.21573
# [444]	Test-logloss:0.21573
# [445]	Test-logloss:0.21573
# [446]	Test-logloss:0.21573
# [447]	Test-logloss:0.21573
# [448]	Test-logloss:0.21573
# [449]	Test-logloss:0.21573
# [450]	Test-logloss:0.21573
# [451]	Test-logloss:0.21573
# [452]	Test-logloss:0.21573
# [453]	Test-logloss:0.21573
# [454]	Test-logloss:0.21573
# [455]	Test-logloss:0.21573
# [456]	Test-logloss:0.21573
# [457]	Test-logloss:0.21573
# [458]	Test-logloss:0.21573
# [459]	Test-logloss:0.21573
# [460]	Test-logloss:0.21573
# [461]	Test-logloss:0.21573
# [462]	Test-logloss:0.21573
# [463]	Test-logloss:0.21573
# [464]	Test-logloss:0.21573
# [465]	Test-logloss:0.21573
# [466]	Test-logloss:0.21573
# [467]	Test-logloss:0.21573
# [468]	Test-logloss:0.21573
# [469]	Test-logloss:0.21573
# [470]	Test-logloss:0.21573
# [471]	Test-logloss:0.21573
# [472]	Test-logloss:0.21573
# [473]	Test-logloss:0.21573
# [474]	Test-logloss:0.21573
# [475]	Test-logloss:0.21573
# [476]	Test-logloss:0.21573
# [477]	Test-logloss:0.21573
# [478]	Test-logloss:0.21573
# [479]	Test-logloss:0.21573
# [480]	Test-logloss:0.21573
# [481]	Test-logloss:0.21573
# [482]	Test-logloss:0.21573
# [483]	Test-logloss:0.21573
# [484]	Test-logloss:0.21573
# [485]	Test-logloss:0.21573
# [486]	Test-logloss:0.21573
# [487]	Test-logloss:0.21573
# [488]	Test-logloss:0.21573
# [489]	Test-logloss:0.21573
# [490]	Test-logloss:0.21573
# [491]	Test-logloss:0.21573
# [492]	Test-logloss:0.21573
# [493]	Test-logloss:0.21573
# [494]	Test-logloss:0.21573
# [495]	Test-logloss:0.21573
# [496]	Test-logloss:0.21573
# [497]	Test-logloss:0.21573
# [498]	Test-logloss:0.21573
# [499]	Test-logloss:0.21573
# [500]	Test-logloss:0.21573
# [501]	Test-logloss:0.21573
# [502]	Test-logloss:0.21573
# [503]	Test-logloss:0.21573
# [504]	Test-logloss:0.21573
# [505]	Test-logloss:0.21573
# [506]	Test-logloss:0.21573
# [507]	Test-logloss:0.21573
# [508]	Test-logloss:0.21573
# [509]	Test-logloss:0.21573
# [510]	Test-logloss:0.21573
# [511]	Test-logloss:0.21573
# [512]	Test-logloss:0.21573
# [513]	Test-logloss:0.21573
# [514]	Test-logloss:0.21573
# [515]	Test-logloss:0.21573
# [516]	Test-logloss:0.21573
# [517]	Test-logloss:0.21573
# [518]	Test-logloss:0.21573
# [519]	Test-logloss:0.21573
# [520]	Test-logloss:0.21573
# [521]	Test-logloss:0.21573
# [522]	Test-logloss:0.21573
# [523]	Test-logloss:0.21573
# [524]	Test-logloss:0.21573
# [525]	Test-logloss:0.21573
# [526]	Test-logloss:0.21573
# [527]	Test-logloss:0.21573
# [528]	Test-logloss:0.21573
# [529]	Test-logloss:0.21573
# [530]	Test-logloss:0.21573
# [531]	Test-logloss:0.21573
# [532]	Test-logloss:0.21573
# [533]	Test-logloss:0.21573
# [534]	Test-logloss:0.21573
# [535]	Test-logloss:0.21573
# [536]	Test-logloss:0.21573
# [537]	Test-logloss:0.21573
# [538]	Test-logloss:0.21573
# [539]	Test-logloss:0.21573
# [540]	Test-logloss:0.21573
# [541]	Test-logloss:0.21573
# [542]	Test-logloss:0.21573
# [543]	Test-logloss:0.21573
# [544]	Test-logloss:0.21573
# [545]	Test-logloss:0.21573
# [546]	Test-logloss:0.21573
# [547]	Test-logloss:0.21573
# [548]	Test-logloss:0.21573
# [549]	Test-logloss:0.21573
# [550]	Test-logloss:0.21573
# [551]	Test-logloss:0.21573
# [552]	Test-logloss:0.21573
# [553]	Test-logloss:0.21573
# [554]	Test-logloss:0.21573
# [555]	Test-logloss:0.21573
# [556]	Test-logloss:0.21573
# [557]	Test-logloss:0.21573
# [558]	Test-logloss:0.21573
# [559]	Test-logloss:0.21573
# [560]	Test-logloss:0.21573
# [561]	Test-logloss:0.21573
# [562]	Test-logloss:0.21573
# [563]	Test-logloss:0.21573
# [564]	Test-logloss:0.21573
# [565]	Test-logloss:0.21573
# [566]	Test-logloss:0.21573
# [567]	Test-logloss:0.21573
# [568]	Test-logloss:0.21573
# [569]	Test-logloss:0.21573
# [570]	Test-logloss:0.21573
# [571]	Test-logloss:0.21573
# [572]	Test-logloss:0.21573
# [573]	Test-logloss:0.21573
# [574]	Test-logloss:0.21573
# [575]	Test-logloss:0.21573
# [576]	Test-logloss:0.21573
# [577]	Test-logloss:0.21573
# [578]	Test-logloss:0.21573
# [579]	Test-logloss:0.21573
# [580]	Test-logloss:0.21573
# [581]	Test-logloss:0.21573
# [582]	Test-logloss:0.21573
# [583]	Test-logloss:0.21573
# [584]	Test-logloss:0.21573
# [585]	Test-logloss:0.21573
# [586]	Test-logloss:0.21573
# [587]	Test-logloss:0.21573
# [588]	Test-logloss:0.21573
# [589]	Test-logloss:0.21573
# [590]	Test-logloss:0.21573
# [591]	Test-logloss:0.21573
# [592]	Test-logloss:0.21573
# [593]	Test-logloss:0.21573
# [594]	Test-logloss:0.21573
# [595]	Test-logloss:0.21573
# [596]	Test-logloss:0.21573
# [597]	Test-logloss:0.21573
# [598]	Test-logloss:0.21573
# [599]	Test-logloss:0.21573
# [600]	Test-logloss:0.21573
# [601]	Test-logloss:0.21573
# [602]	Test-logloss:0.21573
# [603]	Test-logloss:0.21573
# [604]	Test-logloss:0.21573
# [605]	Test-logloss:0.21573
# [606]	Test-logloss:0.21573
# [607]	Test-logloss:0.21573
# [608]	Test-logloss:0.21573
# [609]	Test-logloss:0.21573
# [610]	Test-logloss:0.21573
# [611]	Test-logloss:0.21573
# [612]	Test-logloss:0.21573
# [613]	Test-logloss:0.21573
# [614]	Test-logloss:0.21573
# [615]	Test-logloss:0.21573
# [616]	Test-logloss:0.21573
# [617]	Test-logloss:0.21573
# [618]	Test-logloss:0.21573
# [619]	Test-logloss:0.21573
# [620]	Test-logloss:0.21573
# [621]	Test-logloss:0.21573
# [622]	Test-logloss:0.21573
# [623]	Test-logloss:0.21573
# [624]	Test-logloss:0.21573
# [625]	Test-logloss:0.21573
# [626]	Test-logloss:0.21573
# [627]	Test-logloss:0.21573
# [628]	Test-logloss:0.21573
# [629]	Test-logloss:0.21573
# [630]	Test-logloss:0.21573
# [631]	Test-logloss:0.21573
# [632]	Test-logloss:0.21573
# [633]	Test-logloss:0.21573
# [634]	Test-logloss:0.21573
# [635]	Test-logloss:0.21573
# [636]	Test-logloss:0.21573
# [637]	Test-logloss:0.21573
# [638]	Test-logloss:0.21573
# [639]	Test-logloss:0.21573
# [640]	Test-logloss:0.21573
# [641]	Test-logloss:0.21573
# [642]	Test-logloss:0.21573
# [643]	Test-logloss:0.21573
# [644]	Test-logloss:0.21573
# [645]	Test-logloss:0.21573
# [646]	Test-logloss:0.21573
# [647]	Test-logloss:0.21573
# [648]	Test-logloss:0.21573
# [649]	Test-logloss:0.21573
# [650]	Test-logloss:0.21573
# [651]	Test-logloss:0.21573
# [652]	Test-logloss:0.21573
# [653]	Test-logloss:0.21573
# [654]	Test-logloss:0.21573
# [655]	Test-logloss:0.21573
# [656]	Test-logloss:0.21573
# [657]	Test-logloss:0.21573
# [658]	Test-logloss:0.21573
# [659]	Test-logloss:0.21573
# [660]	Test-logloss:0.21573
# [661]	Test-logloss:0.21573
# [662]	Test-logloss:0.21573
# [663]	Test-logloss:0.21573
# [664]	Test-logloss:0.21573
# [665]	Test-logloss:0.21573
# [666]	Test-logloss:0.21573
# [667]	Test-logloss:0.21573
# [668]	Test-logloss:0.21573
# [669]	Test-logloss:0.21573
# [670]	Test-logloss:0.21573
# [671]	Test-logloss:0.21573
# [672]	Test-logloss:0.21573
# [673]	Test-logloss:0.21573
# [674]	Test-logloss:0.21573
# [675]	Test-logloss:0.21573
# [676]	Test-logloss:0.21573
# [677]	Test-logloss:0.21573
# [678]	Test-logloss:0.21573
# [679]	Test-logloss:0.21573
# [680]	Test-logloss:0.21573
# [681]	Test-logloss:0.21573
# [682]	Test-logloss:0.21573
# [683]	Test-logloss:0.21573
# [684]	Test-logloss:0.21573
# [685]	Test-logloss:0.21573
# [686]	Test-logloss:0.21573
# [687]	Test-logloss:0.21573
# [688]	Test-logloss:0.21573
# [689]	Test-logloss:0.21573
# [690]	Test-logloss:0.21573
# [691]	Test-logloss:0.21573
# [692]	Test-logloss:0.21573
# [693]	Test-logloss:0.21573
# [694]	Test-logloss:0.21573
# [695]	Test-logloss:0.21573
# [696]	Test-logloss:0.21573
# [697]	Test-logloss:0.21573
# [698]	Test-logloss:0.21573
# [699]	Test-logloss:0.21573
# [700]	Test-logloss:0.21573
# [701]	Test-logloss:0.21573
# [702]	Test-logloss:0.21573
# [703]	Test-logloss:0.21573
# [704]	Test-logloss:0.21573
# [705]	Test-logloss:0.21573
# [706]	Test-logloss:0.21573
# [707]	Test-logloss:0.21573
# [708]	Test-logloss:0.21573
# [709]	Test-logloss:0.21573
# [710]	Test-logloss:0.21573
# [711]	Test-logloss:0.21573
# [712]	Test-logloss:0.21573
# [713]	Test-logloss:0.21573
# [714]	Test-logloss:0.21573
# [715]	Test-logloss:0.21573
# [716]	Test-logloss:0.21573
# [717]	Test-logloss:0.21573
# [718]	Test-logloss:0.21573
# [719]	Test-logloss:0.21573
# [720]	Test-logloss:0.21573
# [721]	Test-logloss:0.21573
# [722]	Test-logloss:0.21573
# [723]	Test-logloss:0.21573
# [724]	Test-logloss:0.21573
# [725]	Test-logloss:0.21573
# [726]	Test-logloss:0.21573
# [727]	Test-logloss:0.21573
# [728]	Test-logloss:0.21573
# [729]	Test-logloss:0.21573
# [730]	Test-logloss:0.21573
# [731]	Test-logloss:0.21573
# [732]	Test-logloss:0.21573
# [733]	Test-logloss:0.21573
# [734]	Test-logloss:0.21573
# [735]	Test-logloss:0.21573
# [736]	Test-logloss:0.21573
# [737]	Test-logloss:0.21573
# [738]	Test-logloss:0.21573
# [739]	Test-logloss:0.21573
# [740]	Test-logloss:0.21573
# [741]	Test-logloss:0.21573
# [742]	Test-logloss:0.21573
# [743]	Test-logloss:0.21573
# [744]	Test-logloss:0.21573
# [745]	Test-logloss:0.21573
# [746]	Test-logloss:0.21573
# [747]	Test-logloss:0.21573
# [748]	Test-logloss:0.21573
# [749]	Test-logloss:0.21573
# [750]	Test-logloss:0.21573
# [751]	Test-logloss:0.21573
# [752]	Test-logloss:0.21573
# [753]	Test-logloss:0.21573
# [754]	Test-logloss:0.21573
# [755]	Test-logloss:0.21573
# [756]	Test-logloss:0.21573
# [757]	Test-logloss:0.21573
# [758]	Test-logloss:0.21573
# [759]	Test-logloss:0.21573
# [760]	Test-logloss:0.21573
# [761]	Test-logloss:0.21573
# [762]	Test-logloss:0.21573
# [763]	Test-logloss:0.21573
# [764]	Test-logloss:0.21573
# [765]	Test-logloss:0.21573
# [766]	Test-logloss:0.21573
# [767]	Test-logloss:0.21573
# [768]	Test-logloss:0.21573
# [769]	Test-logloss:0.21573
# [770]	Test-logloss:0.21573
# [771]	Test-logloss:0.21573
# [772]	Test-logloss:0.21573
# [773]	Test-logloss:0.21573
# [774]	Test-logloss:0.21573
# [775]	Test-logloss:0.21573
# [776]	Test-logloss:0.21573
# [777]	Test-logloss:0.21573
# [778]	Test-logloss:0.21573
# [779]	Test-logloss:0.21573
# [780]	Test-logloss:0.21573
# [781]	Test-logloss:0.21573
# [782]	Test-logloss:0.21573
# [783]	Test-logloss:0.21573
# [784]	Test-logloss:0.21573
# [785]	Test-logloss:0.21573
# [786]	Test-logloss:0.21573
# [787]	Test-logloss:0.21573
# [788]	Test-logloss:0.21573
# [789]	Test-logloss:0.21573
# [790]	Test-logloss:0.21573
# [791]	Test-logloss:0.21573
# [792]	Test-logloss:0.21573
# [793]	Test-logloss:0.21573
# [794]	Test-logloss:0.21573
# [795]	Test-logloss:0.21573
# [796]	Test-logloss:0.21573
# [797]	Test-logloss:0.21573
# [798]	Test-logloss:0.21573
# [799]	Test-logloss:0.21573
# [800]	Test-logloss:0.21573
# [801]	Test-logloss:0.21573
# [802]	Test-logloss:0.21573
# [803]	Test-logloss:0.21573
# [804]	Test-logloss:0.21573
# [805]	Test-logloss:0.21573
# [806]	Test-logloss:0.21573
# [807]	Test-logloss:0.21573
# [808]	Test-logloss:0.21573
# [809]	Test-logloss:0.21573
# [810]	Test-logloss:0.21573
# [811]	Test-logloss:0.21573
# [812]	Test-logloss:0.21573
# [813]	Test-logloss:0.21573
# [814]	Test-logloss:0.21573
# [815]	Test-logloss:0.21573
# [816]	Test-logloss:0.21573
# [817]	Test-logloss:0.21573
# [818]	Test-logloss:0.21573
# [819]	Test-logloss:0.21573
# [820]	Test-logloss:0.21573
# [821]	Test-logloss:0.21573
# [822]	Test-logloss:0.21573
# [823]	Test-logloss:0.21573
# [824]	Test-logloss:0.21573
# [825]	Test-logloss:0.21573
# [826]	Test-logloss:0.21573
# [827]	Test-logloss:0.21573
# [828]	Test-logloss:0.21573
# [829]	Test-logloss:0.21573
# [830]	Test-logloss:0.21573
# [831]	Test-logloss:0.21573
# [832]	Test-logloss:0.21573
# [833]	Test-logloss:0.21573
# [834]	Test-logloss:0.21573
# [835]	Test-logloss:0.21573
# [836]	Test-logloss:0.21573
# [837]	Test-logloss:0.21573
# [838]	Test-logloss:0.21573
# [839]	Test-logloss:0.21573
# [840]	Test-logloss:0.21573
# [841]	Test-logloss:0.21573
# [842]	Test-logloss:0.21573
# [843]	Test-logloss:0.21573
# [844]	Test-logloss:0.21573
# [845]	Test-logloss:0.21573
# [846]	Test-logloss:0.21573
# [847]	Test-logloss:0.21573
# [848]	Test-logloss:0.21573
# [849]	Test-logloss:0.21573
# [850]	Test-logloss:0.21573
# [851]	Test-logloss:0.21573
# [852]	Test-logloss:0.21573
# [853]	Test-logloss:0.21573
# [854]	Test-logloss:0.21573
# [855]	Test-logloss:0.21573
# [856]	Test-logloss:0.21573
# [857]	Test-logloss:0.21573
# [858]	Test-logloss:0.21573
# [859]	Test-logloss:0.21573
# [860]	Test-logloss:0.21573
# [861]	Test-logloss:0.21573
# [862]	Test-logloss:0.21573
# [863]	Test-logloss:0.21573
# [864]	Test-logloss:0.21573
# [865]	Test-logloss:0.21573
# [866]	Test-logloss:0.21573
# [867]	Test-logloss:0.21573
# [868]	Test-logloss:0.21573
# [869]	Test-logloss:0.21573
# [870]	Test-logloss:0.21573
# [871]	Test-logloss:0.21573
# [872]	Test-logloss:0.21573
# [873]	Test-logloss:0.21573
# [874]	Test-logloss:0.21573
# [875]	Test-logloss:0.21573
# [876]	Test-logloss:0.21573
# [877]	Test-logloss:0.21573
# [878]	Test-logloss:0.21573
# [879]	Test-logloss:0.21573
# [880]	Test-logloss:0.21573
# [881]	Test-logloss:0.21573
# [882]	Test-logloss:0.21573
# [883]	Test-logloss:0.21573
# [884]	Test-logloss:0.21573
# [885]	Test-logloss:0.21573
# [886]	Test-logloss:0.21573
# [887]	Test-logloss:0.21573
# [888]	Test-logloss:0.21573
# [889]	Test-logloss:0.21573
# [890]	Test-logloss:0.21573
# [891]	Test-logloss:0.21573
# [892]	Test-logloss:0.21573
# [893]	Test-logloss:0.21573
# [894]	Test-logloss:0.21573
# [895]	Test-logloss:0.21573
# [896]	Test-logloss:0.21573
# [897]	Test-logloss:0.21573
# [898]	Test-logloss:0.21573
# [899]	Test-logloss:0.21573
# [900]	Test-logloss:0.21573
# [901]	Test-logloss:0.21573
# [902]	Test-logloss:0.21573
# [903]	Test-logloss:0.21573
# [904]	Test-logloss:0.21573
# [905]	Test-logloss:0.21573
# [906]	Test-logloss:0.21573
# [907]	Test-logloss:0.21573
# [908]	Test-logloss:0.21573
# [909]	Test-logloss:0.21573
# [910]	Test-logloss:0.21573
# [911]	Test-logloss:0.21573
# [912]	Test-logloss:0.21573
# [913]	Test-logloss:0.21573
# [914]	Test-logloss:0.21573
# [915]	Test-logloss:0.21573
# [916]	Test-logloss:0.21573
# [917]	Test-logloss:0.21573
# [918]	Test-logloss:0.21573
# [919]	Test-logloss:0.21573
# [920]	Test-logloss:0.21573
# [921]	Test-logloss:0.21573
# [922]	Test-logloss:0.21573
# [923]	Test-logloss:0.21573
# [924]	Test-logloss:0.21573
# [925]	Test-logloss:0.21573
# [926]	Test-logloss:0.21573
# [927]	Test-logloss:0.21573
# [928]	Test-logloss:0.21573
# [929]	Test-logloss:0.21573
# [930]	Test-logloss:0.21573
# [931]	Test-logloss:0.21573
# [932]	Test-logloss:0.21573
# [933]	Test-logloss:0.21573
# [934]	Test-logloss:0.21573
# [935]	Test-logloss:0.21573
# [936]	Test-logloss:0.21573
# [937]	Test-logloss:0.21573
# [938]	Test-logloss:0.21573
# [939]	Test-logloss:0.21573
# [940]	Test-logloss:0.21573
# [941]	Test-logloss:0.21573
# [942]	Test-logloss:0.21573
# [943]	Test-logloss:0.21573
# [944]	Test-logloss:0.21573
# [945]	Test-logloss:0.21573
# [946]	Test-logloss:0.21573
# [947]	Test-logloss:0.21573
# [948]	Test-logloss:0.21573
# [949]	Test-logloss:0.21573
# [950]	Test-logloss:0.21573
# [951]	Test-logloss:0.21573
# [952]	Test-logloss:0.21573
# [953]	Test-logloss:0.21573
# [954]	Test-logloss:0.21573
# [955]	Test-logloss:0.21573
# [956]	Test-logloss:0.21573
# [957]	Test-logloss:0.21573
# [958]	Test-logloss:0.21573
# [959]	Test-logloss:0.21573
# [960]	Test-logloss:0.21573
# [961]	Test-logloss:0.21573
# [962]	Test-logloss:0.21573
# [963]	Test-logloss:0.21573
# [964]	Test-logloss:0.21573
# [965]	Test-logloss:0.21573
# [966]	Test-logloss:0.21573
# [967]	Test-logloss:0.21573
# [968]	Test-logloss:0.21573
# [969]	Test-logloss:0.21573
# [970]	Test-logloss:0.21573
# [971]	Test-logloss:0.21573
# [972]	Test-logloss:0.21573
# [973]	Test-logloss:0.21573
# [974]	Test-logloss:0.21573
# [975]	Test-logloss:0.21573
# [976]	Test-logloss:0.21573
# [977]	Test-logloss:0.21573
# [978]	Test-logloss:0.21573
# [979]	Test-logloss:0.21573
# [980]	Test-logloss:0.21573
# [981]	Test-logloss:0.21573
# [982]	Test-logloss:0.21573
# [983]	Test-logloss:0.21573
# [984]	Test-logloss:0.21573
# [985]	Test-logloss:0.21573
# [986]	Test-logloss:0.21573
# [987]	Test-logloss:0.21573
# [988]	Test-logloss:0.21573
# [989]	Test-logloss:0.21573
# [990]	Test-logloss:0.21573
# [991]	Test-logloss:0.21573
# [992]	Test-logloss:0.21573
# [993]	Test-logloss:0.21573
# [994]	Test-logloss:0.21573
# [995]	Test-logloss:0.21573
# [996]	Test-logloss:0.21573
# [997]	Test-logloss:0.21573
# [998]	Test-logloss:0.21573
# ROC AUC Score: 0.9571428571428571
# Accuracy: 1.00
#
# Lakers
# [0]	Test-logloss:0.66041
# [1]	Test-logloss:0.63287
# [2]	Test-logloss:0.61249
# [3]	Test-logloss:0.58941
# [4]	Test-logloss:0.57242
# [5]	Test-logloss:0.55290
# [6]	Test-logloss:0.53864
# [7]	Test-logloss:0.52203
# [8]	Test-logloss:0.50209
# [9]	Test-logloss:0.48930
# [10]	Test-logloss:0.47143
# [11]	Test-logloss:0.46027
# [12]	Test-logloss:0.44424
# [13]	Test-logloss:0.43454
# [14]	Test-logloss:0.42003
# [15]	Test-logloss:0.41358
# [16]	Test-logloss:0.40041
# [17]	Test-logloss:0.38982
# [18]	Test-logloss:0.37784
# [19]	Test-logloss:0.37072
# [20]	Test-logloss:0.36473
# [21]	Test-logloss:0.35416
# [22]	Test-logloss:0.34725
# [23]	Test-logloss:0.33791
# [24]	Test-logloss:0.33439
# [25]	Test-logloss:0.32531
# [26]	Test-logloss:0.32104
# [27]	Test-logloss:0.31683
# [28]	Test-logloss:0.30910
# [29]	Test-logloss:0.30545
# [30]	Test-logloss:0.29837
# [31]	Test-logloss:0.29526
# [32]	Test-logloss:0.29149
# [33]	Test-logloss:0.28519
# [34]	Test-logloss:0.28584
# [35]	Test-logloss:0.28179
# [36]	Test-logloss:0.27999
# [37]	Test-logloss:0.28095
# [38]	Test-logloss:0.27986
# [39]	Test-logloss:0.27451
# [40]	Test-logloss:0.27189
# [41]	Test-logloss:0.26653
# [42]	Test-logloss:0.26034
# [43]	Test-logloss:0.25826
# [44]	Test-logloss:0.25950
# [45]	Test-logloss:0.25767
# [46]	Test-logloss:0.25262
# [47]	Test-logloss:0.25108
# [48]	Test-logloss:0.24918
# [49]	Test-logloss:0.24456
# [50]	Test-logloss:0.24456
# [51]	Test-logloss:0.24347
# [52]	Test-logloss:0.23921
# [53]	Test-logloss:0.23833
# [54]	Test-logloss:0.23728
# [55]	Test-logloss:0.23338
# [56]	Test-logloss:0.23228
# [57]	Test-logloss:0.22860
# [58]	Test-logloss:0.22814
# [59]	Test-logloss:0.22885
# [60]	Test-logloss:0.22543
# [61]	Test-logloss:0.22516
# [62]	Test-logloss:0.22195
# [63]	Test-logloss:0.22181
# [64]	Test-logloss:0.22228
# [65]	Test-logloss:0.22145
# [66]	Test-logloss:0.21860
# [67]	Test-logloss:0.21865
# [68]	Test-logloss:0.21594
# [69]	Test-logloss:0.21529
# [70]	Test-logloss:0.21270
# [71]	Test-logloss:0.21279
# [72]	Test-logloss:0.21294
# [73]	Test-logloss:0.21049
# [74]	Test-logloss:0.21013
# [75]	Test-logloss:0.20774
# [76]	Test-logloss:0.20765
# [77]	Test-logloss:0.20827
# [78]	Test-logloss:0.20602
# [79]	Test-logloss:0.20525
# [80]	Test-logloss:0.20428
# [81]	Test-logloss:0.20214
# [82]	Test-logloss:0.20008
# [83]	Test-logloss:0.19941
# [84]	Test-logloss:0.19934
# [85]	Test-logloss:0.19859
# [86]	Test-logloss:0.19798
# [87]	Test-logloss:0.19795
# [88]	Test-logloss:0.19867
# [89]	Test-logloss:0.19797
# [90]	Test-logloss:0.19741
# [91]	Test-logloss:0.19814
# [92]	Test-logloss:0.19749
# [93]	Test-logloss:0.19561
# [94]	Test-logloss:0.19510
# [95]	Test-logloss:0.19584
# [96]	Test-logloss:0.19525
# [97]	Test-logloss:0.19477
# [98]	Test-logloss:0.19421
# [99]	Test-logloss:0.19496
# [100]	Test-logloss:0.19325
# [101]	Test-logloss:0.19281
# [102]	Test-logloss:0.19230
# [103]	Test-logloss:0.19306
# [104]	Test-logloss:0.19258
# [105]	Test-logloss:0.19334
# [106]	Test-logloss:0.19176
# [107]	Test-logloss:0.19253
# [108]	Test-logloss:0.19210
# [109]	Test-logloss:0.19287
# [110]	Test-logloss:0.19364
# [111]	Test-logloss:0.19330
# [112]	Test-logloss:0.19408
# [113]	Test-logloss:0.19376
# [114]	Test-logloss:0.19455
# [115]	Test-logloss:0.19425
# ROC AUC Score: 1.0
# Accuracy: 0.89
#
# Trail Blazers
# [0]	Test-logloss:0.57104
# [1]	Test-logloss:0.53842
# [2]	Test-logloss:0.50898
# [3]	Test-logloss:0.48227
# [4]	Test-logloss:0.45793
# [5]	Test-logloss:0.44552
# [6]	Test-logloss:0.42602
# [7]	Test-logloss:0.41450
# [8]	Test-logloss:0.40391
# [9]	Test-logloss:0.38619
# [10]	Test-logloss:0.37533
# [11]	Test-logloss:0.36680
# [12]	Test-logloss:0.35180
# [13]	Test-logloss:0.34507
# [14]	Test-logloss:0.33272
# [15]	Test-logloss:0.32479
# [16]	Test-logloss:0.31748
# [17]	Test-logloss:0.31058
# [18]	Test-logloss:0.30428
# [19]	Test-logloss:0.29406
# [20]	Test-logloss:0.29109
# [21]	Test-logloss:0.28209
# [22]	Test-logloss:0.27301
# [23]	Test-logloss:0.26602
# [24]	Test-logloss:0.25798
# [25]	Test-logloss:0.25576
# [26]	Test-logloss:0.24835
# [27]	Test-logloss:0.24120
# [28]	Test-logloss:0.23292
# [29]	Test-logloss:0.22648
# [30]	Test-logloss:0.22016
# [31]	Test-logloss:0.21632
# [32]	Test-logloss:0.21064
# [33]	Test-logloss:0.20635
# [34]	Test-logloss:0.20235
# [35]	Test-logloss:0.19590
# [36]	Test-logloss:0.19163
# [37]	Test-logloss:0.18938
# [38]	Test-logloss:0.18637
# [39]	Test-logloss:0.18311
# [40]	Test-logloss:0.18025
# [41]	Test-logloss:0.17727
# [42]	Test-logloss:0.17184
# [43]	Test-logloss:0.16907
# [44]	Test-logloss:0.16644
# [45]	Test-logloss:0.16361
# [46]	Test-logloss:0.16132
# [47]	Test-logloss:0.16086
# [48]	Test-logloss:0.15697
# [49]	Test-logloss:0.15437
# [50]	Test-logloss:0.15107
# [51]	Test-logloss:0.15072
# [52]	Test-logloss:0.14856
# [53]	Test-logloss:0.14556
# [54]	Test-logloss:0.14539
# [55]	Test-logloss:0.14352
# [56]	Test-logloss:0.14113
# [57]	Test-logloss:0.14107
# [58]	Test-logloss:0.13842
# [59]	Test-logloss:0.13683
# [60]	Test-logloss:0.13417
# [61]	Test-logloss:0.13174
# [62]	Test-logloss:0.13229
# [63]	Test-logloss:0.13154
# [64]	Test-logloss:0.13055
# [65]	Test-logloss:0.12775
# [66]	Test-logloss:0.12684
# [67]	Test-logloss:0.12418
# [68]	Test-logloss:0.12162
# [69]	Test-logloss:0.11997
# [70]	Test-logloss:0.11753
# [71]	Test-logloss:0.11803
# [72]	Test-logloss:0.11622
# [73]	Test-logloss:0.11469
# [74]	Test-logloss:0.11230
# [75]	Test-logloss:0.11159
# [76]	Test-logloss:0.11211
# [77]	Test-logloss:0.11046
# [78]	Test-logloss:0.10907
# [79]	Test-logloss:0.10902
# [80]	Test-logloss:0.10708
# [81]	Test-logloss:0.10579
# [82]	Test-logloss:0.10430
# [83]	Test-logloss:0.10308
# [84]	Test-logloss:0.10167
# [85]	Test-logloss:0.10167
# [86]	Test-logloss:0.10053
# [87]	Test-logloss:0.10137
# [88]	Test-logloss:0.09967
# [89]	Test-logloss:0.10050
# [90]	Test-logloss:0.09939
# [91]	Test-logloss:0.09809
# [92]	Test-logloss:0.09813
# [93]	Test-logloss:0.09893
# [94]	Test-logloss:0.09734
# [95]	Test-logloss:0.09630
# [96]	Test-logloss:0.09708
# [97]	Test-logloss:0.09588
# [98]	Test-logloss:0.09487
# [99]	Test-logloss:0.09460
# [100]	Test-logloss:0.09535
# [101]	Test-logloss:0.09420
# [102]	Test-logloss:0.09325
# [103]	Test-logloss:0.09399
# [104]	Test-logloss:0.09407
# [105]	Test-logloss:0.09297
# [106]	Test-logloss:0.09370
# [107]	Test-logloss:0.09277
# [108]	Test-logloss:0.09172
# [109]	Test-logloss:0.09150
# [110]	Test-logloss:0.09063
# [111]	Test-logloss:0.08963
# [112]	Test-logloss:0.08973
# [113]	Test-logloss:0.08983
# [114]	Test-logloss:0.08953
# [115]	Test-logloss:0.08856
# [116]	Test-logloss:0.08776
# [117]	Test-logloss:0.08760
# [118]	Test-logloss:0.08733
# [119]	Test-logloss:0.08641
# [120]	Test-logloss:0.08566
# [121]	Test-logloss:0.08478
# [122]	Test-logloss:0.08454
# [123]	Test-logloss:0.08441
# [124]	Test-logloss:0.08450
# [125]	Test-logloss:0.08375
# [126]	Test-logloss:0.08363
# [127]	Test-logloss:0.08280
# [128]	Test-logloss:0.08258
# [129]	Test-logloss:0.08191
# [130]	Test-logloss:0.08135
# [131]	Test-logloss:0.08145
# [132]	Test-logloss:0.08092
# [133]	Test-logloss:0.08073
# [134]	Test-logloss:0.08083
# [135]	Test-logloss:0.08011
# [136]	Test-logloss:0.07937
# [137]	Test-logloss:0.07886
# [138]	Test-logloss:0.07870
# [139]	Test-logloss:0.07801
# [140]	Test-logloss:0.07731
# [141]	Test-logloss:0.07683
# [142]	Test-logloss:0.07616
# [143]	Test-logloss:0.07551
# [144]	Test-logloss:0.07534
# [145]	Test-logloss:0.07534
# [146]	Test-logloss:0.07534
# [147]	Test-logloss:0.07533
# [148]	Test-logloss:0.07533
# [149]	Test-logloss:0.07533
# [150]	Test-logloss:0.07533
# [151]	Test-logloss:0.07533
# [152]	Test-logloss:0.07533
# [153]	Test-logloss:0.07533
# [154]	Test-logloss:0.07533
# [155]	Test-logloss:0.07533
# [156]	Test-logloss:0.07533
# [157]	Test-logloss:0.07533
# [158]	Test-logloss:0.07533
# [159]	Test-logloss:0.07533
# [160]	Test-logloss:0.07533
# [161]	Test-logloss:0.07533
# [162]	Test-logloss:0.07533
# [163]	Test-logloss:0.07533
# [164]	Test-logloss:0.07533
# [165]	Test-logloss:0.07533
# [166]	Test-logloss:0.07533
# [167]	Test-logloss:0.07533
# [168]	Test-logloss:0.07533
# [169]	Test-logloss:0.07533
# [170]	Test-logloss:0.07533
# [171]	Test-logloss:0.07533
# [172]	Test-logloss:0.07533
# [173]	Test-logloss:0.07533
# [174]	Test-logloss:0.07533
# [175]	Test-logloss:0.07533
# [176]	Test-logloss:0.07533
# [177]	Test-logloss:0.07533
# [178]	Test-logloss:0.07533
# [179]	Test-logloss:0.07533
# [180]	Test-logloss:0.07533
# [181]	Test-logloss:0.07533
# [182]	Test-logloss:0.07533
# [183]	Test-logloss:0.07533
# [184]	Test-logloss:0.07533
# [185]	Test-logloss:0.07533
# [186]	Test-logloss:0.07533
# [187]	Test-logloss:0.07533
# [188]	Test-logloss:0.07533
# [189]	Test-logloss:0.07533
# [190]	Test-logloss:0.07533
# [191]	Test-logloss:0.07532
# [192]	Test-logloss:0.07532
# [193]	Test-logloss:0.07532
# [194]	Test-logloss:0.07532
# [195]	Test-logloss:0.07532
# [196]	Test-logloss:0.07532
# [197]	Test-logloss:0.07532
# [198]	Test-logloss:0.07532
# [199]	Test-logloss:0.07532
# [200]	Test-logloss:0.07532
# [201]	Test-logloss:0.07532
# [202]	Test-logloss:0.07532
# [203]	Test-logloss:0.07532
# [204]	Test-logloss:0.07532
# [205]	Test-logloss:0.07532
# [206]	Test-logloss:0.07532
# [207]	Test-logloss:0.07532
# [208]	Test-logloss:0.07532
# [209]	Test-logloss:0.07532
# [210]	Test-logloss:0.07532
# [211]	Test-logloss:0.07532
# [212]	Test-logloss:0.07532
# [213]	Test-logloss:0.07532
# [214]	Test-logloss:0.07532
# [215]	Test-logloss:0.07532
# [216]	Test-logloss:0.07532
# [217]	Test-logloss:0.07545
# [218]	Test-logloss:0.07545
# [219]	Test-logloss:0.07545
# [220]	Test-logloss:0.07545
# [221]	Test-logloss:0.07545
# [222]	Test-logloss:0.07545
# [223]	Test-logloss:0.07545
# [224]	Test-logloss:0.07545
# [225]	Test-logloss:0.07545
# [226]	Test-logloss:0.07545
# ROC AUC Score: 1.0
# Accuracy: 1.00

# %%
games_pred = []
def predict(
    season,
    nickname_0, 
    nickname_1
):
    xgb_rf_pred_map_0 = {}
    xgb_rf_pred_map_1 = {}
    
    x_0 = get_prediction_feature_map(xgb_rf_model_and_data_map.get(nickname_0)[2].tail(1), season, nickname_0, nickname_1, 0)
    x_1 = get_prediction_feature_map(xgb_rf_model_and_data_map.get(nickname_1)[2].tail(1), season, nickname_1, nickname_0, 1)
    normalization_func_0 = normalization_func_by_team_nickname.get(nickname_0)[0]
    normalization_func_1 = normalization_func_by_team_nickname.get(nickname_1)[0]
    
    x_0_normalized = pd.DataFrame(normalization_func_0.transform(x_0), columns=x_0.columns)
    x_1_normalized = pd.DataFrame(normalization_func_1.transform(x_1), columns=x_1.columns)
    dnew_0 = xgb.DMatrix(x_0_normalized)
    dnew_1 = xgb.DMatrix(x_1_normalized)

    xgb_res_0 = xgb_rf_model_and_data_map.get(nickname_0)[0].predict(dnew_0)
    xgb_res_1 = xgb_rf_model_and_data_map.get(nickname_1)[0].predict(dnew_1)

    rf_res_0 = xgb_rf_model_and_data_map.get(nickname_0)[1].predict(x_0_normalized)
    rf_res_1 = xgb_rf_model_and_data_map.get(nickname_1)[1].predict(x_1_normalized)

    xgb_rf_pred_map_0[nickname_0] = {
        "xgb_proba": xgb_res_0,
        "rf_clf": rf_res_0
    }
    xgb_rf_pred_map_1[nickname_1] = {
        "xgb_proba": xgb_res_1,
        "rf_clf": rf_res_1
    }

    games_pred.append([xgb_rf_pred_map_0, xgb_rf_pred_map_1])
    
    print(nickname_0, " Xgb Proba: ", xgb_res_0)
    print(nickname_1, " Xgb Proba: ", xgb_res_1)
    print(nickname_0, " Classifier: ", rf_res_0)
    print(nickname_1, " Classifier: ", rf_res_1)

# %%
predict(season, "Nuggets", "Grizzlies")
# Out:
# Nuggets  Xgb Proba:  [0.9821586]
# Grizzlies  Xgb Proba:  [0.14444053]
# Nuggets  Classifier:  [1]
# Grizzlies  Classifier:  [0]

# %%
predict(season, "Trail Blazers", "Kings")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[516], line 1
# ----> 1 predict(season, "Trail Blazers", "Kings")
#
# Cell In[514], line 15, in predict(season, nickname_0, nickname_1)
#      12 normalization_func_0 = normalization_func_by_team_nickname.get(nickname_0)[0]
#      13 normalization_func_1 = normalization_func_by_team_nickname.get(nickname_1)[0]
# ---> 15 x_0_normalized = pd.DataFrame(normalization_func_0.transform(x_0), columns=x_0.columns)
#      16 x_1_normalized = pd.DataFrame(normalization_func_1.transform(x_1), columns=x_1.columns)
#      17 dnew_0 = xgb.DMatrix(x_0_normalized)
#
# File ~/SBS_V1/lib/python3.9/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/SBS_V1/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:534, in MinMaxScaler.transform(self, X)
#     530 check_is_fitted(self)
#     532 xp, _ = get_namespace(X)
# --> 534 X = self._validate_data(
#     535     X,
#     536     copy=self.copy,
#     537     dtype=_array_api.supported_float_dtypes(xp),
#     538     force_all_finite="allow-nan",
#     539     reset=False,
#     540 )
#     542 X *= self.scale_
#     543 X += self.min_
#
# File ~/SBS_V1/lib/python3.9/site-packages/sklearn/base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File ~/SBS_V1/lib/python3.9/site-packages/sklearn/base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - assists4
# - blocks4
# - defReb4
# - fga4
# - fgm4
# - ...

# %%
predict(season, "Jazz", "Warriors")
# Out:
# Jazz  Xgb Proba:  [0.57826185]
# Warriors  Xgb Proba:  [0.9641512]
# Jazz  Classifier:  [1]
# Warriors  Classifier:  [1]

# %%
predict(season, "Mavericks", "Thunder")
# Out:
# Mavericks  Xgb Proba:  [0.07481103]
# Thunder  Xgb Proba:  [0.91211873]
# Mavericks  Classifier:  [0]
# Thunder  Classifier:  [1]

# %%
predict(season, "Pistons", "Spurs")
# Out:
# Pistons  Xgb Proba:  [0.16762024]
# Spurs  Xgb Proba:  [0.3641614]
# Pistons  Classifier:  [0]
# Spurs  Classifier:  [1]

# %%
predict(season, "Suns", "Timberwolves")
# Out:
# Suns  Xgb Proba:  [0.7875267]
# Timberwolves  Xgb Proba:  [0.812995]
# Suns  Classifier:  [1]
# Timberwolves  Classifier:  [1]

# %%
predict(season, "Rockets", "Clippers")
# Out:
# Rockets  Xgb Proba:  [0.13271764]
# Clippers  Xgb Proba:  [0.08186571]
# Rockets  Classifier:  [1]
# Clippers  Classifier:  [0]

# %%
predict(season, "Lakers", "Pelicans")
# Out:
# Lakers  Xgb Proba:  [0.5259744]
# Pelicans  Xgb Proba:  [0.5604663]
# Lakers  Classifier:  [1]
# Pelicans  Classifier:  [0]

# %%
#########################################################
# get probability of games hitting in set ###############
def get_proba_from_set(nickname_set, nickname_to_proba_map):
    proba = 1
    for nickname in nickname_set:
        proba = proba * nickname_to_proba_map.get(nickname)
    return proba

# Get combination of games that have 
# highest probablity of winning
def sort_probable_games(games_pred):
    confident_games = []
    for game in games_pred:
        nickname_0 = list(game[0].keys())[0]
        nickname_1 = list(game[1].keys())[0]
        xgb_0 = game[0].get(nickname_0).get("xgb_proba")[0]
        xgb_1 = game[1].get(nickname_1).get("xgb_proba")[0]
        rf_clf_0 = game[0].get(nickname_0).get("rf_clf")[0]
        rf_clf_1 = game[1].get(nickname_1).get("rf_clf")[0]

        spread = abs(xgb_0 - xgb_1)
        if xgb_0 > xgb_1 and rf_clf_0 == 1 and rf_clf_1 == 0 and spread > .15:
            confident_games.append({ "proba": xgb_0, "spread": spread, "nickname": nickname_0})
        if xgb_0 < xgb_1 and rf_clf_0 == 0 and rf_clf_1 == 1 and spread > .15:
            confident_games.append({ "proba": xgb_1, "spread": spread, "nickname": nickname_1 })

    confident_games = list(filter(lambda game: game.get("proba") > .5, confident_games))
    
    nickname_to_proba_map = {}
    parlays_set = set()
    for game in confident_games:
        nickname_to_proba_map.update({ game.get("nickname"): game.get("proba")})    
        parlays_set.add(frozenset([game.get("nickname")]))
        
    for game in confident_games:
        for parlay in parlays_set.copy():            
            if game.get("nickname") not in parlay and game.get("proba") * get_proba_from_set(parlay, nickname_to_proba_map) > .5:
                parlays_set.add(parlay.union([game.get("nickname")]))
    
    
    parlay_probas = {}
    for parlay in parlays_set:
        parlay_probas.update({ parlay: get_proba_from_set(parlay, nickname_to_proba_map)})
    return nickname_to_proba_map, dict(sorted(parlay_probas.items(), key=lambda item: item[1], reverse=True))
#########################################################

# %%
proba_map, parlay_probas = sort_probable_games(games_pred) 
pprint(proba_map)
print()
pprint(parlay_probas)
# Out:
# {'Nuggets': 0.9821586, 'Thunder': 0.91211873}
#
# {frozenset({'Nuggets'}): 0.9821586012840271,
#  frozenset({'Thunder'}): 0.9121187329292297,
#  frozenset({'Nuggets', 'Thunder'}): 0.8958452589387313}

# %%
# knicks, lakers, Rockets, suns
